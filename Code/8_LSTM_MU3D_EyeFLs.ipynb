# %% [markdown]
# # **Introduction**
# The goal of this program is to reduce the number of facial landmarks and use LSTM network to detect if someone is lying.
#
# This program is built on top of our method 2 model: https://colab.research.google.com/drive/17wdVPuG3W0-RzZMYR5VfvXKmay1uPJun
#
# There are signs in the the movement of eyes or iris that can indicate a person may be potentially lying or stressful
#
#
# *   **Dialated Pupils:** indicate heightened stress or cognitive load, which may occur when someone is lying
# *   **Frequent movement of eyes:** signs of nervousness or cognitive strain, potentially indicating attempts to avoid direct eye contact or manage anxiety associated with deception.
# *   **Execssive Blinking:** --> can suggest discomfort or stress, which might be present when someone is being untruthful.
#
#
#
# Code Reference:
# *   **Eye:**  https://github.com/Asadullah-Dal17/Eyes-Position-Estimator-Mediapipe/blob/master/Eye_Tracking_part2/main.py
# *   **Iris:**  https://github.com/Asadullah-Dal17/Iris-python/blob/master/Mediapip-Eyes-tracking-master%2030.05.2022/eyes_tracking/rastreamento-iris.py

# %%
from google.colab import drive
drive.mount('/content/drive')

import numpy as np
import glob
from pathlib import Path
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import math


# Check for GPU availability and set device
#device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = torch.device("cpu")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 2-Layer MLP
# Exact code from method 2 modelling

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

class LSTMModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, layer_num, output_dim):
        super().__init__()
        self.lstm = nn.LSTM(input_size=input_dim, hidden_size=hidden_dim, num_layers=layer_num, batch_first=True)
        self.dropout = nn.Dropout(0.20)
        self.linear = nn.Linear(200, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        out, _ = self.lstm(x)
        out = out[:, -1, :]
        out = self.linear(self.dropout(out))
        out = self.sigmoid(out)
        return out

# %% [markdown]
# # **Getting the Classified Output Y**

# %%
EXCEL_DATA_PATH  = '/content/drive/MyDrive/Deception_Detection/Datasets/MU3D-Package/MU3D Codebook.xlsx'
FOLDER = '/content/drive/MyDrive/Deception_Detection/Datasets/MU3D-Package'
SAVE_NPY_PATH = FOLDER + "/" + "NPY_FILES(240frames)"

df = pd.read_excel(EXCEL_DATA_PATH, sheet_name="Video-Level Data")

# Iterate through each row of the Excel file
truthfulness = {}
for index, row in df.iterrows():
  truthfulness[row["VideoID"]] = row["Veracity"]

# 0 indicates lie, 1 indicates truth

# %% [markdown]
# # **Getting the Input X**

# %%
RIGHT_EYE=[ 33, 7, 163, 144, 145, 153, 154, 155, 133, 173, 157, 158, 159, 160, 161 , 246 ]
LEFT_EYE =[ 362, 382, 381, 380, 374, 373, 390, 249, 263, 466, 388, 387, 386, 385,384, 398 ]

LEFT_IRIS = [474, 475, 476, 477]
RIGHT_IRIS = [469, 470, 471, 472]

L_H_LEFT = [33]     # right eye most right reference point
L_H_RIGHT = [133]   # right eye most left reference point
R_H_LEFT = [362]    # left eye most right reference point
R_H_RIGHT = [263]   # left eye most left reference point

# %% [markdown]
# ## Functions

# %% [markdown]
# #### Convert a numpy array and convert it into chunks
# We have 320 video. Each video is represented by a (240, 478, 2) array. We will divide them into 8 chunks. So each chunk will be a (30, 956) array.

# %%
def npy_to_npychunks(data):

  chunk_size = 30
  num_chunks = data.shape[0] // chunk_size

  # Split the array into chunks
  chunks = np.array_split(data[:num_chunks * 30], num_chunks)

  # Convert list of arrays to a single numpy array
  array = np.stack(chunks)
  return array

# %% [markdown]
# #### Calculating Euclidean Distance

# %%
# Euclidean Distance
def euclideanDistance(point, point1):
    x, y = point
    x1, y1 = point1
    distance = np.sqrt((x1 - x)**2 + (y1 - y)**2)
    return distance

# %% [markdown]
# #### Calculating Blink Ratio

# %%
# Blink Ratio
def blinkRatio(right_eye_landmarks, left_eye_landmarks):
    ratios = []
    # Loop through each frame of landmarks
    for rh_landmarks, lh_landmarks in zip(right_eye_landmarks, left_eye_landmarks):
        # Right eye
        # Horizontal line
        rh_right = rh_landmarks[0]
        rh_left = rh_landmarks[8]
        # Vertical line
        rv_top = rh_landmarks[12]
        rv_bottom = rh_landmarks[4]

        # Left eye
        # Horizontal line
        lh_right = lh_landmarks[0]
        lh_left = lh_landmarks[8]
        # Vertical line
        lv_top = lh_landmarks[12]
        lv_bottom = lh_landmarks[4]

        # Calculate distances
        rhDistance = euclideanDistance(rh_right, rh_left)
        rvDistance = euclideanDistance(rv_top, rv_bottom)
        lhDistance = euclideanDistance(lh_right, lh_left)
        lvDistance = euclideanDistance(lv_top, lv_bottom)

        # Calculate ratios
        reRatio = rhDistance / rvDistance
        # print(reRatio)
        leRatio = lhDistance / lvDistance
        # print(leRatio)

        # Calculate average ratio
        ratio = (reRatio + leRatio) / 2
        ratios.append(ratio)

    return np.array(ratios)

# %% [markdown]
# ### Adding another dimension

# %%
def add_dimension(original_array, dimension_to_add):
  reshaped_array = dimension_to_add[:, np.newaxis, np.newaxis] # Reshape the blink ratio array to match the size of the combined landmarks along axis 1 and axis 2
  reshaped_array = np.repeat(reshaped_array, original_array.shape[1], axis=1) # Repeat the reshaped_ratioarray along axis 1 to match the size of the combined landmarks
  combined_array = np.concatenate((original_array, reshaped_array), axis=2) # Concatenate the repeated blink ratio array with the combined landmarks array along the last dimension
  return combined_array

# %% [markdown]
# ## Eyes

# %% [markdown]
# ### Left and Right Eye Facial Landmarks each with  XY coordinates

# %%
import random

input_list_T = []
input_list_F = []
output_list_T = []
output_list_F = []

loop = 1
for file_path in glob.glob(SAVE_NPY_PATH+"/*", recursive = True):
  # Y Value
  output = truthfulness[Path(file_path).stem]

  # X Value
  array = np.load(file_path)
  # print("Original shape of array: ", array.shape)

  right_eye_landmarks = array[:, RIGHT_EYE, :]
  left_eye_landmarks = array[:, LEFT_EYE, :]
  combined_landmarks = np.concatenate((right_eye_landmarks, left_eye_landmarks), axis=1)
  print("Combimed shape of an array: ",combined_landmarks.shape)

  array = combined_landmarks.reshape(240, -1)

  array = npy_to_npychunks(array)
  print("Chunk shape array: ", array.shape)
  num_chunks = array.shape[0]

  if output == 1:
    input_list_T.append(array)
    output_list_T += [output]*num_chunks
  else:
    input_list_F.append(array)
    output_list_F += [output]*num_chunks
  print(f"# of Videos Processed: {loop}")
  loop += 1


X_T = np.vstack(input_list_T)
X_F = np.vstack(input_list_F)
Y_T = np.array(output_list_T).reshape(-1,1)
Y_F = np.array(output_list_F).reshape(-1,1)



X_T = torch.from_numpy(X_T).to(device)
X_F = torch.from_numpy(X_F).to(device)
Y_T = torch.from_numpy(Y_T).to(device)
Y_F = torch.from_numpy(Y_F).to(device)

X_T = X_T.float()
X_F = X_F.float()
Y_T = Y_T.float()
Y_F = Y_F.float()

print("X_T.shape", X_T.shape)
print("X_F.shape", X_F.shape)
print("Y_T.shape", Y_T.shape)
print("Y_F.shape", Y_F.shape)
# Out:
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 1
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 2
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 3
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 4
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 5
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 6
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 7
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 8
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 9
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 10
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 11
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 12
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 13
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 14
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 15
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 16
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 17
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 18
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 19
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 20
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 21
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 22
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 23
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 24
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 25
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 26
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 27
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 28
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 29
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 30
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 31
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 32
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 33
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 34
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 35
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 36
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 37
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 38
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 39
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 40
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 41
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 42
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 43
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 44
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 45
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 46
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 47
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 48
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 49
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 50
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 51
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 52
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 53
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 54
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 55
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 56
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 57
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 58
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 59
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 60
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 61
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 62
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 63
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 64
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 65
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 66
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 67
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 68
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 69
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 70
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 71
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 72
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 73
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 74
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 75
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 76
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 77
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 78
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 79
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 80
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 81
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 82
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 83
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 84
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 85
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 86
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 87
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 88
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 89
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 90
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 91
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 92
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 93
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 94
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 95
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 96
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 97
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 98
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 99
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 100
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 101
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 102
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 103
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 104
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 105
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 106
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 107
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 108
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 109
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 110
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 111
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 112
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 113
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 114
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 115
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 116
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 117
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 118
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 119
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 120
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 121
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 122
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 123
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 124
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 125
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 126
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 127
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 128
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 129
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 130
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 131
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 132
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 133
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 134
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 135
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 136
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 137
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 138
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 139
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 140
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 141
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 142
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 143
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 144
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 145
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 146
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 147
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 148
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 149
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 150
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 151
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 152
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 153
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 154
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 155
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 156
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 157
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 158
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 159
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 160
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 161
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 162
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 163
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 164
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 165
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 166
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 167
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 168
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 169
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 170
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 171
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 172
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 173
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 174
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 175
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 176
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 177
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 178
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 179
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 180
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 181
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 182
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 183
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 184
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 185
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 186
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 187
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 188
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 189
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 190
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 191
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 192
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 193
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 194
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 195
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 196
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 197
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 198
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 199
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 200
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 201
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 202
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 203
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 204
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 205
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 206
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 207
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 208
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 209
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 210
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 211
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 212
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 213
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 214
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 215
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 216
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 217
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 218
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 219
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 220
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 221
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 222
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 223
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 224
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 225
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 226
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 227
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 228
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 229
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 230
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 231
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 232
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 233
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 234
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 235
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 236
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 237
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 238
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 239
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 240
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 241
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 242
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 243
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 244
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 245
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 246
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 247
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 248
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 249
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 250
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 251
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 252
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 253
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 254
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 255
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 256
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 257
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 258
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 259
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 260
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 261
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 262
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 263
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 264
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 265
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 266
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 267
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 268
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 269
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 270
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 271
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 272
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 273
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 274
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 275
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 276
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 277
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 278
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 279
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 280
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 281
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 282
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 283
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 284
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 285
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 286
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 287
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 288
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 289
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 290
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 291
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 292
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 293
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 294
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 295
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 296
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 297
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 298
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 299
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 300
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 301
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 302
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 303
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 304
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 305
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 306
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 307
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 308
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 309
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 310
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 311
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 312
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 313
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 314
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 315
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 316
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 317
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 318
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 319
# Combimed shape of an array:  (240, 32, 2)
# Chunk shape array:  (8, 30, 64)
# # of Videos Processed: 320
# X_T.shape torch.Size([1280, 30, 64])
# X_F.shape torch.Size([1280, 30, 64])
# Y_T.shape torch.Size([1280, 1])
# Y_F.shape torch.Size([1280, 1])

# %%
import torch.utils.data as data

# Split the shuffled data into 80% Training, 20% Testing
train_dataset_T, val_dataset_T = torch.utils.data.random_split(data.TensorDataset(X_T, Y_T), [0.8, 0.2])
train_dataset_F, val_dataset_F = torch.utils.data.random_split(data.TensorDataset(X_F, Y_F), [0.8, 0.2])

train_dataset = data.ConcatDataset([train_dataset_T, train_dataset_F])
val_dataset = data.ConcatDataset([val_dataset_T, val_dataset_F])

print("Training Dataset Size:", len(train_dataset))
print("Testing Dataset Size:", len(val_dataset))
print()

train_loader = data.DataLoader(train_dataset, batch_size=50, shuffle=True)

total_train_samples = len(train_dataset)
count_train_ones = sum(1 for _, label in train_dataset if label == 1)
percentage_train_ones = (count_train_ones / total_train_samples) * 100
print("Percentage of Y that are Truths in train_dataset:", percentage_train_ones)


test_loader = data.DataLoader(val_dataset, batch_size=1, shuffle=False)

total_val_samples = len(val_dataset)
count_val_ones = sum(1 for _, label in val_dataset if label == 1)
percentage_val_ones = (count_val_ones / total_val_samples) * 100
print("Percentage of Y that are Truths in val_dataset:", percentage_val_ones)


X_train_all = []
Y_train_all = []


# Iterate over the train_loader to accumulate the entire dataset
for X_train, Y_train in train_loader:
    X_train_all.append(X_train)
    Y_train_all.append(Y_train)

X_test_all = []
Y_test_all = []

for X_test, Y_test in test_loader:
    X_test_all.append(X_test)
    Y_test_all.append(Y_test)

X_test_all = torch.cat(X_test_all, dim=0).to(device)
Y_test_all = torch.cat(Y_test_all, dim=0).to(device)

X_train_all = torch.cat(X_train_all, dim=0).to(device)
Y_train_all = torch.cat(Y_train_all, dim=0).to(device)
# Out:
# Training Dataset Size: 2048
# Testing Dataset Size: 512
#
# Percentage of Y that are Truths in train_dataset: 50.0
# Percentage of Y that are Truths in val_dataset: 50.0

# %%
import torch.utils.data as data
import matplotlib.pyplot as plt

# Lists to store training and test losses for each epoch
train_losses = []
test_losses = []

# Function to calculate accuracy
def accuracy(outputs, labels):
  preds = torch.round(outputs)
  return torch.tensor(torch.sum(preds == labels).item() / len(preds))


criterion = nn.BCELoss()
model = LSTMModel(input_dim=956, hidden_dim=200, layer_num=1, output_dim=1)
model = model.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

num_epochs = 50

# Training loop
for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0.0
    epoch_acc = 0.0
    for X_batch, y_batch in train_loader:
        y_pred = model(X_batch)
        loss = criterion(y_pred, y_batch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    model.eval()
    with torch.no_grad():
        print("-------------------")
        # Calculate accuracy on training set
        y_pred = model(X_train_all)
        train_loss = criterion(y_pred, Y_train_all)
        train_acc = accuracy(y_pred, Y_train_all)

        # Calculate accuracy on test set
        y_pred = model(X_test_all)
        test_loss = criterion(y_pred, Y_test_all)

        test_acc = accuracy(y_pred, Y_test_all)

    print("Epoch %d: train loss %.4f, test loss %.4f, train accuracy %.4f, test accuracy %.4f" % (epoch, train_loss, test_loss, train_acc, test_acc))

    # Append the losses to the lists
    train_losses.append(train_loss)
    test_losses.append(test_loss)

# Smooth the losses using a moving average
window_size = 5
train_losses_smoothed = np.convolve(train_losses, np.ones(window_size) / window_size, mode='valid')
test_losses_smoothed = np.convolve(test_losses, np.ones(window_size) / window_size, mode='valid')

# Plotting epoch vs training loss and test loss
epochs = range(window_size // 2 + 1, num_epochs - window_size // 2 + 1)
plt.plot(epochs, train_losses_smoothed, label='Train Loss')
plt.plot(epochs, test_losses_smoothed, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Epoch vs Loss (Smoothed)')
plt.legend()
plt.show()
# Out:
# -------------------
# Epoch 0: train loss 0.6931, test loss 0.6936, train accuracy 0.5034, test accuracy 0.4883
# -------------------
# Epoch 1: train loss 0.6931, test loss 0.6937, train accuracy 0.5024, test accuracy 0.5000
# -------------------
# Epoch 2: train loss 0.6931, test loss 0.6940, train accuracy 0.5010, test accuracy 0.4785
# -------------------
# Epoch 3: train loss 0.6931, test loss 0.6938, train accuracy 0.4995, test accuracy 0.4941
# -------------------
# Epoch 4: train loss 0.6931, test loss 0.6941, train accuracy 0.5161, test accuracy 0.4531
# -------------------
# Epoch 5: train loss 0.6931, test loss 0.6941, train accuracy 0.4961, test accuracy 0.4570
# -------------------
# Epoch 6: train loss 0.6931, test loss 0.6940, train accuracy 0.5117, test accuracy 0.4512
# -------------------
# Epoch 7: train loss 0.6931, test loss 0.6941, train accuracy 0.4971, test accuracy 0.4785
# -------------------
# Epoch 8: train loss 0.6932, test loss 0.6941, train accuracy 0.4990, test accuracy 0.5000
# -------------------
# Epoch 9: train loss 0.6931, test loss 0.6944, train accuracy 0.5000, test accuracy 0.4727
# -------------------
# Epoch 10: train loss 0.6931, test loss 0.6943, train accuracy 0.4985, test accuracy 0.4609
# -------------------
# Epoch 11: train loss 0.6930, test loss 0.6942, train accuracy 0.5166, test accuracy 0.4512
# -------------------
# Epoch 12: train loss 0.6930, test loss 0.6942, train accuracy 0.5156, test accuracy 0.4590
# -------------------
# Epoch 13: train loss 0.6931, test loss 0.6941, train accuracy 0.5024, test accuracy 0.4688
# -------------------
# Epoch 14: train loss 0.6930, test loss 0.6942, train accuracy 0.4956, test accuracy 0.4590
# -------------------
# Epoch 15: train loss 0.6931, test loss 0.6942, train accuracy 0.5000, test accuracy 0.4902
# -------------------
# Epoch 16: train loss 0.6930, test loss 0.6943, train accuracy 0.5024, test accuracy 0.4492
# -------------------
# Epoch 17: train loss 0.6930, test loss 0.6943, train accuracy 0.5171, test accuracy 0.4551
# -------------------
# Epoch 18: train loss 0.6930, test loss 0.6942, train accuracy 0.5039, test accuracy 0.4668
# -------------------
# Epoch 19: train loss 0.6930, test loss 0.6944, train accuracy 0.5142, test accuracy 0.4473
# -------------------
# Epoch 20: train loss 0.6931, test loss 0.6946, train accuracy 0.4951, test accuracy 0.4668
# -------------------
# Epoch 21: train loss 0.6930, test loss 0.6944, train accuracy 0.5063, test accuracy 0.4512
# -------------------
# Epoch 22: train loss 0.6931, test loss 0.6943, train accuracy 0.5039, test accuracy 0.4883
# -------------------
# Epoch 23: train loss 0.6930, test loss 0.6942, train accuracy 0.4995, test accuracy 0.4766
# -------------------
# Epoch 24: train loss 0.6930, test loss 0.6943, train accuracy 0.5024, test accuracy 0.4570
# -------------------
# Epoch 25: train loss 0.6930, test loss 0.6943, train accuracy 0.5156, test accuracy 0.4609
# -------------------
# Epoch 26: train loss 0.6930, test loss 0.6944, train accuracy 0.5093, test accuracy 0.4570
# -------------------
# Epoch 27: train loss 0.6930, test loss 0.6944, train accuracy 0.5078, test accuracy 0.4629
# -------------------
# Epoch 28: train loss 0.6930, test loss 0.6944, train accuracy 0.5200, test accuracy 0.4688
# -------------------
# Epoch 29: train loss 0.6930, test loss 0.6944, train accuracy 0.5142, test accuracy 0.4570
# -------------------
# Epoch 30: train loss 0.6930, test loss 0.6944, train accuracy 0.5029, test accuracy 0.4512
# -------------------
# Epoch 31: train loss 0.6930, test loss 0.6944, train accuracy 0.5034, test accuracy 0.4551
# -------------------
# Epoch 32: train loss 0.6931, test loss 0.6947, train accuracy 0.4956, test accuracy 0.4551
# -------------------
# Epoch 33: train loss 0.6932, test loss 0.6949, train accuracy 0.5034, test accuracy 0.4805
# -------------------
# Epoch 34: train loss 0.6930, test loss 0.6945, train accuracy 0.5181, test accuracy 0.4727
# -------------------
# Epoch 35: train loss 0.6930, test loss 0.6946, train accuracy 0.5039, test accuracy 0.4590
# -------------------
# Epoch 36: train loss 0.6930, test loss 0.6945, train accuracy 0.5200, test accuracy 0.4766
# -------------------
# Epoch 37: train loss 0.6930, test loss 0.6944, train accuracy 0.5127, test accuracy 0.4590
# -------------------
# Epoch 38: train loss 0.6930, test loss 0.6944, train accuracy 0.5083, test accuracy 0.4531
# -------------------
# Epoch 39: train loss 0.6930, test loss 0.6945, train accuracy 0.5063, test accuracy 0.4590
# -------------------
# Epoch 40: train loss 0.6930, test loss 0.6945, train accuracy 0.5171, test accuracy 0.4746
# -------------------
# Epoch 41: train loss 0.6930, test loss 0.6945, train accuracy 0.5117, test accuracy 0.4590
# -------------------
# Epoch 42: train loss 0.6930, test loss 0.6945, train accuracy 0.5156, test accuracy 0.4668
# -------------------
# Epoch 43: train loss 0.6930, test loss 0.6946, train accuracy 0.5117, test accuracy 0.4629
# -------------------
# Epoch 44: train loss 0.6930, test loss 0.6945, train accuracy 0.5029, test accuracy 0.4688
# -------------------
# Epoch 45: train loss 0.6930, test loss 0.6945, train accuracy 0.5093, test accuracy 0.4590
# -------------------
# Epoch 46: train loss 0.6930, test loss 0.6945, train accuracy 0.5137, test accuracy 0.4609
# -------------------
# Epoch 47: train loss 0.6930, test loss 0.6945, train accuracy 0.5020, test accuracy 0.4668
# -------------------
# Epoch 48: train loss 0.6930, test loss 0.6944, train accuracy 0.5171, test accuracy 0.4609
# -------------------
# Epoch 49: train loss 0.6930, test loss 0.6946, train accuracy 0.5229, test accuracy 0.4785

# %% [markdown]
# ### Adding Blink ratio

# %%
import numpy as np

import random

input_list_T = []
input_list_F = []
output_list_T = []
output_list_F = []

loop = 1
for file_path in glob.glob(SAVE_NPY_PATH+"/*", recursive = True):
  # Y Value
  output = truthfulness[Path(file_path).stem]

  # X Value
  array = np.load(file_path)

  ## Filter to just eye landmarks
  right_eye_landmarks = array[:, RIGHT_EYE, :]
  left_eye_landmarks = array[:, LEFT_EYE, :]
  combined_landmarks = np.concatenate((right_eye_landmarks, left_eye_landmarks), axis=1)

  ratioarray = blinkRatio(right_eye_landmarks, left_eye_landmarks)
  combined_array = add_dimension(combined_landmarks, ratioarray)

  # ## We add ratio array as the third dimension
  # reshaped_ratioarray = ratioarray[:, np.newaxis, np.newaxis] # Reshape the blink ratio array to match the size of the combined landmarks along axis 1 and axis 2
  # repeated_ratioarray = np.repeat(reshaped_ratioarray, combined_landmarks.shape[1], axis=1) # Repeat the reshaped_ratioarray along axis 1 to match the size of the combined landmarks
  # combined_array = np.concatenate((combined_landmarks, repeated_ratioarray), axis=2) # Concatenate the repeated blink ratio array with the combined landmarks array along the last dimension

  print(combined_array.shape)
  array = combined_array.reshape(240, -1)
  print(array.shape)
  array = npy_to_npychunks(array)
  print(array.shape)
  num_chunks = array.shape[0]

  if output == 1:
    input_list_T.append(array)
    output_list_T += [output]*num_chunks
  else:
    input_list_F.append(array)
    output_list_F += [output]*num_chunks
  print(f"# of Videos Processed: {loop}")
  loop += 1


X_T = np.vstack(input_list_T)
X_F = np.vstack(input_list_F)
Y_T = np.array(output_list_T).reshape(-1,1)
Y_F = np.array(output_list_F).reshape(-1,1)



X_T = torch.from_numpy(X_T).to(device)
X_F = torch.from_numpy(X_F).to(device)
Y_T = torch.from_numpy(Y_T).to(device)
Y_F = torch.from_numpy(Y_F).to(device)

X_T = X_T.float()
X_F = X_F.float()
Y_T = Y_T.float()
Y_F = Y_F.float()

print("X_T.shape", X_T.shape)
print("X_F.shape", X_F.shape)
print("Y_T.shape", Y_T.shape)
print("Y_F.shape", Y_F.shape)
# Out:
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 1
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 2
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 3
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 4
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 5
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 6
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 7
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 8
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 9
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 10
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 11
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 12
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 13
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 14
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 15
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 16
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 17
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 18
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 19
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 20
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 21
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 22
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 23
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 24
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 25
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 26
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 27
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 28
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 29
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 30
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 31
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 32
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 33
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 34
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 35
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 36
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 37
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 38
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 39
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 40
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 41
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 42
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 43
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 44
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 45
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 46
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 47
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 48
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 49
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 50
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 51
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 52
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 53
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 54
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 55
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 56
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 57
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 58
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 59
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 60
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 61
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 62
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 63
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 64
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 65
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 66
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 67
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 68
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 69
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 70
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 71
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 72
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 73
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 74
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 75
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 76
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 77
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 78
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 79
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 80
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 81
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 82
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 83
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 84
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 85
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 86
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 87
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 88
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 89
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 90
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 91
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 92
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 93
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 94
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 95
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 96
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 97
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 98
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 99
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 100
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 101
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 102
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 103
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 104
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 105
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 106
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 107
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 108
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 109
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 110
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 111
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 112
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 113
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 114
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 115
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 116
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 117
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 118
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 119
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 120
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 121
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 122
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 123
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 124
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 125
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 126
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 127
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 128
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 129
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 130
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 131
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 132
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 133
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 134
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 135
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 136
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 137
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 138
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 139
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 140
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 141
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 142
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 143
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 144
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 145
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 146
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 147
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 148
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 149
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 150
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 151
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 152
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 153
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 154
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 155
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 156
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 157
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 158
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 159
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 160
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 161
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 162
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 163
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 164
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 165
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 166
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 167
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 168
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 169
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 170
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 171
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 172
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 173
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 174
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 175
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 176
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 177
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 178
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 179
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 180
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 181
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 182
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 183
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 184
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 185
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 186
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 187
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 188
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 189
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 190
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 191
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 192
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 193
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 194
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 195
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 196
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 197
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 198
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 199
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 200
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 201
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 202
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 203
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 204
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 205
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 206
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 207
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 208
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 209
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 210
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 211
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 212
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 213
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 214
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 215
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 216
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 217
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 218
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 219
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 220
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 221
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 222
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 223
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 224
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 225
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 226
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 227
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 228
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 229
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 230
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 231
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 232
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 233
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 234
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 235
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 236
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 237
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 238
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 239
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 240
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 241
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 242
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 243
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 244
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 245
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 246
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 247
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 248
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 249
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 250
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 251
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 252
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 253
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 254
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 255
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 256
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 257
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 258
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 259
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 260
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 261
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 262
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 263
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 264
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 265
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 266
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 267
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 268
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 269
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 270
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 271
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 272
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 273
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 274
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 275
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 276
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 277
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 278
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 279
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 280
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 281
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 282
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 283
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 284
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 285
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 286
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 287
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 288
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 289
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 290
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 291
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 292
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 293
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 294
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 295
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 296
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 297
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 298
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 299
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 300
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 301
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 302
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 303
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 304
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 305
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 306
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 307
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 308
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 309
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 310
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 311
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 312
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 313
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 314
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 315
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 316
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 317
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 318
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 319
# (240, 32, 3)
# (240, 96)
# (8, 30, 96)
# # of Videos Processed: 320
# X_T.shape torch.Size([1280, 30, 96])
# X_F.shape torch.Size([1280, 30, 96])
# Y_T.shape torch.Size([1280, 1])
# Y_F.shape torch.Size([1280, 1])

# %%
import torch.utils.data as data

# Split the shuffled data into 80% Training, 20% Testing
train_dataset_T, val_dataset_T = torch.utils.data.random_split(data.TensorDataset(X_T, Y_T), [0.8, 0.2])
train_dataset_F, val_dataset_F = torch.utils.data.random_split(data.TensorDataset(X_F, Y_F), [0.8, 0.2])

train_dataset = data.ConcatDataset([train_dataset_T, train_dataset_F])
val_dataset = data.ConcatDataset([val_dataset_T, val_dataset_F])

print("Training Dataset Size:", len(train_dataset))
print("Testing Dataset Size:", len(val_dataset))
print()

train_loader = data.DataLoader(train_dataset, batch_size=50, shuffle=True)

total_train_samples = len(train_dataset)
count_train_ones = sum(1 for _, label in train_dataset if label == 1)
percentage_train_ones = (count_train_ones / total_train_samples) * 100
print("Percentage of Y that are Truths in train_dataset:", percentage_train_ones)


test_loader = data.DataLoader(val_dataset, batch_size=1, shuffle=False)

total_val_samples = len(val_dataset)
count_val_ones = sum(1 for _, label in val_dataset if label == 1)
percentage_val_ones = (count_val_ones / total_val_samples) * 100
print("Percentage of Y that are Truths in val_dataset:", percentage_val_ones)


X_train_all = []
Y_train_all = []


# Iterate over the train_loader to accumulate the entire dataset
for X_train, Y_train in train_loader:
    X_train_all.append(X_train)
    Y_train_all.append(Y_train)

X_test_all = []
Y_test_all = []

for X_test, Y_test in test_loader:
    X_test_all.append(X_test)
    Y_test_all.append(Y_test)

X_test_all = torch.cat(X_test_all, dim=0).to(device)
Y_test_all = torch.cat(Y_test_all, dim=0).to(device)

X_train_all = torch.cat(X_train_all, dim=0).to(device)
Y_train_all = torch.cat(Y_train_all, dim=0).to(device)
# Out:
# Training Dataset Size: 2048
# Testing Dataset Size: 512
#
# Percentage of Y that are Truths in train_dataset: 50.0
# Percentage of Y that are Truths in val_dataset: 50.0

# %%
import torch.utils.data as data
import matplotlib.pyplot as plt

# Lists to store training and test losses for each epoch
train_losses = []
test_losses = []

# Function to calculate accuracy
def accuracy(outputs, labels):
  preds = torch.round(outputs)
  return torch.tensor(torch.sum(preds == labels).item() / len(preds))


criterion = nn.BCELoss()
model = LSTMModel(input_dim=956, hidden_dim=200, layer_num=1, output_dim=1)
model = model.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

num_epochs = 50

# Training loop
for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0.0
    epoch_acc = 0.0
    for X_batch, y_batch in train_loader:
        y_pred = model(X_batch)
        loss = criterion(y_pred, y_batch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    model.eval()
    with torch.no_grad():
        print("-------------------")
        # Calculate accuracy on training set
        y_pred = model(X_train_all)
        train_loss = criterion(y_pred, Y_train_all)
        train_acc = accuracy(y_pred, Y_train_all)

        # Calculate accuracy on test set
        y_pred = model(X_test_all)
        test_loss = criterion(y_pred, Y_test_all)

        test_acc = accuracy(y_pred, Y_test_all)

    print("Epoch %d: train loss %.4f, test loss %.4f, train accuracy %.4f, test accuracy %.4f" % (epoch, train_loss, test_loss, train_acc, test_acc))

    # Append the losses to the lists
    train_losses.append(train_loss)
    test_losses.append(test_loss)

# Smooth the losses using a moving average
window_size = 5
train_losses_smoothed = np.convolve(train_losses, np.ones(window_size) / window_size, mode='valid')
test_losses_smoothed = np.convolve(test_losses, np.ones(window_size) / window_size, mode='valid')

# Plotting epoch vs training loss and test loss
epochs = range(window_size // 2 + 1, num_epochs - window_size // 2 + 1)
plt.plot(epochs, train_losses_smoothed, label='Train Loss')
plt.plot(epochs, test_losses_smoothed, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Epoch vs Loss (Smoothed)')
plt.legend()
plt.show()
# Out:
# -------------------
# Epoch 0: train loss 0.6924, test loss 0.6958, train accuracy 0.5146, test accuracy 0.4668
# -------------------
# Epoch 1: train loss 0.6923, test loss 0.6975, train accuracy 0.5098, test accuracy 0.4746
# -------------------
# Epoch 2: train loss 0.6921, test loss 0.6970, train accuracy 0.5190, test accuracy 0.4609
# -------------------
# Epoch 3: train loss 0.6919, test loss 0.6966, train accuracy 0.5186, test accuracy 0.4629
# -------------------
# Epoch 4: train loss 0.6919, test loss 0.6965, train accuracy 0.5112, test accuracy 0.4570
# -------------------
# Epoch 5: train loss 0.6931, test loss 0.6982, train accuracy 0.4995, test accuracy 0.5000
# -------------------
# Epoch 6: train loss 0.6921, test loss 0.6973, train accuracy 0.5073, test accuracy 0.5039
# -------------------
# Epoch 7: train loss 0.6921, test loss 0.6969, train accuracy 0.5254, test accuracy 0.4707
# -------------------
# Epoch 8: train loss 0.6916, test loss 0.6975, train accuracy 0.5107, test accuracy 0.4707
# -------------------
# Epoch 9: train loss 0.6916, test loss 0.6967, train accuracy 0.5264, test accuracy 0.4590
# -------------------
# Epoch 10: train loss 0.6912, test loss 0.6963, train accuracy 0.5254, test accuracy 0.4668
# -------------------
# Epoch 11: train loss 0.6919, test loss 0.6970, train accuracy 0.5264, test accuracy 0.4766
# -------------------
# Epoch 12: train loss 0.6912, test loss 0.6967, train accuracy 0.5264, test accuracy 0.4688
# -------------------
# Epoch 13: train loss 0.6910, test loss 0.6972, train accuracy 0.5234, test accuracy 0.4805
# -------------------
# Epoch 14: train loss 0.6909, test loss 0.6968, train accuracy 0.5269, test accuracy 0.4668
# -------------------
# Epoch 15: train loss 0.6916, test loss 0.6969, train accuracy 0.5098, test accuracy 0.5078
# -------------------
# Epoch 16: train loss 0.6907, test loss 0.6967, train accuracy 0.5239, test accuracy 0.4629
# -------------------
# Epoch 17: train loss 0.6909, test loss 0.6973, train accuracy 0.5259, test accuracy 0.4629
# -------------------
# Epoch 18: train loss 0.6908, test loss 0.6964, train accuracy 0.5322, test accuracy 0.4570
# -------------------
# Epoch 19: train loss 0.6906, test loss 0.6974, train accuracy 0.5142, test accuracy 0.4609
# -------------------
# Epoch 20: train loss 0.6904, test loss 0.6969, train accuracy 0.5332, test accuracy 0.4766
# -------------------
# Epoch 21: train loss 0.6902, test loss 0.6966, train accuracy 0.5332, test accuracy 0.4766
# -------------------
# Epoch 22: train loss 0.6921, test loss 0.6981, train accuracy 0.5273, test accuracy 0.4844
# -------------------
# Epoch 23: train loss 0.6902, test loss 0.6973, train accuracy 0.5225, test accuracy 0.4805
# -------------------
# Epoch 24: train loss 0.6898, test loss 0.6961, train accuracy 0.5332, test accuracy 0.4844
# -------------------
# Epoch 25: train loss 0.6899, test loss 0.6961, train accuracy 0.5391, test accuracy 0.4902
# -------------------
# Epoch 26: train loss 0.6896, test loss 0.6957, train accuracy 0.5347, test accuracy 0.4727
# -------------------
# Epoch 27: train loss 0.6910, test loss 0.6996, train accuracy 0.5259, test accuracy 0.5020
# -------------------
# Epoch 28: train loss 0.6897, test loss 0.6983, train accuracy 0.5332, test accuracy 0.4590
# -------------------
# Epoch 29: train loss 0.6895, test loss 0.6962, train accuracy 0.5332, test accuracy 0.4805
# -------------------
# Epoch 30: train loss 0.6889, test loss 0.6963, train accuracy 0.5283, test accuracy 0.4883
# -------------------
# Epoch 31: train loss 0.6886, test loss 0.6963, train accuracy 0.5410, test accuracy 0.4805
# -------------------
# Epoch 32: train loss 0.6889, test loss 0.6958, train accuracy 0.5386, test accuracy 0.4766
# -------------------
# Epoch 33: train loss 0.6883, test loss 0.6968, train accuracy 0.5308, test accuracy 0.4941
# -------------------
# Epoch 34: train loss 0.6880, test loss 0.6958, train accuracy 0.5400, test accuracy 0.4883
# -------------------
# Epoch 35: train loss 0.6882, test loss 0.6969, train accuracy 0.5293, test accuracy 0.5039
# -------------------
# Epoch 36: train loss 0.6889, test loss 0.6971, train accuracy 0.5356, test accuracy 0.4629
# -------------------
# Epoch 37: train loss 0.6881, test loss 0.6953, train accuracy 0.5396, test accuracy 0.4805
# -------------------
# Epoch 38: train loss 0.6871, test loss 0.6960, train accuracy 0.5483, test accuracy 0.4922
# -------------------
# Epoch 39: train loss 0.6880, test loss 0.6964, train accuracy 0.5464, test accuracy 0.4883
# -------------------
# Epoch 40: train loss 0.6872, test loss 0.6947, train accuracy 0.5420, test accuracy 0.4961
# -------------------
# Epoch 41: train loss 0.6866, test loss 0.6981, train accuracy 0.5444, test accuracy 0.4805
# -------------------
# Epoch 42: train loss 0.6877, test loss 0.6972, train accuracy 0.5430, test accuracy 0.4824
# -------------------
# Epoch 43: train loss 0.6885, test loss 0.6987, train accuracy 0.5327, test accuracy 0.4883
# -------------------
# Epoch 44: train loss 0.6872, test loss 0.6956, train accuracy 0.5498, test accuracy 0.4805
# -------------------
# Epoch 45: train loss 0.6886, test loss 0.6979, train accuracy 0.5366, test accuracy 0.5000
# -------------------
# Epoch 46: train loss 0.6863, test loss 0.6957, train accuracy 0.5386, test accuracy 0.4922
# -------------------
# Epoch 47: train loss 0.6878, test loss 0.6978, train accuracy 0.5317, test accuracy 0.5059
# -------------------
# Epoch 48: train loss 0.6864, test loss 0.6980, train accuracy 0.5396, test accuracy 0.5000
# -------------------
# Epoch 49: train loss 0.6859, test loss 0.6947, train accuracy 0.5386, test accuracy 0.4980

# %% [markdown]
# ### Adding when it is a blink or not

# %%
import numpy as np
import random

CLOSED_EYES_FRAME = 3
BLINK_THRESHOLD = 5.5

input_list_T = []
input_list_F = []
output_list_T = []
output_list_F = []

loop = 1
for file_path in glob.glob(SAVE_NPY_PATH+"/*", recursive = True):
  # Y Value
  output = truthfulness[Path(file_path).stem]

  # X Value
  array = np.load(file_path)

  ## Filter to just eye landmarks
  right_eye_landmarks = array[:, RIGHT_EYE, :]
  left_eye_landmarks = array[:, LEFT_EYE, :]
  combined_landmarks = np.concatenate((right_eye_landmarks, left_eye_landmarks), axis=1)

  ratioarray = blinkRatio(right_eye_landmarks, left_eye_landmarks)

  combined_array = add_dimension(combined_landmarks, ratioarray)

  print("Combined Array shape:", combined_array.shape)

  CEF_COUNTER = 0 #counter to track the number of consecutive frames in which a person's eyes are detected as closed
  TOTAL_BLINKS = 0
  blink_events = []

  # Assume ratioarray is an array containing the blink ratio for each frame
  for ratio in ratioarray:
      if ratio > BLINK_THRESHOLD: # If a frame blink ratio is above a threshold, the frame represents a blink event
          CEF_COUNTER += 1
          # Mark the frame as a blink frame
          blink_events.append(1)
      else:
          if CEF_COUNTER > CLOSED_EYES_FRAME: # If a frame blink ratio is below a threshold, the frame represents a blink event
              TOTAL_BLINKS += 1
              CEF_COUNTER = 0
          # Mark the frame as a non-blink frame
          blink_events.append(0)

  # After processing all ratios, if there are still frames at the end of the loop with closed eyes, they are counted as a blink
  if CEF_COUNTER > CLOSED_EYES_FRAME:
      TOTAL_BLINKS += 1


  # Convert blink_events to a numpy array
  blink_array = np.array(blink_events)
  print("Blink Array Shape",blink_array.shape)

  combined_array = add_dimension(combined_array, blink_array)
  print("Blink Array Combined Shape",combined_array.shape)

  array = combined_array.reshape(240, -1)
  print("Reshaped Array:",array.shape)
  array = npy_to_npychunks(array)
  print("Chunk Array",array.shape)
  num_chunks = array.shape[0]

  if output == 1:
    input_list_T.append(array)
    output_list_T += [output]*num_chunks
  else:
    input_list_F.append(array)
    output_list_F += [output]*num_chunks
  print(f"# of Videos Processed: {loop}")
  print("\n")
  loop += 1


X_T = np.vstack(input_list_T)
X_F = np.vstack(input_list_F)
Y_T = np.array(output_list_T).reshape(-1,1)
Y_F = np.array(output_list_F).reshape(-1,1)



X_T = torch.from_numpy(X_T).to(device)
X_F = torch.from_numpy(X_F).to(device)
Y_T = torch.from_numpy(Y_T).to(device)
Y_F = torch.from_numpy(Y_F).to(device)

X_T = X_T.float()
X_F = X_F.float()
Y_T = Y_T.float()
Y_F = Y_F.float()

print("X_T.shape", X_T.shape)
print("X_F.shape", X_F.shape)
print("Y_T.shape", Y_T.shape)
print("Y_F.shape", Y_F.shape)
# Out:
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 1
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 2
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 3
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 4
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 5
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 6
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 7
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 8
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 9
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 10
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 11
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 12
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 13
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 14
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 15
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 16
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 17
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 18
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 19
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 20
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 21
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 22
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 23
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 24
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 25
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 26
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 27
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 28
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 29
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 30
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 31
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 32
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 33
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 34
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 35
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 36
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 37
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 38
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 39
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 40
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 41
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 42
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 43
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 44
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 45
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 46
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 47
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 48
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 49
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 50
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 51
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 52
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 53
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 54
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 55
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 56
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 57
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 58
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 59
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 60
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 61
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 62
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 63
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 64
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 65
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 66
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 67
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 68
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 69
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 70
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 71
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 72
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 73
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 74
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 75
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 76
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 77
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 78
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 79
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 80
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 81
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 82
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 83
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 84
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 85
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 86
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 87
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 88
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 89
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 90
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 91
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 92
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 93
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 94
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 95
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 96
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 97
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 98
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 99
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 100
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 101
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 102
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 103
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 104
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 105
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 106
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 107
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 108
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 109
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 110
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 111
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 112
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 113
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 114
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 115
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 116
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 117
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 118
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 119
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 120
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 121
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 122
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 123
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 124
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 125
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 126
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 127
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 128
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 129
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 130
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 131
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 132
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 133
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 134
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 135
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 136
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 137
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 138
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 139
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 140
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 141
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 142
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 143
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 144
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 145
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 146
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 147
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 148
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 149
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 150
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 151
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 152
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 153
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 154
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 155
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 156
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 157
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 158
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 159
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 160
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 161
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 162
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 163
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 164
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 165
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 166
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 167
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 168
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 169
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 170
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 171
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 172
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 173
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 174
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 175
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 176
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 177
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 178
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 179
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 180
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 181
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 182
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 183
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 184
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 185
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 186
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 187
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 188
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 189
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 190
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 191
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 192
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 193
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 194
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 195
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 196
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 197
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 198
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 199
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 200
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 201
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 202
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 203
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 204
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 205
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 206
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 207
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 208
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 209
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 210
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 211
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 212
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 213
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 214
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 215
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 216
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 217
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 218
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 219
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 220
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 221
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 222
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 223
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 224
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 225
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 226
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 227
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 228
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 229
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 230
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 231
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 232
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 233
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 234
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 235
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 236
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 237
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 238
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 239
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 240
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 241
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 242
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 243
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 244
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 245
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 246
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 247
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 248
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 249
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 250
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 251
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 252
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 253
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 254
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 255
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 256
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 257
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 258
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 259
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 260
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 261
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 262
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 263
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 264
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 265
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 266
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 267
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 268
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 269
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 270
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 271
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 272
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 273
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 274
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 275
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 276
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 277
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 278
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 279
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 280
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 281
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 282
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 283
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 284
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 285
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 286
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 287
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 288
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 289
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 290
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 291
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 292
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 293
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 294
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 295
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 296
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 297
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 298
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 299
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 300
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 301
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 302
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 303
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 304
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 305
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 306
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 307
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 308
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 309
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 310
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 311
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 312
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 313
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 314
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 315
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 316
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 317
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 318
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 319
#
#
# Combined Array shape: (240, 32, 3)
# Blink Array Shape (240,)
# Blink Array Combined Shape (240, 32, 4)
# Reshaped Array: (240, 128)
# Chunk Array (8, 30, 128)
# # of Videos Processed: 320
#
#
# X_T.shape torch.Size([1280, 30, 128])
# X_F.shape torch.Size([1280, 30, 128])
# Y_T.shape torch.Size([1280, 1])
# Y_F.shape torch.Size([1280, 1])

# %%
import torch.utils.data as data

# Split the shuffled data into 80% Training, 20% Testing
train_dataset_T, val_dataset_T = torch.utils.data.random_split(data.TensorDataset(X_T, Y_T), [0.8, 0.2])
train_dataset_F, val_dataset_F = torch.utils.data.random_split(data.TensorDataset(X_F, Y_F), [0.8, 0.2])

train_dataset = data.ConcatDataset([train_dataset_T, train_dataset_F])
val_dataset = data.ConcatDataset([val_dataset_T, val_dataset_F])

print("Training Dataset Size:", len(train_dataset))
print("Testing Dataset Size:", len(val_dataset))
print()

train_loader = data.DataLoader(train_dataset, batch_size=50, shuffle=True)

total_train_samples = len(train_dataset)
count_train_ones = sum(1 for _, label in train_dataset if label == 1)
percentage_train_ones = (count_train_ones / total_train_samples) * 100
print("Percentage of Y that are Truths in train_dataset:", percentage_train_ones)


test_loader = data.DataLoader(val_dataset, batch_size=1, shuffle=False)

total_val_samples = len(val_dataset)
count_val_ones = sum(1 for _, label in val_dataset if label == 1)
percentage_val_ones = (count_val_ones / total_val_samples) * 100
print("Percentage of Y that are Truths in val_dataset:", percentage_val_ones)


X_train_all = []
Y_train_all = []


# Iterate over the train_loader to accumulate the entire dataset
for X_train, Y_train in train_loader:
    X_train_all.append(X_train)
    Y_train_all.append(Y_train)

X_test_all = []
Y_test_all = []

for X_test, Y_test in test_loader:
    X_test_all.append(X_test)
    Y_test_all.append(Y_test)

X_test_all = torch.cat(X_test_all, dim=0).to(device)
Y_test_all = torch.cat(Y_test_all, dim=0).to(device)

X_train_all = torch.cat(X_train_all, dim=0).to(device)
Y_train_all = torch.cat(Y_train_all, dim=0).to(device)
# Out:
# Training Dataset Size: 2048
# Testing Dataset Size: 512
#
# Percentage of Y that are Truths in train_dataset: 50.0
# Percentage of Y that are Truths in val_dataset: 50.0

# %%
import torch.utils.data as data
import matplotlib.pyplot as plt

# Lists to store training and test losses for each epoch
train_losses = []
test_losses = []

# Function to calculate accuracy
def accuracy(outputs, labels):
  preds = torch.round(outputs)
  return torch.tensor(torch.sum(preds == labels).item() / len(preds))


criterion = nn.BCELoss()
model = LSTMModel(input_dim=956, hidden_dim=200, layer_num=1, output_dim=1)
model = model.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

num_epochs = 100

# Training loop
for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0.0
    epoch_acc = 0.0
    for X_batch, y_batch in train_loader:
        y_pred = model(X_batch)
        loss = criterion(y_pred, y_batch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    model.eval()
    with torch.no_grad():
        print("-------------------")
        # Calculate accuracy on training set
        y_pred = model(X_train_all)
        train_loss = criterion(y_pred, Y_train_all)
        train_acc = accuracy(y_pred, Y_train_all)

        # Calculate accuracy on test set
        y_pred = model(X_test_all)
        test_loss = criterion(y_pred, Y_test_all)

        test_acc = accuracy(y_pred, Y_test_all)

    print("Epoch %d: train loss %.4f, test loss %.4f, train accuracy %.4f, test accuracy %.4f" % (epoch, train_loss, test_loss, train_acc, test_acc))

    # Append the losses to the lists
    train_losses.append(train_loss)
    test_losses.append(test_loss)

# Smooth the losses using a moving average
window_size = 5
train_losses_smoothed = np.convolve(train_losses, np.ones(window_size) / window_size, mode='valid')
test_losses_smoothed = np.convolve(test_losses, np.ones(window_size) / window_size, mode='valid')

# Plotting epoch vs training loss and test loss
epochs = range(window_size // 2 + 1, num_epochs - window_size // 2 + 1)
plt.plot(epochs, train_losses_smoothed, label='Train Loss')
plt.plot(epochs, test_losses_smoothed, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Epoch vs Loss (Smoothed)')
plt.legend()
plt.show()
# Out:
# -------------------
# Epoch 0: train loss 0.6935, test loss 0.6937, train accuracy 0.5020, test accuracy 0.4941
# -------------------
# Epoch 1: train loss 0.6928, test loss 0.6926, train accuracy 0.5073, test accuracy 0.5176
# -------------------
# Epoch 2: train loss 0.6925, test loss 0.6931, train accuracy 0.5093, test accuracy 0.5176
# -------------------
# Epoch 3: train loss 0.6937, test loss 0.6941, train accuracy 0.5029, test accuracy 0.4941
# -------------------
# Epoch 4: train loss 0.6926, test loss 0.6932, train accuracy 0.5083, test accuracy 0.5059
# -------------------
# Epoch 5: train loss 0.6931, test loss 0.6939, train accuracy 0.5005, test accuracy 0.5000
# -------------------
# Epoch 6: train loss 0.6919, test loss 0.6929, train accuracy 0.5186, test accuracy 0.5078
# -------------------
# Epoch 7: train loss 0.6918, test loss 0.6927, train accuracy 0.5122, test accuracy 0.5195
# -------------------
# Epoch 8: train loss 0.6918, test loss 0.6935, train accuracy 0.5146, test accuracy 0.5117
# -------------------
# Epoch 9: train loss 0.6916, test loss 0.6930, train accuracy 0.5195, test accuracy 0.4980
# -------------------
# Epoch 10: train loss 0.6920, test loss 0.6944, train accuracy 0.5020, test accuracy 0.5059
# -------------------
# Epoch 11: train loss 0.6917, test loss 0.6947, train accuracy 0.5166, test accuracy 0.5020
# -------------------
# Epoch 12: train loss 0.6918, test loss 0.6944, train accuracy 0.5073, test accuracy 0.4863
# -------------------
# Epoch 13: train loss 0.6920, test loss 0.6933, train accuracy 0.5078, test accuracy 0.4961
# -------------------
# Epoch 14: train loss 0.6912, test loss 0.6934, train accuracy 0.5273, test accuracy 0.5059
# -------------------
# Epoch 15: train loss 0.6920, test loss 0.6942, train accuracy 0.5103, test accuracy 0.4961
# -------------------
# Epoch 16: train loss 0.6917, test loss 0.6944, train accuracy 0.5117, test accuracy 0.4922
# -------------------
# Epoch 17: train loss 0.6943, test loss 0.6978, train accuracy 0.5049, test accuracy 0.5020
# -------------------
# Epoch 18: train loss 0.6911, test loss 0.6933, train accuracy 0.5205, test accuracy 0.5000
# -------------------
# Epoch 19: train loss 0.6909, test loss 0.6946, train accuracy 0.5225, test accuracy 0.4980
# -------------------
# Epoch 20: train loss 0.6908, test loss 0.6937, train accuracy 0.5337, test accuracy 0.4902
# -------------------
# Epoch 21: train loss 0.6923, test loss 0.6967, train accuracy 0.5093, test accuracy 0.4961
# -------------------
# Epoch 22: train loss 0.6905, test loss 0.6943, train accuracy 0.5347, test accuracy 0.4922
# -------------------
# Epoch 23: train loss 0.6912, test loss 0.6954, train accuracy 0.5078, test accuracy 0.5000
# -------------------
# Epoch 24: train loss 0.6906, test loss 0.6948, train accuracy 0.5269, test accuracy 0.4902
# -------------------
# Epoch 25: train loss 0.6902, test loss 0.6946, train accuracy 0.5322, test accuracy 0.4844
# -------------------
# Epoch 26: train loss 0.6905, test loss 0.6954, train accuracy 0.5088, test accuracy 0.5039
# -------------------
# Epoch 27: train loss 0.6910, test loss 0.6943, train accuracy 0.5181, test accuracy 0.4961
# -------------------
# Epoch 28: train loss 0.6900, test loss 0.6943, train accuracy 0.5332, test accuracy 0.4863
# -------------------
# Epoch 29: train loss 0.6901, test loss 0.6947, train accuracy 0.5327, test accuracy 0.4883
# -------------------
# Epoch 30: train loss 0.6897, test loss 0.6945, train accuracy 0.5137, test accuracy 0.5059
# -------------------
# Epoch 31: train loss 0.6903, test loss 0.6943, train accuracy 0.5171, test accuracy 0.4980
# -------------------
# Epoch 32: train loss 0.6894, test loss 0.6948, train accuracy 0.5327, test accuracy 0.4980
# -------------------
# Epoch 33: train loss 0.6907, test loss 0.6977, train accuracy 0.5132, test accuracy 0.4883
# -------------------
# Epoch 34: train loss 0.6893, test loss 0.6954, train accuracy 0.5327, test accuracy 0.5020
# -------------------
# Epoch 35: train loss 0.6890, test loss 0.6953, train accuracy 0.5410, test accuracy 0.5000
# -------------------
# Epoch 36: train loss 0.6896, test loss 0.6954, train accuracy 0.5269, test accuracy 0.4980
# -------------------
# Epoch 37: train loss 0.6889, test loss 0.6948, train accuracy 0.5391, test accuracy 0.5176
# -------------------
# Epoch 38: train loss 0.6899, test loss 0.6953, train accuracy 0.5195, test accuracy 0.5098
# -------------------
# Epoch 39: train loss 0.6883, test loss 0.6941, train accuracy 0.5518, test accuracy 0.5000
# -------------------
# Epoch 40: train loss 0.6882, test loss 0.6937, train accuracy 0.5454, test accuracy 0.5020
# -------------------
# Epoch 41: train loss 0.6882, test loss 0.6937, train accuracy 0.5444, test accuracy 0.5078
# -------------------
# Epoch 42: train loss 0.6875, test loss 0.6938, train accuracy 0.5552, test accuracy 0.5059
# -------------------
# Epoch 43: train loss 0.6872, test loss 0.6936, train accuracy 0.5425, test accuracy 0.5117
# -------------------
# Epoch 44: train loss 0.6868, test loss 0.6935, train accuracy 0.5581, test accuracy 0.4961
# -------------------
# Epoch 45: train loss 0.6866, test loss 0.6942, train accuracy 0.5488, test accuracy 0.4883
# -------------------
# Epoch 46: train loss 0.6866, test loss 0.6946, train accuracy 0.5322, test accuracy 0.5195
# -------------------
# Epoch 47: train loss 0.6871, test loss 0.6944, train accuracy 0.5444, test accuracy 0.4961
# -------------------
# Epoch 48: train loss 0.6862, test loss 0.6936, train accuracy 0.5562, test accuracy 0.5156
# -------------------
# Epoch 49: train loss 0.6862, test loss 0.6951, train accuracy 0.5459, test accuracy 0.4883
# -------------------
# Epoch 50: train loss 0.6849, test loss 0.6931, train accuracy 0.5562, test accuracy 0.5156
# -------------------
# Epoch 51: train loss 0.6848, test loss 0.6942, train accuracy 0.5586, test accuracy 0.5234
# -------------------
# Epoch 52: train loss 0.6868, test loss 0.6919, train accuracy 0.5366, test accuracy 0.5078
# -------------------
# Epoch 53: train loss 0.6871, test loss 0.6998, train accuracy 0.5430, test accuracy 0.5059
# -------------------
# Epoch 54: train loss 0.6851, test loss 0.6968, train accuracy 0.5391, test accuracy 0.5176
# -------------------
# Epoch 55: train loss 0.6864, test loss 0.6948, train accuracy 0.5498, test accuracy 0.4980
# -------------------
# Epoch 56: train loss 0.6844, test loss 0.6960, train accuracy 0.5435, test accuracy 0.5117
# -------------------
# Epoch 57: train loss 0.6830, test loss 0.6948, train accuracy 0.5498, test accuracy 0.5020
# -------------------
# Epoch 58: train loss 0.6835, test loss 0.6944, train accuracy 0.5625, test accuracy 0.5117
# -------------------
# Epoch 59: train loss 0.6825, test loss 0.6956, train accuracy 0.5474, test accuracy 0.5195
# -------------------
# Epoch 60: train loss 0.6815, test loss 0.6966, train accuracy 0.5552, test accuracy 0.5195
# -------------------
# Epoch 61: train loss 0.6803, test loss 0.6948, train accuracy 0.5728, test accuracy 0.5156
# -------------------
# Epoch 62: train loss 0.6809, test loss 0.6957, train accuracy 0.5640, test accuracy 0.4883
# -------------------
# Epoch 63: train loss 0.6796, test loss 0.6975, train accuracy 0.5605, test accuracy 0.5312
# -------------------
# Epoch 64: train loss 0.6778, test loss 0.6995, train accuracy 0.5703, test accuracy 0.5059
# -------------------
# Epoch 65: train loss 0.6786, test loss 0.6977, train accuracy 0.5718, test accuracy 0.5020
# -------------------
# Epoch 66: train loss 0.6779, test loss 0.6976, train accuracy 0.5757, test accuracy 0.5020
# -------------------
# Epoch 67: train loss 0.6775, test loss 0.6987, train accuracy 0.5732, test accuracy 0.5156
# -------------------
# Epoch 68: train loss 0.6759, test loss 0.6994, train accuracy 0.5708, test accuracy 0.5156
# -------------------
# Epoch 69: train loss 0.6740, test loss 0.6980, train accuracy 0.5796, test accuracy 0.5195
# -------------------
# Epoch 70: train loss 0.6745, test loss 0.6969, train accuracy 0.5747, test accuracy 0.5371
# -------------------
# Epoch 71: train loss 0.6738, test loss 0.7010, train accuracy 0.5742, test accuracy 0.5156
# -------------------
# Epoch 72: train loss 0.6710, test loss 0.7031, train accuracy 0.5811, test accuracy 0.5039
# -------------------
# Epoch 73: train loss 0.6714, test loss 0.7047, train accuracy 0.5698, test accuracy 0.5059
# -------------------
# Epoch 74: train loss 0.6697, test loss 0.7030, train accuracy 0.5757, test accuracy 0.5020
# -------------------
# Epoch 75: train loss 0.6794, test loss 0.6980, train accuracy 0.5547, test accuracy 0.5273
# -------------------
# Epoch 76: train loss 0.6683, test loss 0.7046, train accuracy 0.5771, test accuracy 0.5020
# -------------------
# Epoch 77: train loss 0.6692, test loss 0.7018, train accuracy 0.5825, test accuracy 0.5273
# -------------------
# Epoch 78: train loss 0.6671, test loss 0.7025, train accuracy 0.5869, test accuracy 0.4941
# -------------------
# Epoch 79: train loss 0.6680, test loss 0.7012, train accuracy 0.5859, test accuracy 0.5195
# -------------------
# Epoch 80: train loss 0.6737, test loss 0.7100, train accuracy 0.5757, test accuracy 0.5039
# -------------------
# Epoch 81: train loss 0.6641, test loss 0.7016, train accuracy 0.5942, test accuracy 0.5273
# -------------------
# Epoch 82: train loss 0.6691, test loss 0.7025, train accuracy 0.5830, test accuracy 0.5195
# -------------------
# Epoch 83: train loss 0.6623, test loss 0.7051, train accuracy 0.5854, test accuracy 0.4902
# -------------------
# Epoch 84: train loss 0.6619, test loss 0.7047, train accuracy 0.5977, test accuracy 0.5117
# -------------------
# Epoch 85: train loss 0.6620, test loss 0.7035, train accuracy 0.5942, test accuracy 0.4961
# -------------------
# Epoch 86: train loss 0.6662, test loss 0.7012, train accuracy 0.5835, test accuracy 0.5312
# -------------------
# Epoch 87: train loss 0.6632, test loss 0.7040, train accuracy 0.5986, test accuracy 0.5234
# -------------------
# Epoch 88: train loss 0.6600, test loss 0.7055, train accuracy 0.5957, test accuracy 0.5059
# -------------------
# Epoch 89: train loss 0.6587, test loss 0.7047, train accuracy 0.6030, test accuracy 0.5039
# -------------------
# Epoch 90: train loss 0.6582, test loss 0.7103, train accuracy 0.5996, test accuracy 0.5195
# -------------------
# Epoch 91: train loss 0.6562, test loss 0.7079, train accuracy 0.6045, test accuracy 0.4941
# -------------------
# Epoch 92: train loss 0.6569, test loss 0.7073, train accuracy 0.6064, test accuracy 0.5020
# -------------------
# Epoch 93: train loss 0.6543, test loss 0.7173, train accuracy 0.5938, test accuracy 0.5176
# -------------------
# Epoch 94: train loss 0.6527, test loss 0.7078, train accuracy 0.6064, test accuracy 0.5234
# -------------------
# Epoch 95: train loss 0.6541, test loss 0.7143, train accuracy 0.6079, test accuracy 0.5059
# -------------------
# Epoch 96: train loss 0.6484, test loss 0.7118, train accuracy 0.6123, test accuracy 0.5156
# -------------------
# Epoch 97: train loss 0.6626, test loss 0.7043, train accuracy 0.6001, test accuracy 0.5098
# -------------------
# Epoch 98: train loss 0.6482, test loss 0.7119, train accuracy 0.6143, test accuracy 0.5273
# -------------------
# Epoch 99: train loss 0.6545, test loss 0.7147, train accuracy 0.6128, test accuracy 0.5020

# %%
import torch.utils.data as data
import matplotlib.pyplot as plt

# Lists to store training and test losses for each epoch
train_losses = []
test_losses = []

# Function to calculate accuracy
def accuracy(outputs, labels):
  preds = torch.round(outputs)
  return torch.tensor(torch.sum(preds == labels).item() / len(preds))


criterion = nn.BCELoss()
model = LSTMModel(input_dim=956, hidden_dim=200, layer_num=1, output_dim=1)
model = model.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

num_epochs = 150

# Training loop
for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0.0
    epoch_acc = 0.0
    for X_batch, y_batch in train_loader:
        y_pred = model(X_batch)
        loss = criterion(y_pred, y_batch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    model.eval()
    with torch.no_grad():
        print("-------------------")
        # Calculate accuracy on training set
        y_pred = model(X_train_all)
        train_loss = criterion(y_pred, Y_train_all)
        train_acc = accuracy(y_pred, Y_train_all)

        # Calculate accuracy on test set
        y_pred = model(X_test_all)
        test_loss = criterion(y_pred, Y_test_all)

        test_acc = accuracy(y_pred, Y_test_all)

    print("Epoch %d: train loss %.4f, test loss %.4f, train accuracy %.4f, test accuracy %.4f" % (epoch, train_loss, test_loss, train_acc, test_acc))

    # Append the losses to the lists
    train_losses.append(train_loss)
    test_losses.append(test_loss)

# Smooth the losses using a moving average
window_size = 5
train_losses_smoothed = np.convolve(train_losses, np.ones(window_size) / window_size, mode='valid')
test_losses_smoothed = np.convolve(test_losses, np.ones(window_size) / window_size, mode='valid')

# Plotting epoch vs training loss and test loss
epochs = range(window_size // 2 + 1, num_epochs - window_size // 2 + 1)
plt.plot(epochs, train_losses_smoothed, label='Train Loss')
plt.plot(epochs, test_losses_smoothed, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Epoch vs Loss (Smoothed)')
plt.legend()
plt.show()
# Out:
# -------------------
# Epoch 0: train loss 0.6930, test loss 0.6922, train accuracy 0.5000, test accuracy 0.5059
# -------------------
# Epoch 1: train loss 0.6931, test loss 0.6934, train accuracy 0.5015, test accuracy 0.4902
# -------------------
# Epoch 2: train loss 0.6937, test loss 0.6949, train accuracy 0.5039, test accuracy 0.5039
# -------------------
# Epoch 3: train loss 0.6931, test loss 0.6928, train accuracy 0.5044, test accuracy 0.5156
# -------------------
# Epoch 4: train loss 0.6924, test loss 0.6932, train accuracy 0.5132, test accuracy 0.5098
# -------------------
# Epoch 5: train loss 0.6923, test loss 0.6924, train accuracy 0.5195, test accuracy 0.5488
# -------------------
# Epoch 6: train loss 0.6922, test loss 0.6921, train accuracy 0.5078, test accuracy 0.5332
# -------------------
# Epoch 7: train loss 0.6928, test loss 0.6933, train accuracy 0.5049, test accuracy 0.4941
# -------------------
# Epoch 8: train loss 0.6924, test loss 0.6930, train accuracy 0.5103, test accuracy 0.5117
# -------------------
# Epoch 9: train loss 0.6919, test loss 0.6922, train accuracy 0.5137, test accuracy 0.5234
# -------------------
# Epoch 10: train loss 0.6920, test loss 0.6935, train accuracy 0.5083, test accuracy 0.5098
# -------------------
# Epoch 11: train loss 0.6917, test loss 0.6940, train accuracy 0.5171, test accuracy 0.4922
# -------------------
# Epoch 12: train loss 0.6912, test loss 0.6933, train accuracy 0.5303, test accuracy 0.5020
# -------------------
# Epoch 13: train loss 0.6927, test loss 0.6943, train accuracy 0.5068, test accuracy 0.4941
# -------------------
# Epoch 14: train loss 0.6911, test loss 0.6933, train accuracy 0.5215, test accuracy 0.5039
# -------------------
# Epoch 15: train loss 0.6915, test loss 0.6930, train accuracy 0.5151, test accuracy 0.5117
# -------------------
# Epoch 16: train loss 0.6929, test loss 0.6958, train accuracy 0.5049, test accuracy 0.5000
# -------------------
# Epoch 17: train loss 0.6913, test loss 0.6938, train accuracy 0.5151, test accuracy 0.4824
# -------------------
# Epoch 18: train loss 0.6908, test loss 0.6932, train accuracy 0.5264, test accuracy 0.5059
# -------------------
# Epoch 19: train loss 0.6906, test loss 0.6947, train accuracy 0.5229, test accuracy 0.5098
# -------------------
# Epoch 20: train loss 0.6912, test loss 0.6938, train accuracy 0.5166, test accuracy 0.4902
# -------------------
# Epoch 21: train loss 0.6912, test loss 0.6943, train accuracy 0.5112, test accuracy 0.4941
# -------------------
# Epoch 22: train loss 0.6902, test loss 0.6948, train accuracy 0.5249, test accuracy 0.5059
# -------------------
# Epoch 23: train loss 0.6899, test loss 0.6941, train accuracy 0.5322, test accuracy 0.4922
# -------------------
# Epoch 24: train loss 0.6929, test loss 0.6991, train accuracy 0.5098, test accuracy 0.4980
# -------------------
# Epoch 25: train loss 0.6898, test loss 0.6935, train accuracy 0.5386, test accuracy 0.5078
# -------------------
# Epoch 26: train loss 0.6907, test loss 0.6959, train accuracy 0.5078, test accuracy 0.4980
# -------------------
# Epoch 27: train loss 0.6896, test loss 0.6935, train accuracy 0.5327, test accuracy 0.5098
# -------------------
# Epoch 28: train loss 0.6892, test loss 0.6937, train accuracy 0.5547, test accuracy 0.5195
# -------------------
# Epoch 29: train loss 0.6889, test loss 0.6940, train accuracy 0.5503, test accuracy 0.5039
# -------------------
# Epoch 30: train loss 0.6889, test loss 0.6933, train accuracy 0.5532, test accuracy 0.5078
# -------------------
# Epoch 31: train loss 0.6924, test loss 0.6985, train accuracy 0.5098, test accuracy 0.4922
# -------------------
# Epoch 32: train loss 0.6902, test loss 0.6934, train accuracy 0.5200, test accuracy 0.5098
# -------------------
# Epoch 33: train loss 0.6888, test loss 0.6934, train accuracy 0.5454, test accuracy 0.5020
# -------------------
# Epoch 34: train loss 0.6881, test loss 0.6933, train accuracy 0.5503, test accuracy 0.4980
# -------------------
# Epoch 35: train loss 0.6880, test loss 0.6934, train accuracy 0.5332, test accuracy 0.5234
# -------------------
# Epoch 36: train loss 0.6873, test loss 0.6936, train accuracy 0.5361, test accuracy 0.5176
# -------------------
# Epoch 37: train loss 0.6893, test loss 0.6961, train accuracy 0.5151, test accuracy 0.4980
# -------------------
# Epoch 38: train loss 0.6873, test loss 0.6931, train accuracy 0.5474, test accuracy 0.5117
# -------------------
# Epoch 39: train loss 0.6891, test loss 0.6951, train accuracy 0.5269, test accuracy 0.5000
# -------------------
# Epoch 40: train loss 0.6871, test loss 0.6933, train accuracy 0.5508, test accuracy 0.5020
# -------------------
# Epoch 41: train loss 0.6865, test loss 0.6934, train accuracy 0.5381, test accuracy 0.5137
# -------------------
# Epoch 42: train loss 0.6888, test loss 0.6951, train accuracy 0.5176, test accuracy 0.5039
# -------------------
# Epoch 43: train loss 0.6858, test loss 0.6924, train accuracy 0.5591, test accuracy 0.5273
# -------------------
# Epoch 44: train loss 0.6876, test loss 0.6950, train accuracy 0.5386, test accuracy 0.5020
# -------------------
# Epoch 45: train loss 0.6856, test loss 0.6936, train accuracy 0.5591, test accuracy 0.5137
# -------------------
# Epoch 46: train loss 0.6852, test loss 0.6943, train accuracy 0.5586, test accuracy 0.5176
# -------------------
# Epoch 47: train loss 0.6854, test loss 0.6942, train accuracy 0.5503, test accuracy 0.5176
# -------------------
# Epoch 48: train loss 0.6844, test loss 0.6933, train accuracy 0.5557, test accuracy 0.5254
# -------------------
# Epoch 49: train loss 0.6847, test loss 0.6932, train accuracy 0.5591, test accuracy 0.5000
# -------------------
# Epoch 50: train loss 0.6836, test loss 0.6932, train accuracy 0.5532, test accuracy 0.5273
# -------------------
# Epoch 51: train loss 0.6846, test loss 0.6940, train accuracy 0.5581, test accuracy 0.5117
# -------------------
# Epoch 52: train loss 0.6837, test loss 0.6937, train accuracy 0.5605, test accuracy 0.5117
# -------------------
# Epoch 53: train loss 0.6837, test loss 0.6945, train accuracy 0.5566, test accuracy 0.5156
# -------------------
# Epoch 54: train loss 0.6870, test loss 0.6972, train accuracy 0.5474, test accuracy 0.4922
# -------------------
# Epoch 55: train loss 0.6827, test loss 0.6937, train accuracy 0.5645, test accuracy 0.5273
# -------------------
# Epoch 56: train loss 0.6833, test loss 0.6932, train accuracy 0.5625, test accuracy 0.5156
# -------------------
# Epoch 57: train loss 0.6850, test loss 0.6946, train accuracy 0.5518, test accuracy 0.4902
# -------------------
# Epoch 58: train loss 0.6826, test loss 0.6951, train accuracy 0.5601, test accuracy 0.5000
# -------------------
# Epoch 59: train loss 0.6814, test loss 0.6934, train accuracy 0.5596, test accuracy 0.5234
# -------------------
# Epoch 60: train loss 0.6822, test loss 0.6946, train accuracy 0.5552, test accuracy 0.5117
# -------------------
# Epoch 61: train loss 0.6817, test loss 0.6969, train accuracy 0.5527, test accuracy 0.5117
# -------------------
# Epoch 62: train loss 0.6808, test loss 0.6939, train accuracy 0.5640, test accuracy 0.5098
# -------------------
# Epoch 63: train loss 0.6799, test loss 0.6951, train accuracy 0.5605, test accuracy 0.4863
# -------------------
# Epoch 64: train loss 0.6800, test loss 0.6926, train accuracy 0.5640, test accuracy 0.5352
# -------------------
# Epoch 65: train loss 0.6792, test loss 0.6948, train accuracy 0.5605, test accuracy 0.4980
# -------------------
# Epoch 66: train loss 0.6788, test loss 0.6949, train accuracy 0.5581, test accuracy 0.5156
# -------------------
# Epoch 67: train loss 0.6818, test loss 0.6984, train accuracy 0.5527, test accuracy 0.4980
# -------------------
# Epoch 68: train loss 0.6803, test loss 0.6979, train accuracy 0.5532, test accuracy 0.5098
# -------------------
# Epoch 69: train loss 0.6795, test loss 0.6969, train accuracy 0.5571, test accuracy 0.5293
# -------------------
# Epoch 70: train loss 0.6785, test loss 0.6946, train accuracy 0.5669, test accuracy 0.5098
# -------------------
# Epoch 71: train loss 0.6768, test loss 0.6961, train accuracy 0.5645, test accuracy 0.4922
# -------------------
# Epoch 72: train loss 0.6758, test loss 0.6956, train accuracy 0.5742, test accuracy 0.4922
# -------------------
# Epoch 73: train loss 0.6757, test loss 0.6945, train accuracy 0.5659, test accuracy 0.5098
# -------------------
# Epoch 74: train loss 0.6769, test loss 0.6977, train accuracy 0.5723, test accuracy 0.5098
# -------------------
# Epoch 75: train loss 0.6744, test loss 0.6948, train accuracy 0.5781, test accuracy 0.5059
# -------------------
# Epoch 76: train loss 0.6738, test loss 0.6957, train accuracy 0.5801, test accuracy 0.5039
# -------------------
# Epoch 77: train loss 0.6763, test loss 0.6958, train accuracy 0.5664, test accuracy 0.5059
# -------------------
# Epoch 78: train loss 0.6744, test loss 0.6929, train accuracy 0.5703, test accuracy 0.5215
# -------------------
# Epoch 79: train loss 0.6709, test loss 0.6925, train accuracy 0.5825, test accuracy 0.5410
# -------------------
# Epoch 80: train loss 0.6710, test loss 0.6951, train accuracy 0.5859, test accuracy 0.5098
# -------------------
# Epoch 81: train loss 0.6695, test loss 0.6974, train accuracy 0.5762, test accuracy 0.5098
# -------------------
# Epoch 82: train loss 0.6693, test loss 0.6995, train accuracy 0.5840, test accuracy 0.5000
# -------------------
# Epoch 83: train loss 0.6673, test loss 0.7007, train accuracy 0.5835, test accuracy 0.5156
# -------------------
# Epoch 84: train loss 0.6693, test loss 0.6953, train accuracy 0.5757, test accuracy 0.5176
# -------------------
# Epoch 85: train loss 0.6658, test loss 0.7021, train accuracy 0.5903, test accuracy 0.5059
# -------------------
# Epoch 86: train loss 0.6634, test loss 0.6981, train accuracy 0.5938, test accuracy 0.5137
# -------------------
# Epoch 87: train loss 0.6662, test loss 0.7013, train accuracy 0.5830, test accuracy 0.5078
# -------------------
# Epoch 88: train loss 0.6661, test loss 0.6995, train accuracy 0.5815, test accuracy 0.4980
# -------------------
# Epoch 89: train loss 0.6623, test loss 0.7022, train accuracy 0.5981, test accuracy 0.5059
# -------------------
# Epoch 90: train loss 0.6620, test loss 0.6984, train accuracy 0.5913, test accuracy 0.5254
# -------------------
# Epoch 91: train loss 0.6589, test loss 0.7058, train accuracy 0.5972, test accuracy 0.5059
# -------------------
# Epoch 92: train loss 0.6577, test loss 0.7081, train accuracy 0.6006, test accuracy 0.5039
# -------------------
# Epoch 93: train loss 0.6613, test loss 0.7025, train accuracy 0.5884, test accuracy 0.5078
# -------------------
# Epoch 94: train loss 0.6540, test loss 0.7024, train accuracy 0.6030, test accuracy 0.5078
# -------------------
# Epoch 95: train loss 0.6605, test loss 0.7127, train accuracy 0.5991, test accuracy 0.5020
# -------------------
# Epoch 96: train loss 0.6540, test loss 0.7103, train accuracy 0.6001, test accuracy 0.4707
# -------------------
# Epoch 97: train loss 0.6550, test loss 0.7121, train accuracy 0.6094, test accuracy 0.5195
# -------------------
# Epoch 98: train loss 0.6570, test loss 0.7065, train accuracy 0.6035, test accuracy 0.4961
# -------------------
# Epoch 99: train loss 0.6540, test loss 0.7146, train accuracy 0.6084, test accuracy 0.5020
# -------------------
# Epoch 100: train loss 0.6512, test loss 0.7055, train accuracy 0.6084, test accuracy 0.5254
# -------------------
# Epoch 101: train loss 0.6499, test loss 0.7034, train accuracy 0.6069, test accuracy 0.5195
# -------------------
# Epoch 102: train loss 0.6478, test loss 0.7108, train accuracy 0.6182, test accuracy 0.5137
# -------------------
# Epoch 103: train loss 0.6481, test loss 0.7121, train accuracy 0.6138, test accuracy 0.4922
# -------------------
# Epoch 104: train loss 0.6441, test loss 0.7104, train accuracy 0.6216, test accuracy 0.4863
# -------------------
# Epoch 105: train loss 0.6431, test loss 0.7098, train accuracy 0.6133, test accuracy 0.5098
# -------------------
# Epoch 106: train loss 0.6375, test loss 0.7137, train accuracy 0.6304, test accuracy 0.5195
# -------------------
# Epoch 107: train loss 0.6469, test loss 0.7156, train accuracy 0.6094, test accuracy 0.5059
# -------------------
# Epoch 108: train loss 0.6386, test loss 0.7226, train accuracy 0.6230, test accuracy 0.4805
# -------------------
# Epoch 109: train loss 0.6383, test loss 0.7209, train accuracy 0.6299, test accuracy 0.5195
# -------------------
# Epoch 110: train loss 0.6324, test loss 0.7172, train accuracy 0.6450, test accuracy 0.4941
# -------------------
# Epoch 111: train loss 0.6351, test loss 0.7253, train accuracy 0.6284, test accuracy 0.4883
# -------------------
# Epoch 112: train loss 0.6294, test loss 0.7256, train accuracy 0.6343, test accuracy 0.4922
# -------------------
# Epoch 113: train loss 0.6249, test loss 0.7243, train accuracy 0.6382, test accuracy 0.5215
# -------------------
# Epoch 114: train loss 0.6308, test loss 0.7359, train accuracy 0.6284, test accuracy 0.4844
# -------------------
# Epoch 115: train loss 0.6177, test loss 0.7299, train accuracy 0.6465, test accuracy 0.4922
# -------------------
# Epoch 116: train loss 0.6379, test loss 0.7612, train accuracy 0.6201, test accuracy 0.4980
# -------------------
# Epoch 117: train loss 0.6155, test loss 0.7341, train accuracy 0.6421, test accuracy 0.4961
# -------------------
# Epoch 118: train loss 0.6103, test loss 0.7345, train accuracy 0.6523, test accuracy 0.5332
# -------------------
# Epoch 119: train loss 0.6184, test loss 0.7410, train accuracy 0.6387, test accuracy 0.5352
# -------------------
# Epoch 120: train loss 0.6114, test loss 0.7411, train accuracy 0.6499, test accuracy 0.5156
# -------------------
# Epoch 121: train loss 0.6020, test loss 0.7407, train accuracy 0.6616, test accuracy 0.5273
# -------------------
# Epoch 122: train loss 0.5955, test loss 0.7498, train accuracy 0.6689, test accuracy 0.5117
# -------------------
# Epoch 123: train loss 0.5970, test loss 0.7662, train accuracy 0.6641, test accuracy 0.5098
# -------------------
# Epoch 124: train loss 0.6075, test loss 0.7618, train accuracy 0.6479, test accuracy 0.4922
# -------------------
# Epoch 125: train loss 0.5997, test loss 0.7544, train accuracy 0.6509, test accuracy 0.4883
# -------------------
# Epoch 126: train loss 0.5834, test loss 0.7658, train accuracy 0.6802, test accuracy 0.5137
# -------------------
# Epoch 127: train loss 0.5929, test loss 0.7754, train accuracy 0.6709, test accuracy 0.4805
# -------------------
# Epoch 128: train loss 0.5809, test loss 0.7680, train accuracy 0.6836, test accuracy 0.4980
# -------------------
# Epoch 129: train loss 0.5807, test loss 0.7739, train accuracy 0.6816, test accuracy 0.4922
# -------------------
# Epoch 130: train loss 0.5736, test loss 0.7859, train accuracy 0.6733, test accuracy 0.5020
# -------------------
# Epoch 131: train loss 0.5618, test loss 0.7855, train accuracy 0.7051, test accuracy 0.5137
# -------------------
# Epoch 132: train loss 0.5549, test loss 0.7870, train accuracy 0.7041, test accuracy 0.4902
# -------------------
# Epoch 133: train loss 0.5575, test loss 0.8086, train accuracy 0.7017, test accuracy 0.4883
# -------------------
# Epoch 134: train loss 0.5648, test loss 0.7947, train accuracy 0.6816, test accuracy 0.5137
# -------------------
# Epoch 135: train loss 0.5504, test loss 0.7993, train accuracy 0.7007, test accuracy 0.5039
# -------------------
# Epoch 136: train loss 0.5419, test loss 0.7974, train accuracy 0.7163, test accuracy 0.5059
# -------------------
# Epoch 137: train loss 0.5340, test loss 0.8003, train accuracy 0.7305, test accuracy 0.5117
# -------------------
# Epoch 138: train loss 0.5195, test loss 0.8143, train accuracy 0.7383, test accuracy 0.4902
# -------------------
# Epoch 139: train loss 0.5124, test loss 0.8194, train accuracy 0.7407, test accuracy 0.4980
# -------------------
# Epoch 140: train loss 0.5537, test loss 0.8165, train accuracy 0.6948, test accuracy 0.4961
# -------------------
# Epoch 141: train loss 0.5285, test loss 0.8213, train accuracy 0.7256, test accuracy 0.5098
# -------------------
# Epoch 142: train loss 0.5231, test loss 0.8221, train accuracy 0.7305, test accuracy 0.5000
# -------------------
# Epoch 143: train loss 0.5002, test loss 0.8577, train accuracy 0.7515, test accuracy 0.5098
# -------------------
# Epoch 144: train loss 0.5001, test loss 0.8586, train accuracy 0.7485, test accuracy 0.4980
# -------------------
# Epoch 145: train loss 0.4978, test loss 0.8663, train accuracy 0.7544, test accuracy 0.5020
# -------------------
# Epoch 146: train loss 0.4720, test loss 0.8786, train accuracy 0.7695, test accuracy 0.4941
# -------------------
# Epoch 147: train loss 0.4900, test loss 0.8869, train accuracy 0.7510, test accuracy 0.5039
# -------------------
# Epoch 148: train loss 0.4726, test loss 0.8886, train accuracy 0.7646, test accuracy 0.5039
# -------------------
# Epoch 149: train loss 0.4532, test loss 0.8898, train accuracy 0.7817, test accuracy 0.5000

# %% [markdown]
# ## Iris

# %% [markdown]
# ### Left and Right Eye/Iris Facial Landmarks each with  XY coordinates

# %%
import random

input_list_T = []
input_list_F = []
output_list_T = []
output_list_F = []

loop = 1
for file_path in glob.glob(SAVE_NPY_PATH+"/*", recursive = True):
  # Y Value
  output = truthfulness[Path(file_path).stem]

  # X Value
  array = np.load(file_path)
  print(array.shape)

  right_eye_landmarks = array[:, RIGHT_EYE, :]
  left_eye_landmarks = array[:, LEFT_EYE, :]
  right_iris_landmarks = array[:, RIGHT_IRIS, :]
  left_iris_landmarks = array[:, LEFT_IRIS, :]

  combined_landmarks = np.concatenate((right_eye_landmarks, left_eye_landmarks, right_iris_landmarks, left_iris_landmarks), axis=1)
  print(combined_landmarks.shape)

  array = combined_landmarks.reshape(240, -1)
  # print(array.shape)

  array = npy_to_npychunks(array)
  print(array.shape)
  num_chunks = array.shape[0]

  if output == 1:
    input_list_T.append(array)
    output_list_T += [output]*num_chunks
  else:
    input_list_F.append(array)
    output_list_F += [output]*num_chunks
  print(f"# of Videos Processed: {loop}")
  loop += 1


X_T = np.vstack(input_list_T)
X_F = np.vstack(input_list_F)
Y_T = np.array(output_list_T).reshape(-1,1)
Y_F = np.array(output_list_F).reshape(-1,1)



X_T = torch.from_numpy(X_T).to(device)
X_F = torch.from_numpy(X_F).to(device)
Y_T = torch.from_numpy(Y_T).to(device)
Y_F = torch.from_numpy(Y_F).to(device)

X_T = X_T.float()
X_F = X_F.float()
Y_T = Y_T.float()
Y_F = Y_F.float()

print("X_T.shape", X_T.shape)
print("X_F.shape", X_F.shape)
print("Y_T.shape", Y_T.shape)
print("Y_F.shape", Y_F.shape)
# Out:
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 1
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 2
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 3
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 4
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 5
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 6
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 7
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 8
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 9
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 10
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 11
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 12
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 13
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 14
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 15
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 16
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 17
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 18
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 19
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 20
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 21
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 22
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 23
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 24
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 25
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 26
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 27
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 28
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 29
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 30
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 31
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 32
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 33
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 34
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 35
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 36
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 37
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 38
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 39
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 40
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 41
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 42
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 43
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 44
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 45
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 46
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 47
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 48
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 49
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 50
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 51
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 52
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 53
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 54
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 55
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 56
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 57
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 58
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 59
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 60
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 61
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 62
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 63
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 64
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 65
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 66
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 67
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 68
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 69
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 70
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 71
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 72
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 73
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 74
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 75
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 76
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 77
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 78
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 79
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 80
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 81
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 82
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 83
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 84
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 85
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 86
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 87
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 88
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 89
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 90
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 91
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 92
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 93
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 94
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 95
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 96
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 97
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 98
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 99
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 100
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 101
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 102
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 103
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 104
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 105
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 106
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 107
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 108
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 109
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 110
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 111
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 112
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 113
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 114
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 115
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 116
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 117
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 118
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 119
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 120
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 121
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 122
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 123
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 124
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 125
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 126
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 127
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 128
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 129
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 130
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 131
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 132
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 133
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 134
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 135
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 136
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 137
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 138
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 139
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 140
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 141
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 142
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 143
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 144
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 145
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 146
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 147
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 148
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 149
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 150
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 151
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 152
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 153
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 154
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 155
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 156
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 157
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 158
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 159
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 160
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 161
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 162
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 163
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 164
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 165
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 166
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 167
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 168
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 169
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 170
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 171
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 172
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 173
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 174
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 175
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 176
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 177
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 178
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 179
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 180
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 181
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 182
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 183
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 184
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 185
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 186
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 187
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 188
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 189
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 190
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 191
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 192
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 193
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 194
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 195
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 196
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 197
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 198
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 199
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 200
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 201
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 202
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 203
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 204
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 205
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 206
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 207
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 208
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 209
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 210
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 211
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 212
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 213
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 214
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 215
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 216
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 217
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 218
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 219
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 220
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 221
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 222
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 223
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 224
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 225
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 226
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 227
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 228
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 229
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 230
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 231
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 232
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 233
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 234
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 235
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 236
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 237
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 238
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 239
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 240
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 241
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 242
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 243
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 244
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 245
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 246
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 247
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 248
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 249
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 250
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 251
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 252
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 253
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 254
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 255
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 256
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 257
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 258
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 259
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 260
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 261
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 262
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 263
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 264
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 265
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 266
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 267
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 268
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 269
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 270
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 271
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 272
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 273
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 274
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 275
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 276
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 277
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 278
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 279
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 280
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 281
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 282
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 283
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 284
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 285
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 286
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 287
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 288
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 289
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 290
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 291
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 292
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 293
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 294
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 295
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 296
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 297
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 298
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 299
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 300
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 301
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 302
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 303
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 304
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 305
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 306
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 307
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 308
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 309
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 310
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 311
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 312
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 313
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 314
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 315
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 316
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 317
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 318
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 319
# (240, 478, 2)
# (240, 40, 2)
# (8, 30, 80)
# # of Videos Processed: 320
# X_T.shape torch.Size([1280, 30, 80])
# X_F.shape torch.Size([1280, 30, 80])
# Y_T.shape torch.Size([1280, 1])
# Y_F.shape torch.Size([1280, 1])

# %%
import torch.utils.data as data

# Split the shuffled data into 80% Training, 20% Testing
train_dataset_T, val_dataset_T = torch.utils.data.random_split(data.TensorDataset(X_T, Y_T), [0.8, 0.2])
train_dataset_F, val_dataset_F = torch.utils.data.random_split(data.TensorDataset(X_F, Y_F), [0.8, 0.2])

train_dataset = data.ConcatDataset([train_dataset_T, train_dataset_F])
val_dataset = data.ConcatDataset([val_dataset_T, val_dataset_F])

print("Training Dataset Size:", len(train_dataset))
print("Testing Dataset Size:", len(val_dataset))
print()

train_loader = data.DataLoader(train_dataset, batch_size=50, shuffle=True)

total_train_samples = len(train_dataset)
count_train_ones = sum(1 for _, label in train_dataset if label == 1)
percentage_train_ones = (count_train_ones / total_train_samples) * 100
print("Percentage of Y that are Truths in train_dataset:", percentage_train_ones)


test_loader = data.DataLoader(val_dataset, batch_size=1, shuffle=False)

total_val_samples = len(val_dataset)
count_val_ones = sum(1 for _, label in val_dataset if label == 1)
percentage_val_ones = (count_val_ones / total_val_samples) * 100
print("Percentage of Y that are Truths in val_dataset:", percentage_val_ones)


X_train_all = []
Y_train_all = []


# Iterate over the train_loader to accumulate the entire dataset
for X_train, Y_train in train_loader:
    X_train_all.append(X_train)
    Y_train_all.append(Y_train)

X_test_all = []
Y_test_all = []

for X_test, Y_test in test_loader:
    X_test_all.append(X_test)
    Y_test_all.append(Y_test)

X_test_all = torch.cat(X_test_all, dim=0).to(device)
Y_test_all = torch.cat(Y_test_all, dim=0).to(device)

X_train_all = torch.cat(X_train_all, dim=0).to(device)
Y_train_all = torch.cat(Y_train_all, dim=0).to(device)
# Out:
# Training Dataset Size: 2048
# Testing Dataset Size: 512
#
# Percentage of Y that are Truths in train_dataset: 50.0
# Percentage of Y that are Truths in val_dataset: 50.0

# %%
import torch.utils.data as data
import matplotlib.pyplot as plt

# Lists to store training and test losses for each epoch
train_losses = []
test_losses = []

# Function to calculate accuracy
def accuracy(outputs, labels):
  preds = torch.round(outputs)
  return torch.tensor(torch.sum(preds == labels).item() / len(preds))


criterion = nn.BCELoss()
model = LSTMModel(input_dim=956, hidden_dim=200, layer_num=1, output_dim=1)
model = model.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

num_epochs = 50

# Training loop
for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0.0
    epoch_acc = 0.0
    for X_batch, y_batch in train_loader:
        y_pred = model(X_batch)
        loss = criterion(y_pred, y_batch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    model.eval()
    with torch.no_grad():
        print("-------------------")
        # Calculate accuracy on training set
        y_pred = model(X_train_all)
        train_loss = criterion(y_pred, Y_train_all)
        train_acc = accuracy(y_pred, Y_train_all)

        # Calculate accuracy on test set
        y_pred = model(X_test_all)
        test_loss = criterion(y_pred, Y_test_all)

        test_acc = accuracy(y_pred, Y_test_all)

    print("Epoch %d: train loss %.4f, test loss %.4f, train accuracy %.4f, test accuracy %.4f" % (epoch, train_loss, test_loss, train_acc, test_acc))

    # Append the losses to the lists
    train_losses.append(train_loss)
    test_losses.append(test_loss)

# Smooth the losses using a moving average
window_size = 5
train_losses_smoothed = np.convolve(train_losses, np.ones(window_size) / window_size, mode='valid')
test_losses_smoothed = np.convolve(test_losses, np.ones(window_size) / window_size, mode='valid')

# Plotting epoch vs training loss and test loss
epochs = range(window_size // 2 + 1, num_epochs - window_size // 2 + 1)
plt.plot(epochs, train_losses_smoothed, label='Train Loss')
plt.plot(epochs, test_losses_smoothed, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Epoch vs Loss (Smoothed)')
plt.legend()
plt.show()
# Out:
# -------------------
# Epoch 0: train loss 0.6930, test loss 0.6935, train accuracy 0.4995, test accuracy 0.4980
# -------------------
# Epoch 1: train loss 0.6929, test loss 0.6943, train accuracy 0.5044, test accuracy 0.4961
# -------------------
# Epoch 2: train loss 0.6928, test loss 0.6945, train accuracy 0.5044, test accuracy 0.4824
# -------------------
# Epoch 3: train loss 0.6929, test loss 0.6953, train accuracy 0.5054, test accuracy 0.5039
# -------------------
# Epoch 4: train loss 0.6927, test loss 0.6950, train accuracy 0.5078, test accuracy 0.4727
# -------------------
# Epoch 5: train loss 0.6925, test loss 0.6954, train accuracy 0.5117, test accuracy 0.5156
# -------------------
# Epoch 6: train loss 0.6924, test loss 0.6957, train accuracy 0.5205, test accuracy 0.4668
# -------------------
# Epoch 7: train loss 0.6923, test loss 0.6958, train accuracy 0.5186, test accuracy 0.4355
# -------------------
# Epoch 8: train loss 0.6922, test loss 0.6964, train accuracy 0.5156, test accuracy 0.4375
# -------------------
# Epoch 9: train loss 0.6924, test loss 0.6965, train accuracy 0.5195, test accuracy 0.4512
# -------------------
# Epoch 10: train loss 0.6921, test loss 0.6965, train accuracy 0.5132, test accuracy 0.4355
# -------------------
# Epoch 11: train loss 0.6921, test loss 0.6968, train accuracy 0.5181, test accuracy 0.4434
# -------------------
# Epoch 12: train loss 0.6921, test loss 0.6972, train accuracy 0.5078, test accuracy 0.4160
# -------------------
# Epoch 13: train loss 0.6920, test loss 0.6972, train accuracy 0.5151, test accuracy 0.4355
# -------------------
# Epoch 14: train loss 0.6921, test loss 0.6981, train accuracy 0.5210, test accuracy 0.4629
# -------------------
# Epoch 15: train loss 0.6923, test loss 0.6975, train accuracy 0.5215, test accuracy 0.4492
# -------------------
# Epoch 16: train loss 0.6921, test loss 0.6975, train accuracy 0.5127, test accuracy 0.4180
# -------------------
# Epoch 17: train loss 0.6920, test loss 0.6976, train accuracy 0.5215, test accuracy 0.4453
# -------------------
# Epoch 18: train loss 0.6920, test loss 0.6978, train accuracy 0.5146, test accuracy 0.4375
# -------------------
# Epoch 19: train loss 0.6919, test loss 0.6979, train accuracy 0.5166, test accuracy 0.4414
# -------------------
# Epoch 20: train loss 0.6920, test loss 0.6980, train accuracy 0.5107, test accuracy 0.4199
# -------------------
# Epoch 21: train loss 0.6919, test loss 0.6981, train accuracy 0.5229, test accuracy 0.4434
# -------------------
# Epoch 22: train loss 0.6922, test loss 0.6992, train accuracy 0.5220, test accuracy 0.4668
# -------------------
# Epoch 23: train loss 0.6919, test loss 0.6982, train accuracy 0.5190, test accuracy 0.4414
# -------------------
# Epoch 24: train loss 0.6919, test loss 0.6984, train accuracy 0.5068, test accuracy 0.4121
# -------------------
# Epoch 25: train loss 0.6919, test loss 0.6987, train accuracy 0.5205, test accuracy 0.4395
# -------------------
# Epoch 26: train loss 0.6918, test loss 0.6989, train accuracy 0.5166, test accuracy 0.4336
# -------------------
# Epoch 27: train loss 0.6918, test loss 0.6989, train accuracy 0.5166, test accuracy 0.4375
# -------------------
# Epoch 28: train loss 0.6918, test loss 0.6988, train accuracy 0.5195, test accuracy 0.4375
# -------------------
# Epoch 29: train loss 0.6918, test loss 0.6990, train accuracy 0.5156, test accuracy 0.4336
# -------------------
# Epoch 30: train loss 0.6921, test loss 0.6987, train accuracy 0.5127, test accuracy 0.4297
# -------------------
# Epoch 31: train loss 0.6918, test loss 0.6987, train accuracy 0.5151, test accuracy 0.4355
# -------------------
# Epoch 32: train loss 0.6918, test loss 0.6989, train accuracy 0.5171, test accuracy 0.4414
# -------------------
# Epoch 33: train loss 0.6918, test loss 0.6990, train accuracy 0.5195, test accuracy 0.4375
# -------------------
# Epoch 34: train loss 0.6918, test loss 0.6991, train accuracy 0.5205, test accuracy 0.4375
# -------------------
# Epoch 35: train loss 0.6918, test loss 0.6988, train accuracy 0.5151, test accuracy 0.4395
# -------------------
# Epoch 36: train loss 0.6918, test loss 0.6989, train accuracy 0.5181, test accuracy 0.4434
# -------------------
# Epoch 37: train loss 0.6918, test loss 0.6992, train accuracy 0.5176, test accuracy 0.4434
# -------------------
# Epoch 38: train loss 0.6919, test loss 0.6991, train accuracy 0.5127, test accuracy 0.4180
# -------------------
# Epoch 39: train loss 0.6918, test loss 0.6995, train accuracy 0.5210, test accuracy 0.4375
# -------------------
# Epoch 40: train loss 0.6918, test loss 0.6991, train accuracy 0.5176, test accuracy 0.4316
# -------------------
# Epoch 41: train loss 0.6918, test loss 0.6992, train accuracy 0.5190, test accuracy 0.4414
# -------------------
# Epoch 42: train loss 0.6917, test loss 0.6997, train accuracy 0.5181, test accuracy 0.4414
# -------------------
# Epoch 43: train loss 0.6918, test loss 0.6996, train accuracy 0.5186, test accuracy 0.4375
# -------------------
# Epoch 44: train loss 0.6918, test loss 0.6992, train accuracy 0.5151, test accuracy 0.4414
# -------------------
# Epoch 45: train loss 0.6917, test loss 0.6994, train accuracy 0.5220, test accuracy 0.4473
# -------------------
# Epoch 46: train loss 0.6918, test loss 0.6999, train accuracy 0.5210, test accuracy 0.4395
# -------------------
# Epoch 47: train loss 0.6917, test loss 0.6997, train accuracy 0.5220, test accuracy 0.4453
# -------------------
# Epoch 48: train loss 0.6917, test loss 0.6996, train accuracy 0.5200, test accuracy 0.4375
# -------------------
# Epoch 49: train loss 0.6917, test loss 0.6998, train accuracy 0.5142, test accuracy 0.4414

# %% [markdown]
# ### Iris position
#
# Regarding the iris position, we averaged four points on the iris to determine the iris's center point. We then measured the eye width as the Euclidean distance between the eye's furthest right and left points and calculated the distance from the iris center to the rightmost point. From these measurements, we derived a ratio of the center-to-right point distance relative to the eye width. This ratio, along with a predefined threshold, helps find out whether a person is looking right, center, or left.
#
# Note: This code does not work because there are some debugging issues maybe to do with the iris coordinates. When we run the position, it always gives us a ratio of around 2.5 which leads to a always left iris position

# %%
def iris_position(iris_center, right_point, left_point):
    center_to_right_dist = euclideanDistance(iris_center, right_point)
    total_distance = euclideanDistance(right_point, left_point)

    # print("center to right:",center_to_right_dist)
    # print("center to right:",center_to_right_dist)
    # print("total distance:",total_distance)

    ratio = center_to_right_dist/total_distance
    iris_position =""
    if ratio <= 0.42:
        iris_position="right"
    elif ratio > 0.42 and ratio <= 0.57:
        iris_position="center"
    else:
        iris_position = "left"
    # print(iris_position, ratio)
    # print("\n")
    return iris_position, ratio

# %%
import random

input_list_T = []
input_list_F = []
output_list_T = []
output_list_F = []

loop = 1
for file_path in glob.glob(SAVE_NPY_PATH+"/*", recursive = True):
  # Y Value
  output = truthfulness[Path(file_path).stem]

  # X Value
  array = np.load(file_path)

  right_iris_landmarks = array[:, RIGHT_IRIS, :]
  left_iris_landmarks = array[:, LEFT_IRIS, :]

  # combined_landmarks = np.concatenate((right_iris_landmarks, left_iris_landmarks), axis=1)
  # print(combined_landmarks.shape)

  LEFT_IRIS = [474, 475, 476, 477]
  RIGHT_IRIS = [469, 470, 471, 472]

  L_H_LEFT = [33]     # right eye most right reference point
  L_H_RIGHT = [133]   # right eye most left reference point
  R_H_LEFT = [362]    # left eye most right reference point
  R_H_RIGHT = [263]   # left eye most left reference point

  new_array = []
  for frame in array:

    right_iris_center = np.mean(frame[RIGHT_IRIS, :], axis=0)
    right_eye_right_corner = frame[R_H_RIGHT, :].flatten()
    right_eye_left_corner = frame[R_H_LEFT, :].flatten()

    left_iris_center = np.mean(frame[LEFT_IRIS, :], axis=0)
    left_eye_right_corner = frame[L_H_RIGHT, :].flatten()
    left_eye_left_corner = frame[L_H_LEFT, :].flatten()
    print(frame[RIGHT_IRIS, :])
    print(right_iris_center, right_eye_right_corner, right_eye_left_corner)
    iris_pos_right, ratio_right = iris_position(right_iris_center, right_eye_right_corner, right_eye_left_corner)


    iris_pos_left, ratio_left = iris_position(left_iris_center, left_eye_left_corner, left_eye_right_corner)

    new_array.append([iris_pos_right, ratio_right, iris_pos_left, ratio_left])


    array = np.array(new_array)
    print(array.shape)
    print("\n")
    break
#   array = combined_landmarks.reshape(240, -1)
#   # print(array.shape)

#   array = npy_to_npychunks(array)
#   print(array.shape)
#   num_chunks = array.shape[0]

#   if output == 1:
#     input_list_T.append([iris_pos_right, ratio_right, iris_pos_left, ratio_left])
#     output_list_T += [output]*num_chunks
#   else:
#     input_list_F.append([iris_pos_right, ratio_right, iris_pos_left, ratio_left])
#     output_list_F += [output]*num_chunks
#   print(f"# of Videos Processed: {loop}")
#   loop += 1


# X_T = np.vstack(input_list_T)
# X_F = np.vstack(input_list_F)
# Y_T = np.array(output_list_T).reshape(-1,1)
# Y_F = np.array(output_list_F).reshape(-1,1)



# X_T = torch.from_numpy(X_T).to(device)
# X_F = torch.from_numpy(X_F).to(device)
# Y_T = torch.from_numpy(Y_T).to(device)
# Y_F = torch.from_numpy(Y_F).to(device)

# X_T = X_T.float()
# X_F = X_F.float()
# Y_T = Y_T.float()
# Y_F = Y_F.float()

# print("X_T.shape", X_T.shape)
# print("X_F.shape", X_F.shape)
# print("Y_T.shape", Y_T.shape)
# print("Y_F.shape", Y_F.shape)
# Out:
# [[0.37434083 0.66189331]
#  [0.35355479 0.63791764]
#  [0.33229277 0.66116595]
#  [0.35285938 0.68634593]]
# [0.35326194 0.66183071] [0.60247529 0.6616264 ] [0.51070148 0.67622483]
# (1, 4)
#
#
# [[0.20325924 0.1942358 ]
#  [0.19352272 0.17770585]
#  [0.18081099 0.19228694]
#  [0.19000381 0.20955542]]
# [0.19189919 0.193446  ] [0.3898609  0.22079991] [0.32218811 0.22348054]
# (1, 4)
#
#
# [[0.49146649 0.47969961]
#  [0.4811281  0.46940535]
#  [0.47205406 0.48134133]
#  [0.48226002 0.49194247]]
# [0.48172717 0.48059719] [0.59697217 0.47159511] [0.55412918 0.47833928]
# (1, 4)
#
#
# [[0.49758831 0.36400697]
#  [0.48651725 0.35201347]
#  [0.47595483 0.36354619]
#  [0.48697698 0.37567046]]
# [0.48675934 0.36380927] [0.62000442 0.36762273] [0.57636273 0.36773169]
# (1, 4)
#
#
# [[0.52276462 0.14443442]
#  [0.51180702 0.13001651]
#  [0.49990383 0.14306845]
#  [0.51060849 0.15819354]]
# [0.51127099 0.14392823] [0.66128761 0.15292093] [0.60892081 0.15837643]
# (1, 4)
#
#
# [[0.4881331  0.52755994]
#  [0.47580284 0.51597631]
#  [0.4654758  0.52986079]
#  [0.47767115 0.54176438]]
# [0.47677072 0.52879035] [0.62480521 0.50645804] [0.57247657 0.52088654]
# (1, 4)
#
#
# [[0.39270872 0.23453392]
#  [0.37715548 0.21615158]
#  [0.36110184 0.23365138]
#  [0.37688208 0.25265628]]
# [0.37696203 0.23424829] [0.56518131 0.24355958] [0.49955395 0.24617589]
# (1, 4)
#
#
# [[0.4889771  0.33494383]
#  [0.47966266 0.32470286]
#  [0.4707627  0.33583295]
#  [0.4799698  0.34628636]]
# [0.47984307 0.3354415 ] [0.61016732 0.33112961] [0.56040752 0.33174914]
# (1, 4)
#
#
# [[0.42036    0.48429137]
#  [0.41288617 0.47742128]
#  [0.4073078  0.48639572]
#  [0.41460651 0.49340665]]
# [0.41379012 0.48537876] [0.52376711 0.47734597] [0.48087391 0.47814506]
# (1, 4)
#
#
# [[0.61535645 0.39145499]
#  [0.59812844 0.37370628]
#  [0.5818063  0.39263386]
#  [0.5989005  0.41103637]]
# [0.59854792 0.39220788] [0.79836112 0.38566938] [0.72909886 0.39848003]
# (1, 4)
#
#
# [[0.3161841  0.23930159]
#  [0.30288786 0.23262021]
#  [0.29569301 0.24871677]
#  [0.3090148  0.25568587]]
# [0.30594494 0.24408111] [0.45865124 0.17546953] [0.4041369  0.19871646]
# (1, 4)
#
#
# [[0.42271012 0.42329398]
#  [0.40900958 0.40553367]
#  [0.39459851 0.42183295]
#  [0.40803987 0.44047475]]
# [0.40858952 0.42278384] [0.58491373 0.43259665] [0.52242285 0.44410816]
# (1, 4)
#
#
# [[0.43921441 0.52075481]
#  [0.42426935 0.50286597]
#  [0.40942568 0.52125752]
#  [0.42444065 0.54014468]]
# [0.42433752 0.52125575] [0.58820087 0.51993412] [0.53029799 0.53208792]
# (1, 4)
#
#
# [[0.50439197 0.35492548]
#  [0.49425343 0.34479472]
#  [0.48537347 0.35661903]
#  [0.49547958 0.36717492]]
# [0.49487461 0.35587854] [0.60939109 0.34796357] [0.56606835 0.35667536]
# (1, 4)
#
#
# [[0.34041411 0.34776562]
#  [0.32413232 0.32757938]
#  [0.30785638 0.34717959]
#  [0.32407367 0.36802924]]
# [0.32411912 0.34763846] [0.51596951 0.35354474] [0.44233492 0.3616547 ]
# (1, 4)
#
#
# [[0.35772899 0.47705591]
#  [0.34157664 0.45817256]
#  [0.32530293 0.47664213]
#  [0.34130752 0.49594849]]
# [0.34147902 0.47695477] [0.53199416 0.48913348] [0.46215448 0.49154198]
# (1, 4)
#
#
# [[0.5155834  0.35314053]
#  [0.50011688 0.33606997]
#  [0.48566091 0.35475355]
#  [0.50116861 0.37219056]]
# [0.50063245 0.35403866] [0.67260003 0.35058066] [0.61013508 0.36046886]
# (1, 4)
#
#
# [[0.47782588 0.44831958]
#  [0.46376735 0.43286985]
#  [0.4496817  0.44847766]
#  [0.46378195 0.4645994 ]]
# [0.46376422 0.44856662] [0.62687212 0.44522429] [0.56734455 0.45338342]
# (1, 4)
#
#
# [[0.36908609 0.50185466]
#  [0.35461187 0.48639083]
#  [0.34177518 0.5043872 ]
#  [0.35624242 0.52079952]]
# [0.35542889 0.50335805] [0.51327008 0.48697573] [0.45595691 0.50613499]
# (1, 4)
#
#
# [[0.37956011 0.31655785]
#  [0.36589015 0.31072441]
#  [0.35888824 0.32735375]
#  [0.37257585 0.33378646]]
# [0.36922859 0.32210562] [0.50298542 0.25522852] [0.45605305 0.28483441]
# (1, 4)
#
#
# [[0.43556786 0.40364927]
#  [0.41864821 0.37929597]
#  [0.3982906  0.39786136]
#  [0.41498315 0.42274922]]
# [0.41687246 0.40088896] [0.63338238 0.44081742] [0.55606502 0.43221724]
# (1, 4)
#
#
# [[0.44481373 0.24344721]
#  [0.43404621 0.23071128]
#  [0.42240116 0.24114121]
#  [0.43300563 0.25420827]]
# [0.43356668 0.24237699] [0.57692522 0.26235807] [0.52860105 0.25822505]
# (1, 4)
#
#
# [[0.49973357 0.39977962]
#  [0.4917424  0.39133549]
#  [0.4839741  0.40006727]
#  [0.49177399 0.40861234]]
# [0.49180602 0.39994868] [0.60443658 0.39910513] [0.5625484  0.39780235]
# (1, 4)
#
#
# [[0.46336061 0.45437786]
#  [0.4520365  0.44073385]
#  [0.44041672 0.45220926]
#  [0.45149058 0.46594453]]
# [0.4518261  0.45331638] [0.58790958 0.47023904] [0.53937107 0.4658969 ]
# (1, 4)
#
#
# [[0.32710299 0.44139856]
#  [0.31275442 0.43222302]
#  [0.30382496 0.44985461]
#  [0.31811866 0.45968652]]
# [0.31545026 0.44579068] [0.46175396 0.40150234] [0.40746951 0.42304426]
# (1, 4)
#
#
# [[0.33618581 0.43997896]
#  [0.32359579 0.42752835]
#  [0.31269032 0.44176257]
#  [0.32485083 0.45462808]]
# [0.32433069 0.44097449] [0.49461001 0.42649302] [0.42944849 0.43155932]
# (1, 4)
#
#
# [[0.45869151 0.36217159]
#  [0.44707599 0.34554935]
#  [0.43380126 0.3591015 ]
#  [0.44546196 0.37608689]]
# [0.44625768 0.36072733] [0.58781922 0.37946844] [0.53585446 0.37764403]
# (1, 4)
#
#
# [[0.41602209 0.24390461]
#  [0.4005591  0.22920564]
#  [0.38818574 0.24821872]
#  [0.40355211 0.26359862]]
# [0.40207976 0.24623189] [0.56962407 0.21802293] [0.51026362 0.23790361]
# (1, 4)
#
#
# [[0.55841351 0.48960316]
#  [0.54836357 0.47468683]
#  [0.53568453 0.48559326]
#  [0.54542083 0.50090921]]
# [0.54697061 0.48769812] [0.68091059 0.52207237] [0.63373762 0.51552236]
# (1, 4)
#
#
# [[0.45816892 0.27341604]
#  [0.445878   0.25426582]
#  [0.43039048 0.26877189]
#  [0.4424125  0.28827655]]
# [0.44421247 0.27118257] [0.61358595 0.30375209] [0.5553146  0.30069113]
# (1, 4)
#
#
# [[0.50725615 0.42265213]
#  [0.49565712 0.41097045]
#  [0.48507205 0.42346805]
#  [0.4965328  0.43551168]]
# [0.49612953 0.42315058] [0.63852412 0.41749382] [0.58915621 0.42737654]
# (1, 4)
#
#
# [[0.5340246  0.29778999]
#  [0.52236229 0.28596419]
#  [0.51161087 0.29847971]
#  [0.52323914 0.31081939]]
# [0.52280922 0.29826332] [0.65896314 0.29733297] [0.60897368 0.30243754]
# (1, 4)
#
#
# [[0.3646841  0.36843473]
#  [0.35130024 0.35734722]
#  [0.34124511 0.37395859]
#  [0.35453701 0.38549092]]
# [0.35294162 0.37130786] [0.49145907 0.34038571] [0.4395242  0.36027661]
# (1, 4)
#
#
# [[0.49059841 0.21181752]
#  [0.47425631 0.19526386]
#  [0.45847565 0.21271996]
#  [0.47464535 0.2297703 ]]
# [0.47449393 0.21239291] [0.6759268 0.2226966] [0.60894316 0.21829928]
# (1, 4)
#
#
# [[0.72876215 0.36802089]
#  [0.72089964 0.35277098]
#  [0.70852846 0.36142585]
#  [0.71637189 0.37701777]]
# [0.71864054 0.36480887] [0.84928846 0.41710058] [0.80616111 0.40024817]
# (1, 4)
#
#
# [[0.5139758  0.42174608]
#  [0.5012095  0.41021121]
#  [0.49092236 0.42526841]
#  [0.50373286 0.43735611]]
# [0.50246013 0.42364545] [0.636724   0.40823269] [0.58516717 0.41911286]
# (1, 4)
#
#
# [[0.48792681 0.45451891]
#  [0.47484118 0.43910888]
#  [0.46221581 0.45372859]
#  [0.47507021 0.46924871]]
# [0.4750135  0.45415127] [0.66841918 0.45738012] [0.5949201  0.45643559]
# (1, 4)
#
#
# [[0.48254877 0.36203462]
#  [0.46576869 0.34561044]
#  [0.45149726 0.36507377]
#  [0.46816996 0.38206035]]
# [0.46699617 0.36369479] [0.66697276 0.35210171] [0.59643179 0.36660969]
# (1, 4)
#
#
# [[0.43677992 0.49554712]
#  [0.41800582 0.47239804]
#  [0.39844984 0.49490166]
#  [0.41732976 0.51942271]]
# [0.41764133 0.49556738] [0.63665044 0.49057788] [0.55758989 0.51142532]
# (1, 4)
#
#
# [[0.43767127 0.43111819]
#  [0.42714852 0.41943994]
#  [0.41689387 0.43152028]
#  [0.4274134  0.44356593]]
# [0.42728177 0.43141109] [0.58158869 0.42515355] [0.52476931 0.42689705]
# (1, 4)
#
#
# [[0.53172517 0.51378453]
#  [0.51759267 0.50112897]
#  [0.50602603 0.51703191]
#  [0.52011454 0.53017044]]
# [0.5188646  0.51552896] [0.69161665 0.49559736] [0.62570292 0.50139832]
# (1, 4)
#
#
# [[0.54892361 0.39441508]
#  [0.54119241 0.38571829]
#  [0.53369761 0.39428586]
#  [0.54133344 0.40316424]]
# [0.54128677 0.39439587] [0.65123653 0.39448151] [0.6096279  0.39560992]
# (1, 4)
#
#
# [[0.50534737 0.45514634]
#  [0.49296191 0.44330305]
#  [0.48223591 0.45719501]
#  [0.49465644 0.46932849]]
# [0.49380041 0.45624322] [0.63331175 0.44667786] [0.58290344 0.45212719]
# (1, 4)
#
#
# [[0.49363387 0.50223529]
#  [0.48326576 0.49395233]
#  [0.47584802 0.50607365]
#  [0.48597974 0.51469797]]
# [0.48468184 0.50423981] [0.62087834 0.48324963] [0.57074827 0.48871002]
# (1, 4)
#
#
# [[0.43373048 0.57467484]
#  [0.41889787 0.56147194]
#  [0.40692341 0.57988435]
#  [0.42169312 0.59365517]]
# [0.42031122 0.57742158] [0.5797202  0.55000001] [0.52015728 0.56754905]
# (1, 4)
#
#
# [[0.5476222  0.34147823]
#  [0.53834891 0.32971698]
#  [0.52933854 0.34215254]
#  [0.53883672 0.35456052]]
# [0.53853659 0.34197707] [0.65801084 0.33682883] [0.6198743  0.34391439]
# (1, 4)
#
#
# [[0.46914521 0.44066781]
#  [0.4540903  0.42759717]
#  [0.44201031 0.44502521]
#  [0.45698503 0.45874998]]
# [0.45555771 0.44301004] [0.61491263 0.421222  ] [0.5581634  0.43575287]
# (1, 4)
#
#
# [[0.48263294 0.47074771]
#  [0.47034761 0.46367794]
#  [0.4635683  0.47844422]
#  [0.47587115 0.48585749]]
# [0.473105   0.47468184] [0.60893053 0.4248181 ] [0.55790293 0.4429183 ]
# (1, 4)
#
#
# [[0.40876016 0.36267236]
#  [0.39691865 0.34584439]
#  [0.38298082 0.35906127]
#  [0.39474654 0.37620431]]
# [0.39585155 0.36094558] [0.55003971 0.39199805] [0.49928164 0.38725844]
# (1, 4)
#
#
# [[0.5364446  0.37735128]
#  [0.52843946 0.36994472]
#  [0.52184802 0.37903807]
#  [0.52968442 0.3865549 ]]
# [0.52910413 0.37822224] [0.63819754 0.36535448] [0.59822935 0.37157127]
# (1, 4)
#
#
# [[0.48303404 0.31923413]
#  [0.46760553 0.30574077]
#  [0.45469433 0.32275492]
#  [0.46974981 0.33681065]]
# [0.46877093 0.32113512] [0.65970379 0.31087071] [0.59041274 0.3149156 ]
# (1, 4)
#
#
# [[0.47093508 0.40639299]
#  [0.45976451 0.39517686]
#  [0.44953591 0.40742868]
#  [0.46062422 0.41866457]]
# [0.46021493 0.40691578] [0.5946995  0.42088076] [0.54991972 0.4122687 ]
# (1, 4)
#
#
# [[0.42535511 0.37283447]
#  [0.40951133 0.36000183]
#  [0.39737102 0.37804443]
#  [0.41284072 0.39146778]]
# [0.41126955 0.37558713] [0.59153855 0.35534036] [0.52879387 0.36076641]
# (1, 4)
#
#
# [[0.45575884 0.40617037]
#  [0.4401021  0.38800427]
#  [0.42580268 0.40767908]
#  [0.44116595 0.42657524]]
# [0.44070739 0.40710724] [0.61498398 0.40263832] [0.54920793 0.41669506]
# (1, 4)
#
#
# [[0.45424977 0.46985781]
#  [0.44167218 0.45774257]
#  [0.43120778 0.47280383]
#  [0.44368884 0.48536876]]
# [0.44270464 0.47144324] [0.5819732  0.46554095] [0.53390962 0.47279793]
# (1, 4)
#
#
# [[0.3588956  0.20559238]
#  [0.34115779 0.18806146]
#  [0.32456547 0.20749229]
#  [0.34213704 0.22571364]]
# [0.34168898 0.20671494] [0.54931068 0.20019829] [0.47059774 0.20996608]
# (1, 4)
#
#
# [[0.40093499 0.47030908]
#  [0.39273748 0.45962334]
#  [0.38350141 0.46916959]
#  [0.39181775 0.48034194]]
# [0.39224791 0.46986099] [0.50362927 0.47265068] [0.46163058 0.47462833]
# (1, 4)
#
#
# [[0.71453893 0.43534797]
#  [0.69735837 0.42273933]
#  [0.68466914 0.44347054]
#  [0.7019648  0.45690724]]
# [0.69963281 0.43961627] [0.8806653  0.40508187] [0.82552588 0.41739553]
# (1, 4)
#
#
# [[0.40866709 0.2284233 ]
#  [0.39298648 0.21305427]
#  [0.37980631 0.23150645]
#  [0.39521664 0.24690554]]
# [0.39416913 0.22997239] [0.59161496 0.20742585] [0.51393211 0.21496078]
# (1, 4)
#
#
# [[0.47314247 0.37722617]
#  [0.46451676 0.36945641]
#  [0.45699075 0.3776657 ]
#  [0.4653748  0.38571566]]
# [0.4650062  0.37751599] [0.58670932 0.38173538] [0.54466653 0.37974358]
# (1, 4)
#
#
# [[0.48624459 0.48089007]
#  [0.47545451 0.46836796]
#  [0.46437165 0.48080122]
#  [0.47496402 0.49366361]]
# [0.47525869 0.48093072] [0.62021875 0.48743266] [0.57030314 0.49211749]
# (1, 4)
#
#
# [[0.44592834 0.48755455]
#  [0.43440539 0.47396189]
#  [0.42293257 0.48749343]
#  [0.43438357 0.50143963]]
# [0.43441246 0.48761237] [0.57416284 0.49184263] [0.52253783 0.49376559]
# (1, 4)
#
#
# [[0.4783361  0.45918757]
#  [0.4620184  0.44223288]
#  [0.44731891 0.46167693]
#  [0.46345815 0.47911465]]
# [0.46278289 0.46055301] [0.64748973 0.43724316] [0.58296931 0.45778573]
# (1, 4)
#
#
# [[0.50720918 0.33462641]
#  [0.49934381 0.32329684]
#  [0.49027762 0.33205274]
#  [0.49791148 0.3437553 ]]
# [0.49868552 0.33343282] [0.61487859 0.35183069] [0.58029377 0.35037076]
# (1, 4)
#
#
# [[0.58822328 0.54625946]
#  [0.58126742 0.53832281]
#  [0.57449543 0.54687274]
#  [0.58139384 0.55493432]]
# [0.58134499 0.54659733] [0.67575127 0.54297137] [0.64120692 0.54577863]
# (1, 4)
#
#
# [[0.4145751  0.48699623]
#  [0.40244964 0.47505149]
#  [0.39139998 0.48858339]
#  [0.40324235 0.50110883]]
# [0.40291677 0.48793498] [0.55390996 0.47559077] [0.50495481 0.48633018]
# (1, 4)
#
#
# [[0.4190883  0.42517954]
#  [0.40342596 0.40847719]
#  [0.38872308 0.42629215]
#  [0.40441251 0.44336441]]
# [0.40391246 0.42582832] [0.58023131 0.42318964] [0.51391143 0.43017584]
# (1, 4)
#
#
# [[0.53897274 0.54682612]
#  [0.52391195 0.53070819]
#  [0.50955731 0.54787815]
#  [0.5246374  0.56444347]]
# [0.52426985 0.54746398] [0.68783659 0.54834819] [0.62735772 0.55533624]
# (1, 4)
#
#
# [[0.49402809 0.31340244]
#  [0.48511922 0.29950118]
#  [0.47347099 0.30898675]
#  [0.48232096 0.3236796 ]]
# [0.48373482 0.31139249] [0.59765565 0.34312499] [0.55619621 0.3372817 ]
# (1, 4)
#
#
# [[0.44669861 0.28645426]
#  [0.43038675 0.27370644]
#  [0.41815719 0.29119945]
#  [0.43426794 0.30441713]]
# [0.43237762 0.28894432] [0.63629729 0.26828837] [0.56446701 0.27116093]
# (1, 4)
#
#
# [[0.40892208 0.39036623]
#  [0.39072168 0.37306482]
#  [0.37495747 0.39368224]
#  [0.3929348  0.41161856]]
# [0.39188401 0.39218296] [0.62775809 0.36715269] [0.5475809  0.37830499]
# (1, 4)
#
#
# [[0.43526617 0.48589242]
#  [0.4190402  0.46765256]
#  [0.40302837 0.485973  ]
#  [0.41929096 0.50500154]]
# [0.41915642 0.48612988] [0.60167849 0.48633689] [0.53161925 0.49552763]
# (1, 4)
#
#
# [[0.56229454 0.50455046]
#  [0.54828066 0.48903257]
#  [0.53649735 0.50701976]
#  [0.55121636 0.52329803]]
# [0.54957223 0.5059752 ] [0.70170891 0.48421276] [0.63840842 0.50408679]
# (1, 4)
#
#
# [[0.45931864 0.3844229 ]
#  [0.44850892 0.36882693]
#  [0.43539247 0.38018668]
#  [0.44605359 0.39616305]]
# [0.4473184  0.38239989] [0.59595436 0.41122371] [0.5434829  0.40743929]
# (1, 4)
#
#
# [[0.52191949 0.4547179 ]
#  [0.51048297 0.43920872]
#  [0.4976342  0.45254976]
#  [0.50906503 0.46828994]]
# [0.50977542 0.45369158] [0.66478735 0.47783515] [0.61318618 0.47446886]
# (1, 4)
#
#
# [[0.44117025 0.37071896]
#  [0.4237785  0.35299072]
#  [0.40793884 0.37235242]
#  [0.42516887 0.3903811 ]]
# [0.42451411 0.3716108 ] [0.63015187 0.36809057] [0.55960155 0.37757301]
# (1, 4)
#
#
# [[0.50579119 0.44270915]
#  [0.4921993  0.42246699]
#  [0.4752475  0.4376018 ]
#  [0.48852491 0.45807284]]
# [0.49044073 0.4402127 ] [0.68246049 0.46702796] [0.61086798 0.46642089]
# (1, 4)
#
#
# [[0.54279101 0.52973759]
#  [0.53409475 0.51516408]
#  [0.52278483 0.52520806]
#  [0.53128588 0.54014021]]
# [0.53273912 0.52756248] [0.66578907 0.56169844] [0.6185171  0.55445933]
# (1, 4)
#
#
# [[0.24279206 0.33048487]
#  [0.23159021 0.31675544]
#  [0.21945214 0.32877055]
#  [0.23055741 0.34282076]]
# [0.23109796 0.32970791] [0.37145638 0.34227169] [0.3196798  0.34437528]
# (1, 4)
#
#
# [[0.42937714 0.51237428]
#  [0.41517797 0.5000807 ]
#  [0.40397775 0.51643968]
#  [0.41790414 0.5289827 ]]
# [0.41660925 0.51446934] [0.5918197  0.48322767] [0.53289539 0.49983475]
# (1, 4)
#
#
# [[0.52369696 0.41884631]
#  [0.50746518 0.3989616 ]
#  [0.49169379 0.41797334]
#  [0.50917369 0.43864524]]
# [0.50800741 0.41860662] [0.71023893 0.42720523] [0.63346475 0.43585259]
# (1, 4)
#
#
# [[0.44444922 0.39889342]
#  [0.43157545 0.38803133]
#  [0.42068374 0.40090954]
#  [0.43323624 0.41220698]]
# [0.43248616 0.40001032] [0.60592502 0.39300525] [0.54117548 0.39284801]
# (1, 4)
#
#
# [[0.37523085 0.19494936]
#  [0.36219305 0.1759291 ]
#  [0.34686762 0.19097422]
#  [0.35927546 0.21021816]]
# [0.36089174 0.19301771] [0.54817325 0.21930596] [0.47825569 0.21514501]
# (1, 4)
#
#
# [[0.36896974 0.25970083]
#  [0.35476035 0.2469047 ]
#  [0.34444422 0.2651642 ]
#  [0.35860193 0.27878678]]
# [0.35669406 0.26263913] [0.50945175 0.22626643] [0.45434037 0.25329578]
# (1, 4)
#
#
# [[0.40675154 0.38829932]
#  [0.3981756  0.38025227]
#  [0.39126492 0.39074099]
#  [0.39985171 0.39915255]]
# [0.39901094 0.38961128] [0.48994014 0.37843478] [0.45713964 0.38560098]
# (1, 4)
#
#
# [[0.4791173  0.47206557]
#  [0.46643919 0.45691863]
#  [0.45347255 0.47140735]
#  [0.46598262 0.48717669]]
# [0.46625292 0.47189206] [0.62166893 0.48446503] [0.56543273 0.48549178]
# (1, 4)
#
#
# [[0.42129916 0.37965173]
#  [0.40705326 0.36408621]
#  [0.39411297 0.38140756]
#  [0.40825036 0.39753336]]
# [0.40767894 0.38066971] [0.6050545  0.37874728] [0.53630704 0.3788231 ]
# (1, 4)
#
#
# [[0.44635415 0.32156628]
#  [0.43471169 0.31404364]
#  [0.42695013 0.32732993]
#  [0.4385848  0.33519712]]
# [0.43665019 0.32453424] [0.5553782  0.29321712] [0.51324385 0.30835706]
# (1, 4)
#
#
# [[0.36738193 0.32107937]
#  [0.35506046 0.31353474]
#  [0.34767377 0.32857805]
#  [0.35996404 0.33661002]]
# [0.35752005 0.32495055] [0.47674656 0.28475642] [0.4316749  0.30289757]
# (1, 4)
#
#
# [[0.36785918 0.15685177]
#  [0.35449919 0.14018701]
#  [0.3393544  0.15402828]
#  [0.35246539 0.17117101]]
# [0.35354454 0.15555952] [0.54893637 0.17898563] [0.47926158 0.17277892]
# (1, 4)
#
#
# [[0.43346694 0.40449291]
#  [0.41812927 0.38859487]
#  [0.40427709 0.40666354]
#  [0.41985759 0.42315546]]
# [0.41893272 0.40572669] [0.58437073 0.39533585] [0.52391982 0.40543145]
# (1, 4)
#
#
# [[0.36923829 0.47467592]
#  [0.35711461 0.46263051]
#  [0.3463068  0.47674644]
#  [0.35839561 0.48916242]]
# [0.35776383 0.47580382] [0.51276112 0.46784642] [0.45381913 0.46988457]
# (1, 4)
#
#
# [[0.56687754 0.47492111]
#  [0.54767203 0.44927305]
#  [0.52634001 0.47181141]
#  [0.54549062 0.4982906 ]]
# [0.54659505 0.47357404] [0.77503109 0.48587042] [0.69032192 0.49452311]
# (1, 4)
#
#
# [[0.52724159 0.45464554]
#  [0.51801181 0.44606757]
#  [0.51053768 0.4563818 ]
#  [0.51962399 0.46513599]]
# [0.51885377 0.45555773] [0.63618177 0.44293088] [0.59209853 0.44687006]
# (1, 4)
#
#
# [[0.47386059 0.47117186]
#  [0.45705697 0.4532817 ]
#  [0.44253159 0.47407097]
#  [0.45925552 0.49275115]]
# [0.45817617 0.47281892] [0.63891304 0.45916909] [0.57005101 0.47648948]
# (1, 4)
#
#
# [[0.49684474 0.40402806]
#  [0.48639375 0.39166585]
#  [0.47553238 0.4029457 ]
#  [0.48587614 0.41573116]]
# [0.48616175 0.40359269] [0.61767411 0.41519964] [0.56972337 0.41563141]
# (1, 4)
#
#
# [[0.4336611  0.45700374]
#  [0.42244408 0.44689041]
#  [0.41414866 0.46139011]
#  [0.42541617 0.47186521]]
# [0.4239175  0.45928737] [0.54475099 0.43490228] [0.50146616 0.45135754]
# (1, 4)
#
#
# [[0.49123529 0.47756818]
#  [0.4783912  0.46395159]
#  [0.46595031 0.47760791]
#  [0.47853476 0.49132079]]
# [0.47852789 0.47761212] [0.62999892 0.48212451] [0.57559198 0.48529917]
# (1, 4)
#
#
# [[0.58276719 0.31998473]
#  [0.572936   0.30632687]
#  [0.56084239 0.3155334 ]
#  [0.57055974 0.32948673]]
# [0.57177633 0.31783293] [0.71059924 0.36113131] [0.66469491 0.34564763]
# (1, 4)
#
#
# [[0.38955259 0.48478961]
#  [0.37347221 0.47180766]
#  [0.36290812 0.49073899]
#  [0.37862837 0.50434262]]
# [0.37614033 0.48791972] [0.56175876 0.45089492] [0.49395314 0.47374201]
# (1, 4)
#
#
# [[0.48587683 0.51799256]
#  [0.47508326 0.50969958]
#  [0.46689183 0.52153057]
#  [0.47746104 0.53002083]]
# [0.47632824 0.51981089] [0.61838943 0.48952556] [0.56749308 0.50141382]
# (1, 4)
#
#
# [[0.4876098  0.52683282]
#  [0.47584447 0.51580811]
#  [0.46604779 0.52943301]
#  [0.47763386 0.5408138 ]]
# [0.47678398 0.52822194] [0.63311094 0.49839991] [0.57744479 0.51285028]
# (1, 4)
#
#
# [[0.44120735 0.34478238]
#  [0.42902663 0.32700941]
#  [0.41434649 0.34157604]
#  [0.42635578 0.35981208]]
# [0.42773406 0.34329498] [0.59154487 0.36002582] [0.52799016 0.36491609]
# (1, 4)
#
#
# [[0.4717268  0.47775033]
#  [0.46324545 0.46550214]
#  [0.4532249  0.47579151]
#  [0.46142834 0.48840359]]
# [0.46240637 0.47686189] [0.5865618  0.49049419] [0.54106259 0.48990449]
# (1, 4)
#
#
# [[0.44484484 0.14991894]
#  [0.43090931 0.12975323]
#  [0.41613758 0.14712919]
#  [0.4294534  0.16820738]]
# [0.43033628 0.14875219] [0.61567158 0.18874784] [0.55284607 0.18527456]
# (1, 4)
#
#
# [[0.63238084 0.34010524]
#  [0.62287742 0.32414073]
#  [0.61005074 0.33542436]
#  [0.61950564 0.35199022]]
# [0.62120366 0.33791514] [0.75041455 0.36527324] [0.69754732 0.36164576]
# (1, 4)
#
#
# [[0.39870998 0.15949398]
#  [0.38253647 0.14475819]
#  [0.36896953 0.16281699]
#  [0.38501006 0.17808795]]
# [0.38380651 0.16128928] [0.57237065 0.14668821] [0.50719315 0.15734315]
# (1, 4)
#
#
# [[0.35290611 0.35352451]
#  [0.33488935 0.33459032]
#  [0.31937081 0.35610232]
#  [0.33732057 0.37570858]]
# [0.33612171 0.35498143] [0.53056991 0.34347504] [0.45817891 0.35764778]
# (1, 4)
#
#
# [[0.32128873 0.47208992]
#  [0.30587003 0.45614016]
#  [0.29192808 0.47352791]
#  [0.30710506 0.489831  ]]
# [0.30654798 0.47289725] [0.50209391 0.47109896] [0.42793211 0.47132549]
# (1, 4)
#
#
# [[0.52354115 0.27849609]
#  [0.51059574 0.26749212]
#  [0.50116664 0.28277817]
#  [0.51397169 0.29414564]]
# [0.5123188 0.280728 ] [0.66065884 0.26218241] [0.6095683  0.27028632]
# (1, 4)
#
#
# [[0.52146757 0.47751981]
#  [0.51337594 0.465083  ]
#  [0.505611   0.47720414]
#  [0.51421124 0.49059495]]
# [0.51366644 0.47760048] [0.60438991 0.4847047 ] [0.57765287 0.48850846]
# (1, 4)
#
#
# [[0.52961928 0.47743189]
#  [0.51556551 0.45773247]
#  [0.49936709 0.47444761]
#  [0.51338649 0.49475101]]
# [0.51448459 0.47609074] [0.69639701 0.48279172] [0.63154238 0.49476096]
# (1, 4)
#
#
# [[0.43356121 0.41701534]
#  [0.42053691 0.4007408 ]
#  [0.40677997 0.41530642]
#  [0.41950476 0.43220216]]
# [0.42009571 0.41631618] [0.59452033 0.42317712] [0.5348767  0.43127427]
# (1, 4)
#
#
# [[0.43474653 0.48318642]
#  [0.42182434 0.46998656]
#  [0.40976253 0.48350012]
#  [0.42262694 0.49693879]]
# [0.42224009 0.48340297] [0.57641888 0.48575446] [0.52606487 0.49141073]
# (1, 4)
#
#
# [[0.47134626 0.37546656]
#  [0.46370688 0.36773014]
#  [0.45662662 0.37580436]
#  [0.4640106  0.38394508]]
# [0.46392259 0.37573653] [0.57978421 0.38201973] [0.5393818  0.38052249]
# (1, 4)
#
#
# [[0.44236448 0.2934655 ]
#  [0.43569291 0.28590065]
#  [0.42936084 0.29367724]
#  [0.43599108 0.30149943]]
# [0.43585233 0.2936357 ] [0.5255022  0.29856867] [0.49511781 0.29766887]
# (1, 4)
#
#
# [[0.59028882 0.48799387]
#  [0.58243316 0.48027045]
#  [0.57552129 0.48839241]
#  [0.58319843 0.49635684]]
# [0.58286043 0.48825339] [0.6790908  0.48642012] [0.64580542 0.48957181]
# (1, 4)
#
#
# [[0.44076183 0.38923919]
#  [0.42651263 0.3724373 ]
#  [0.41173553 0.38841018]
#  [0.42623684 0.40556613]]
# [0.42631171 0.3889132 ] [0.59544569 0.39761552] [0.53097105 0.40225101]
# (1, 4)
#
#
# [[0.52262664 0.54455829]
#  [0.50702411 0.5270322 ]
#  [0.49274421 0.54657257]
#  [0.50831676 0.56484175]]
# [0.50767793 0.5457512 ] [0.67513263 0.53933775] [0.61183012 0.55281955]
# (1, 4)
#
#
# [[0.52385592 0.36689821]
#  [0.51388335 0.35599363]
#  [0.50418651 0.36675888]
#  [0.51408857 0.37802833]]
# [0.51400359 0.36691976] [0.63293141 0.36893257] [0.59047323 0.37045595]
# (1, 4)
#
#
# [[0.45109722 0.45476633]
#  [0.43688855 0.43971714]
#  [0.42439219 0.45738757]
#  [0.43856633 0.4730843 ]]
# [0.43773607 0.45623884] [0.61302465 0.44782066] [0.54738492 0.45172077]
# (1, 4)
#
#
# [[0.4414809  0.45492676]
#  [0.43339401 0.44782543]
#  [0.42712313 0.45780885]
#  [0.43520805 0.46522865]]
# [0.43430153 0.45644742] [0.54498142 0.44089195] [0.50609136 0.44640112]
# (1, 4)
#
#
# [[0.48306665 0.35024905]
#  [0.4739314  0.34104425]
#  [0.46554607 0.3504301 ]
#  [0.4743802  0.35972399]]
# [0.47423108 0.35036185] [0.60058022 0.3549493 ] [0.55771911 0.35437393]
# (1, 4)
#
#
# [[0.56182009 0.32800257]
#  [0.55178529 0.31241339]
#  [0.53862286 0.32357526]
#  [0.54877883 0.33971125]]
# [0.55025177 0.32592562] [0.68782943 0.35705179] [0.64073533 0.35028341]
# (1, 4)
#
#
# [[0.37526426 0.60524029]
#  [0.36053389 0.5918178 ]
#  [0.34896022 0.60951936]
#  [0.36356527 0.6232509 ]]
# [0.36208091 0.60745709] [0.54807007 0.5827111 ] [0.48134619 0.59197623]
# (1, 4)
#
#
# [[0.42343596 0.42253131]
#  [0.40849346 0.40582579]
#  [0.39383239 0.42339724]
#  [0.40871608 0.4405247 ]]
# [0.40861947 0.42306976] [0.58903688 0.42016509] [0.52503449 0.43459719]
# (1, 4)
#
#
# [[0.31612647 0.34722596]
#  [0.30695006 0.33341187]
#  [0.29491061 0.34261495]
#  [0.30388314 0.35682049]]
# [0.30546757 0.34501832] [0.44367287 0.37076619] [0.39371574 0.37078547]
# (1, 4)
#
#
# [[0.53444672 0.22637512]
#  [0.52391356 0.21180859]
#  [0.51205927 0.22421847]
#  [0.52252144 0.23952694]]
# [0.52323525 0.22548228] [0.65643233 0.24078296] [0.6106984  0.24452502]
# (1, 4)
#
#
# [[0.45108515 0.39924908]
#  [0.4394094  0.38761169]
#  [0.42929465 0.40092343]
#  [0.44079471 0.41308156]]
# [0.44014598 0.40021644] [0.57676911 0.39177188] [0.52849817 0.39839548]
# (1, 4)
#
#
# [[0.47893727 0.50285238]
#  [0.46856123 0.49373585]
#  [0.46078977 0.50595719]
#  [0.47107947 0.51545376]]
# [0.46984193 0.50449979] [0.5748592  0.48455983] [0.53951478 0.49670407]
# (1, 4)
#
#
# [[0.46943593 0.35882017]
#  [0.4590742  0.34955162]
#  [0.45083609 0.36086521]
#  [0.46100232 0.3703295 ]]
# [0.46008714 0.35989162] [0.57893986 0.34719545] [0.53662783 0.35601366]
# (1, 4)
#
#
# [[0.37293509 0.28551355]
#  [0.35560405 0.27505708]
#  [0.34372813 0.29323745]
#  [0.36016142 0.30438608]]
# [0.35810717 0.28954854] [0.58649182 0.25518882] [0.51321989 0.2603437 ]
# (1, 4)
#
#
# [[0.43694645 0.55071276]
#  [0.42036772 0.53198779]
#  [0.40447664 0.55143791]
#  [0.421067   0.57108176]]
# [0.42071445 0.55130506] [0.60033631 0.54854649] [0.53384769 0.5587973 ]
# (1, 4)
#
#
# [[0.3991347  0.57075095]
#  [0.3812868  0.55201304]
#  [0.36436206 0.57187778]
#  [0.38214031 0.59121001]]
# [0.38173097 0.57146294] [0.60574621 0.5649358 ] [0.52295572 0.57066131]
# (1, 4)
#
#
# [[0.71141386 0.2769058 ]
#  [0.69925356 0.25779796]
#  [0.68340552 0.27242988]
#  [0.69513386 0.29218984]]
# [0.6973017  0.27483087] [0.90563142 0.31764337] [0.8367914  0.31543702]
# (1, 4)
#
#
# [[0.48991969 0.2817499 ]
#  [0.47913098 0.27187961]
#  [0.47007644 0.284464  ]
#  [0.48063105 0.29474315]]
# [0.47993954 0.28320917] [0.61644089 0.26625866] [0.56525147 0.27313712]
# (1, 4)
#
#
# [[0.4732421  0.44789925]
#  [0.461191   0.43532068]
#  [0.45075279 0.45031938]
#  [0.46266145 0.46354812]]
# [0.46196184 0.44927186] [0.60961425 0.43592587] [0.55861783 0.44666305]
# (1, 4)
#
#
# [[0.53365839 0.49651879]
#  [0.52368367 0.4829042 ]
#  [0.51279896 0.49401283]
#  [0.5223366  0.50773317]]
# [0.5231194  0.49529225] [0.68509668 0.5226568 ] [0.62171316 0.51055497]
# (1, 4)
#
#
# [[0.56578434 0.42982972]
#  [0.55102324 0.41105348]
#  [0.53465933 0.42653769]
#  [0.54941499 0.44557554]]
# [0.55022047 0.42824911] [0.74758393 0.45245379] [0.67716873 0.44773251]
# (1, 4)
#
#
# [[0.43102264 0.39383262]
#  [0.42364904 0.38451484]
#  [0.41578713 0.39252922]
#  [0.42292261 0.4018504 ]]
# [0.42334536 0.39318177] [0.5400452  0.40346977] [0.49823919 0.39923239]
# (1, 4)
#
#
# [[0.43896958 0.50357729]
#  [0.42631739 0.49118167]
#  [0.41672188 0.50654697]
#  [0.42889315 0.51939118]]
# [0.4277255  0.50517428] [0.61107838 0.47830343] [0.53847259 0.49222499]
# (1, 4)
#
#
# [[0.46533313 0.29097831]
#  [0.45125613 0.27623093]
#  [0.43838358 0.29215914]
#  [0.45214626 0.30752128]]
# [0.45177978 0.29172242] [0.62618083 0.29298121] [0.56149822 0.29727352]
# (1, 4)
#
#
# [[0.45123938 0.47835943]
#  [0.43998441 0.47031975]
#  [0.43305272 0.48420441]
#  [0.44405678 0.49254593]]
# [0.44208332 0.48135738] [0.57675123 0.44739127] [0.52601236 0.4597134 ]
# (1, 4)
#
#
# [[0.41913494 0.43653989]
#  [0.40283746 0.41824743]
#  [0.38676879 0.43683892]
#  [0.40311506 0.45589083]]
# [0.40296406 0.43687927] [0.60903066 0.43608806] [0.53488219 0.44115847]
# (1, 4)
#
#
# [[0.54618436 0.50225031]
#  [0.53148907 0.4871237 ]
#  [0.51795542 0.50346112]
#  [0.53259766 0.5192917 ]]
# [0.53205663 0.50303171] [0.69542044 0.49783704] [0.6349225 0.50707  ]
# (1, 4)
#
#
# [[0.45350432 0.44071504]
#  [0.43881929 0.42724505]
#  [0.42632234 0.44376785]
#  [0.4410044  0.4579055 ]]
# [0.43991259 0.44240836] [0.60037184 0.4327029 ] [0.53967088 0.44233006]
# (1, 4)
#
#
# [[0.45321143 0.46402428]
#  [0.43967795 0.44915646]
#  [0.42703992 0.46504295]
#  [0.44047564 0.48086616]]
# [0.44010124 0.46477246] [0.59367752 0.45701358] [0.5346939  0.47439033]
# (1, 4)
#
#
# [[0.46760857 0.32548162]
#  [0.45899382 0.31530732]
#  [0.45062622 0.32527328]
#  [0.45917559 0.3357586 ]]
# [0.45910105 0.3254552 ] [0.56843805 0.32879007] [0.52823311 0.33004564]
# (1, 4)
#
#
# [[0.47675931 0.42039675]
#  [0.46387181 0.40815741]
#  [0.45253822 0.4226259 ]
#  [0.46521467 0.43534029]]
# [0.464596   0.42163008] [0.63058197 0.41203764] [0.56970179 0.417808  ]
# (1, 4)
#
#
# [[0.50671136 0.43973988]
#  [0.49471122 0.42925921]
#  [0.48523828 0.44315282]
#  [0.49721283 0.45380047]]
# [0.49596842 0.44148809] [0.63025141 0.42457297] [0.58198631 0.43182045]
# (1, 4)
#
#
# [[0.38558537 0.27170056]
#  [0.36596766 0.25463313]
#  [0.35038561 0.27721405]
#  [0.36989194 0.294833  ]]
# [0.36795764 0.27459519] [0.58837146 0.24744296] [0.51193458 0.26159012]
# (1, 4)
#
#
# [[0.48956352 0.51865351]
#  [0.4756076  0.50630295]
#  [0.46547073 0.52337092]
#  [0.48040453 0.53619987]]
# [0.4777616  0.52113181] [0.62067896 0.49870282] [0.56385279 0.51319814]
# (1, 4)
#
#
# [[0.51750159 0.43288341]
#  [0.50608575 0.42153633]
#  [0.49596921 0.43431741]
#  [0.50728893 0.44595331]]
# [0.50671137 0.43367261] [0.64467412 0.42832273] [0.59706801 0.43629116]
# (1, 4)
#
#
# [[0.41928759 0.32577509]
#  [0.40558273 0.3095001 ]
#  [0.39158341 0.32472366]
#  [0.40496126 0.34119684]]
# [0.40535375 0.32529892] [0.56778663 0.33770207] [0.51125062 0.33672148]
# (1, 4)
#
#
# [[0.31703097 0.24515764]
#  [0.30462906 0.23034094]
#  [0.29173046 0.24408919]
#  [0.30389404 0.25936633]]
# [0.30432113 0.24473853] [0.46654695 0.2619366 ] [0.41192898 0.26156762]
# (1, 4)
#
#
# [[0.43373862 0.35435298]
#  [0.41954157 0.34362355]
#  [0.40952557 0.36007959]
#  [0.42364311 0.37122178]]
# [0.42161222 0.35731947] [0.582551   0.32012743] [0.5249753  0.33888263]
# (1, 4)
#
#
# [[0.46322259 0.45723942]
#  [0.44855717 0.44143724]
#  [0.43461794 0.45840991]
#  [0.44929594 0.47499728]]
# [0.44892341 0.45802096] [0.61349601 0.4527908 ] [0.5531472  0.46577179]
# (1, 4)
#
#
# [[0.44154131 0.35808289]
#  [0.4320859  0.3440952 ]
#  [0.42090958 0.35402688]
#  [0.43032277 0.36847657]]
# [0.43121489 0.35617039] [0.57333571 0.39685178] [0.52509201 0.38834411]
# (1, 4)
#
#
# [[0.62519413 0.56059259]
#  [0.61797202 0.5507412 ]
#  [0.60974646 0.55871832]
#  [0.61678451 0.56871915]]
# [0.61742428 0.55969281] [0.73092407 0.57510859] [0.68802053 0.57146657]
# (1, 4)
#
#
# [[0.35971677 0.32957003]
#  [0.34265223 0.31110102]
#  [0.32735622 0.33143133]
#  [0.34440655 0.35044473]]
# [0.34353294 0.33063678] [0.531178   0.32468167] [0.46167073 0.33561125]
# (1, 4)
#
#
# [[0.42676908 0.23812641]
#  [0.41377002 0.22107625]
#  [0.39885047 0.23348376]
#  [0.41195035 0.2509985 ]]
# [0.41283498 0.23592123] [0.58765477 0.28045535] [0.53057313 0.26726925]
# (1, 4)
#
#
# [[0.45798388 0.49605078]
#  [0.44567984 0.48161685]
#  [0.43393594 0.49645227]
#  [0.4461228  0.51150274]]
# [0.44593062 0.49640566] [0.59552282 0.49378046] [0.54281265 0.50385648]
# (1, 4)
#
#
# [[0.47186095 0.35232964]
#  [0.45894644 0.3374157 ]
#  [0.44628039 0.3521333 ]
#  [0.45904535 0.36757681]]
# [0.45903328 0.35236386] [0.62737316 0.35003397] [0.56550783 0.35562187]
# (1, 4)
#
#
# [[0.47050631 0.26880705]
#  [0.4567211  0.24936114]
#  [0.44207317 0.26698053]
#  [0.45687449 0.28748316]]
# [0.45654377 0.26815797] [0.63241076 0.28314328] [0.56504798 0.28946579]
# (1, 4)
#
#
# [[0.45511195 0.5212335 ]
#  [0.44548261 0.50781012]
#  [0.43472254 0.51898056]
#  [0.44409934 0.53272229]]
# [0.44485411 0.52018662] [0.58189714 0.54000598] [0.53177661 0.53782141]
# (1, 4)
#
#
# [[0.27140987 0.3125487 ]
#  [0.26084241 0.29962301]
#  [0.24953891 0.31072867]
#  [0.25997344 0.32409728]]
# [0.26044116 0.31174941] [0.39406079 0.32486063] [0.34702182 0.32731351]
# (1, 4)
#
#
# [[0.49366102 0.24280208]
#  [0.48116687 0.22671974]
#  [0.46789047 0.24153592]
#  [0.4803004  0.25843334]]
# [0.48075469 0.24237277] [0.63396931 0.25387728] [0.57936561 0.25996304]
# (1, 4)
#
#
# [[0.65040529 0.3981508 ]
#  [0.638753   0.38661003]
#  [0.62864882 0.40028256]
#  [0.63999665 0.41206855]]
# [0.63945094 0.39927799] [0.77908629 0.38770616] [0.72500104 0.39406645]
# (1, 4)
#
#
# [[0.53155142 0.39523911]
#  [0.52290165 0.38047361]
#  [0.51061189 0.39005521]
#  [0.51938272 0.40531009]]
# [0.52111192 0.39276951] [0.65811014 0.43696421] [0.61239314 0.42027512]
# (1, 4)
#
#
# [[0.44281548 0.58305687]
#  [0.42852014 0.56592619]
#  [0.41456553 0.58275598]
#  [0.4287788  0.60057437]]
# [0.42866999 0.58307835] [0.60647476 0.58378261] [0.53937376 0.59638923]
# (1, 4)
#
#
# [[0.49267504 0.34675089]
#  [0.48275277 0.33373481]
#  [0.47186333 0.34512803]
#  [0.48160356 0.35834521]]
# [0.48222367 0.34598973] [0.63171744 0.36557996] [0.57464421 0.35430285]
# (1, 4)
#
#
# [[0.37501574 0.48015457]
#  [0.3579284  0.46157289]
#  [0.34106085 0.4797875 ]
#  [0.35806975 0.49870756]]
# [0.35801868 0.48005563] [0.56165069 0.48430732] [0.48344728 0.48482293]
# (1, 4)
#
#
# [[0.43929842 0.52776909]
#  [0.42462102 0.50887448]
#  [0.40887645 0.52590734]
#  [0.42347887 0.54584587]]
# [0.42406869 0.52709919] [0.60110086 0.53582013] [0.53337711 0.54535198]
# (1, 4)
#
#
# [[0.64399016 0.285739  ]
#  [0.62852412 0.26553679]
#  [0.61114573 0.28219226]
#  [0.62657809 0.3028048 ]]
# [0.62755953 0.28406821] [0.81494081 0.29898298] [0.75211024 0.3048602 ]
# (1, 4)
#
#
# [[0.409688   0.24009044]
#  [0.39210847 0.22776826]
#  [0.38014859 0.24768905]
#  [0.39758468 0.26056528]]
# [0.39488243 0.24402826] [0.58830774 0.20192324] [0.52336878 0.22052191]
# (1, 4)
#
#
# [[0.48363516 0.53256959]
#  [0.47458366 0.52012622]
#  [0.46443161 0.53106475]
#  [0.47367081 0.54393679]]
# [0.47408031 0.53192434] [0.57905775 0.54095244] [0.5428673  0.54477191]
# (1, 4)
#
#
# [[0.50299579 0.36718044]
#  [0.4916122  0.35546222]
#  [0.48149788 0.36825907]
#  [0.49273068 0.38020599]]
# [0.49220914 0.36777693] [0.62520558 0.35832369] [0.57747883 0.3676528 ]
# (1, 4)
#
#
# [[0.44816646 0.42429632]
#  [0.4398109  0.41512412]
#  [0.43156615 0.42443597]
#  [0.43977073 0.43369266]]
# [0.43982856 0.42438727] [0.55889034 0.42401692] [0.51670837 0.42484349]
# (1, 4)
#
#
# [[0.4901084  0.36113   ]
#  [0.47654858 0.34450483]
#  [0.46302602 0.36081702]
#  [0.47636816 0.37808228]]
# [0.47651279 0.36113353] [0.64769    0.36891669] [0.58256114 0.37639251]
# (1, 4)
#
#
# [[0.49550849 0.30632028]
#  [0.48378828 0.29191008]
#  [0.47125864 0.30420235]
#  [0.48283565 0.31890264]]
# [0.48334777 0.30533384] [0.65213102 0.31724286] [0.58776277 0.31064412]
# (1, 4)
#
#
# [[0.48716733 0.47670102]
#  [0.47440952 0.46443635]
#  [0.46421507 0.47895348]
#  [0.4774662  0.49173295]]
# [0.47581453 0.47795595] [0.61888969 0.47121429] [0.56773096 0.48044342]
# (1, 4)
#
#
# [[0.48390174 0.27797779]
#  [0.47237873 0.26463091]
#  [0.46125293 0.27868009]
#  [0.47285458 0.292696  ]]
# [0.472597  0.2784962] [0.61072242 0.27886739] [0.56083715 0.28763863]
# (1, 4)
#
#
# [[0.49513322 0.43971708]
#  [0.48176071 0.42745116]
#  [0.47061059 0.44297621]
#  [0.48379147 0.45582137]]
# [0.482824   0.44149145] [0.62983382 0.42505443] [0.57758784 0.43820754]
# (1, 4)
#
#
# [[0.49595135 0.42651391]
#  [0.48575479 0.41579473]
#  [0.47627071 0.42724061]
#  [0.4863812  0.43818733]]
# [0.48608951 0.42693415] [0.62210572 0.42572281] [0.56969988 0.42280459]
# (1, 4)
#
#
# [[0.45106289 0.28403667]
#  [0.43426186 0.26589957]
#  [0.41811481 0.2845456 ]
#  [0.43496281 0.30311808]]
# [0.43460059 0.28439998] [0.64480495 0.2840277 ] [0.57148242 0.28746259]
# (1, 4)
#
#
# [[0.43172789 0.48798382]
#  [0.42003357 0.48119491]
#  [0.41280231 0.49478891]
#  [0.42428458 0.50185865]]
# [0.42221209 0.49145658] [0.55418783 0.45443371] [0.50518793 0.46696943]
# (1, 4)
#
#
# [[0.42209804 0.55329585]
#  [0.4001247  0.52787977]
#  [0.37837726 0.55360675]
#  [0.40044132 0.58040643]]
# [0.40026033 0.5537972 ] [0.64930379 0.54979581] [0.55704081 0.56748593]
# (1, 4)
#
#
# [[0.50517446 0.41584188]
#  [0.49115425 0.40159982]
#  [0.47840121 0.41786236]
#  [0.49245754 0.43274701]]
# [0.49179687 0.41701277] [0.65186697 0.41557175] [0.5907976  0.42171592]
# (1, 4)
#
#
# [[0.54038697 0.5076499 ]
#  [0.5251596  0.49306911]
#  [0.51219273 0.51036727]
#  [0.52733165 0.5255959 ]]
# [0.52626774 0.50917055] [0.6907903  0.49583626] [0.62915319 0.50862873]
# (1, 4)
#
#
# [[0.26310298 0.30494821]
#  [0.24555305 0.29239327]
#  [0.23463802 0.3138147 ]
#  [0.25198299 0.3268553 ]]
# [0.24881926 0.30950287] [0.42577213 0.25403941] [0.35817179 0.28344429]
# (1, 4)
#
#
# [[0.48224118 0.38248315]
#  [0.47127217 0.373537  ]
#  [0.46290284 0.38626599]
#  [0.47351974 0.39575016]]
# [0.47248399 0.38450908] [0.62383533 0.3567071 ] [0.56987822 0.36693826]
# (1, 4)
#
#
# [[0.47001788 0.35733569]
#  [0.45903379 0.34752589]
#  [0.45025027 0.36096695]
#  [0.46112889 0.37099242]]
# [0.46010771 0.35920524] [0.5762921 0.3369624] [0.53282106 0.35193995]
# (1, 4)
#
#
# [[0.47895086 0.40880048]
#  [0.46286845 0.39273643]
#  [0.44860941 0.41152847]
#  [0.46486822 0.42815754]]
# [0.46382423 0.41030573] [0.63409871 0.39876068] [0.5731566  0.40799272]
# (1, 4)
#
#
# [[0.53801173 0.40443844]
#  [0.524665   0.38898528]
#  [0.5125246  0.40584654]
#  [0.52567929 0.42176318]]
# [0.52522016 0.40525836] [0.67130983 0.40068603] [0.61822891 0.41080272]
# (1, 4)
#
#
# [[0.50227112 0.37816802]
#  [0.4939571  0.37026906]
#  [0.48612392 0.37950557]
#  [0.49426922 0.38743836]]
# [0.49415534 0.37884525] [0.60020906 0.37306124] [0.56256807 0.3750931 ]
# (1, 4)
#
#
# [[0.41153085 0.47723275]
#  [0.39925933 0.46671265]
#  [0.39015508 0.48210174]
#  [0.40236074 0.49309751]]
# [0.4008265  0.47978617] [0.52787125 0.4544332 ] [0.48226562 0.46919784]
# (1, 4)
#
#
# [[0.48737776 0.47004965]
#  [0.4754189  0.4543494 ]
#  [0.46200171 0.46741787]
#  [0.47387022 0.48366779]]
# [0.47466715 0.46887118] [0.6297313  0.48860526] [0.57179433 0.48924315]
# (1, 4)
#
#
# [[0.45721036 0.38663059]
#  [0.44489342 0.37463045]
#  [0.43447128 0.38864911]
#  [0.44664273 0.4009653 ]]
# [0.44580445 0.38771886] [0.60918081 0.3757658 ] [0.54719293 0.38127342]
# (1, 4)
#
#
# [[0.51386833 0.47875869]
#  [0.50206852 0.46210819]
#  [0.48768649 0.47478014]
#  [0.49934858 0.49208093]]
# [0.50074298 0.47693199] [0.65071201 0.50890505] [0.59668481 0.5042457 ]
# (1, 4)
#
#
# [[0.43865377 0.37401053]
#  [0.43082595 0.36522564]
#  [0.42331177 0.3742426 ]
#  [0.43112862 0.38336033]]
# [0.43098003 0.37420978] [0.51867175 0.37999651] [0.48698577 0.37925673]
# (1, 4)
#
#
# [[0.41439915 0.36015102]
#  [0.39850289 0.34283486]
#  [0.38426131 0.36274058]
#  [0.40017605 0.38095084]]
# [0.39933485 0.36166932] [0.58483571 0.34669626] [0.52272463 0.36627588]
# (1, 4)
#
#
# [[0.51890367 0.40909308]
#  [0.50805557 0.39654535]
#  [0.49646723 0.40775076]
#  [0.50710398 0.42057678]]
# [0.50763261 0.40849149] [0.65147543 0.41800815] [0.60161787 0.42137927]
# (1, 4)
#
#
# [[0.29000202 0.51424527]
#  [0.27279854 0.49363703]
#  [0.25722694 0.51716429]
#  [0.27386427 0.53871596]]
# [0.27347294 0.51594064] [0.5274778  0.50115985] [0.43967533 0.51865584]
# (1, 4)
#
#
# [[0.48197737 0.55200708]
#  [0.4691011  0.53487587]
#  [0.45567012 0.55065012]
#  [0.46833742 0.56820184]]
# [0.4687715  0.55143373] [0.63572419 0.55286384] [0.57836658 0.56227714]
# (1, 4)
#
#
# [[0.38008204 0.31388807]
#  [0.36777395 0.29810366]
#  [0.35587099 0.31330901]
#  [0.36790156 0.32932103]]
# [0.36790714 0.31365544] [0.55185187 0.31719065] [0.47542718 0.31754178]
# (1, 4)
#
#
# [[0.47747755 0.41626757]
#  [0.46403807 0.40162241]
#  [0.45073482 0.41493106]
#  [0.46405268 0.43003213]]
# [0.46407578 0.4157133 ] [0.65026939 0.42655307] [0.58342934 0.42248058]
# (1, 4)
#
#
# [[0.43875688 0.33983928]
#  [0.42649215 0.32400057]
#  [0.41344368 0.33862245]
#  [0.42552584 0.35489008]]
# [0.42605464 0.33933809] [0.57836401 0.34895897] [0.52329057 0.35404992]
# (1, 4)
#
#
# [[0.36380622 0.48559785]
#  [0.35025397 0.47062624]
#  [0.33784828 0.48736602]
#  [0.35137489 0.50312364]]
# [0.35082084 0.48667844] [0.50083715 0.47629446] [0.44570681 0.4904125 ]
# (1, 4)
#
#
# [[0.54580659 0.43635139]
#  [0.5265941  0.41230929]
#  [0.50754595 0.43637681]
#  [0.52670515 0.46128982]]
# [0.52666295 0.43658183] [0.74658632 0.43159544] [0.66657817 0.44604582]
# (1, 4)
#
#
# [[0.47441339 0.21441299]
#  [0.45983237 0.19986819]
#  [0.44628707 0.21505557]
#  [0.46057254 0.23015717]]
# [0.46027634 0.21487348] [0.63955528 0.22251724] [0.57732189 0.22439705]
# (1, 4)
#
#
# [[0.37430862 0.11043919]
#  [0.36166269 0.09353784]
#  [0.3476119  0.10811855]
#  [0.36012754 0.12552157]]
# [0.36092769 0.10940429] [0.52510822 0.12458817] [0.46222657 0.13002616]
# (1, 4)
#
#
# [[0.45735806 0.44323865]
#  [0.44236916 0.42845041]
#  [0.42866307 0.4449881 ]
#  [0.44365394 0.46041432]]
# [0.44301106 0.44427287] [0.61756968 0.43296114] [0.55515844 0.44333547]
# (1, 4)
#
#
# [[0.61710876 0.56710052]
#  [0.60110867 0.5497703 ]
#  [0.58668095 0.56918907]
#  [0.60260034 0.58730513]]
# [0.60187468 0.56834126] [0.79978478 0.5556283 ] [0.72667927 0.57277167]
# (1, 4)
#
#
# [[0.63803595 0.34947944]
#  [0.62508154 0.33134806]
#  [0.60914844 0.34435964]
#  [0.62211746 0.36298683]]
# [0.62359585 0.34704349] [0.80547011 0.39650589] [0.74843711 0.38439912]
# (1, 4)
#
#
# [[0.52675331 0.46788761]
#  [0.51867747 0.45945558]
#  [0.51192343 0.46949422]
#  [0.51969451 0.47838339]]
# [0.51926218 0.4688052 ] [0.62049508 0.4554953 ] [0.58578324 0.46501657]
# (1, 4)
#
#
# [[0.56510425 0.34293544]
#  [0.55474949 0.33368731]
#  [0.5466643  0.34586751]
#  [0.55701339 0.35546297]]
# [0.55588286 0.34448831] [0.66928953 0.32927328] [0.62882882 0.33885211]
# (1, 4)
#
#
# [[0.48021731 0.31758922]
#  [0.47120517 0.3036539 ]
#  [0.4594748  0.31293714]
#  [0.4682835  0.32724077]]
# [0.4697952  0.31535526] [0.59589934 0.35309061] [0.55062097 0.3381373 ]
# (1, 4)
#
#
# [[0.44274187 0.43351549]
#  [0.42938617 0.42419505]
#  [0.42071491 0.44004458]
#  [0.43389243 0.44984928]]
# [0.43168385 0.4369011 ] [0.58478618 0.39663479] [0.53064662 0.41547251]
# (1, 4)
#
#
# [[0.42433712 0.33214021]
#  [0.40744215 0.32070509]
#  [0.396339   0.33956909]
#  [0.41281617 0.3513816 ]]
# [0.41023361 0.335949  ] [0.58772773 0.28975493] [0.52361006 0.30912179]
# (1, 4)
#
#
# [[0.51700073 0.53153068]
#  [0.50688815 0.52015388]
#  [0.49651784 0.53050071]
#  [0.50637031 0.54208362]]
# [0.50669426 0.53106722] [0.64889175 0.5285821 ] [0.59719247 0.53166014]
# (1, 4)
#
#
# [[0.45147973 0.53460872]
#  [0.43633127 0.52059639]
#  [0.42395467 0.53824615]
#  [0.43896735 0.55259085]]
# [0.43768325 0.53651053] [0.60027635 0.51670569] [0.54000187 0.53248894]
# (1, 4)
#
#
# [[0.48878583 0.5046066 ]
#  [0.47625253 0.49251145]
#  [0.4654277  0.50641328]
#  [0.47787341 0.51888448]]
# [0.47708487 0.50560395] [0.63817447 0.48412013] [0.58093596 0.49574333]
# (1, 4)
#
#
# [[0.41824466 0.36850771]
#  [0.40220454 0.3503108 ]
#  [0.38686427 0.36955583]
#  [0.40282151 0.38818976]]
# [0.40253375 0.36914103] [0.59153283 0.3639417 ] [0.5273968  0.37922546]
# (1, 4)
#
#
# [[0.53438121 0.41889393]
#  [0.52473474 0.40289131]
#  [0.51173145 0.41350397]
#  [0.52124488 0.43015555]]
# [0.52302307 0.41636119] [0.66403973 0.45618311] [0.61553228 0.44445181]
# (1, 4)
#
#
# [[0.39861384 0.32954639]
#  [0.3775655  0.3107793 ]
#  [0.35885769 0.33313602]
#  [0.37971774 0.35231692]]
# [0.37868869 0.33144466] [0.6439895  0.32035959] [0.55605108 0.32313144]
# (1, 4)
#
#
# [[0.38914686 0.54540175]
#  [0.37480849 0.5309236 ]
#  [0.36150151 0.54679918]
#  [0.37560219 0.56175715]]
# [0.37526476 0.54622042] [0.57543021 0.53045857] [0.50106657 0.54076993]
# (1, 4)
#
#
# [[0.46770754 0.35745928]
#  [0.45944417 0.34848303]
#  [0.45166889 0.35756087]
#  [0.45980659 0.36670947]]
# [0.4596568  0.35755316] [0.57186139 0.36770475] [0.52845502 0.35930264]
# (1, 4)
#
#
# [[0.5400697  0.54281139]
#  [0.5233658  0.52554053]
#  [0.50837994 0.5452562 ]
#  [0.52515757 0.56293762]]
# [0.52424325 0.54413643] [0.70051253 0.53804106] [0.63527    0.54677773]
# (1, 4)
#
#
# [[0.3204155  0.39279866]
#  [0.3074711  0.37482202]
#  [0.29357374 0.39266986]
#  [0.30621442 0.41129529]]
# [0.30691869 0.39289646] [0.49976051 0.40702781] [0.42955545 0.40884399]
# (1, 4)
#
#
# [[0.49462527 0.57765865]
#  [0.48100135 0.56271178]
#  [0.4677484  0.57761139]
#  [0.48086932 0.59335184]]
# [0.48106109 0.57783341] [0.6450268  0.58420229] [0.59323668 0.59309793]
# (1, 4)
#
#
# [[0.44705814 0.47020185]
#  [0.42949039 0.45864403]
#  [0.41873267 0.48005408]
#  [0.43628168 0.49215367]]
# [0.43289072 0.47526341] [0.59810841 0.42075425] [0.54137111 0.44803602]
# (1, 4)
#
#
# [[0.45054284 0.39431617]
#  [0.44248644 0.3854211 ]
#  [0.43438238 0.39275151]
#  [0.44223213 0.40206423]]
# [0.44241095 0.39363825] [0.55864316 0.40994918] [0.51804113 0.40414798]
# (1, 4)
#
#
# [[0.43833232 0.4438639 ]
#  [0.4311474  0.43540663]
#  [0.42404589 0.44408447]
#  [0.43108711 0.45281553]]
# [0.43115318 0.44404263] [0.53703463 0.44689626] [0.49884453 0.44847217]
# (1, 4)
#
#
# [[0.56028491 0.37386179]
#  [0.55080712 0.36118031]
#  [0.54008049 0.37037921]
#  [0.54930562 0.38337004]]
# [0.55011953 0.37219784] [0.67370832 0.39614356] [0.63106221 0.39366844]
# (1, 4)
#
#
# [[0.45519495 0.47456086]
#  [0.44447106 0.45857802]
#  [0.43238154 0.47201556]
#  [0.44356045 0.4888202 ]]
# [0.443902   0.47349366] [0.58272374 0.49273279] [0.52964032 0.49058142]
# (1, 4)
#
#
# [[0.40018764 0.41978058]
#  [0.38620281 0.40242431]
#  [0.3719629  0.41930187]
#  [0.38570219 0.43755606]]
# [0.38601389 0.4197657 ] [0.5620929  0.42002213] [0.49830177 0.43606651]
# (1, 4)
#
#
# [[0.51673168 0.56595409]
#  [0.50101942 0.54553235]
#  [0.4839465  0.56420189]
#  [0.49965164 0.58534658]]
# [0.50033731 0.56525873] [0.69732326 0.56283993] [0.62984931 0.57672888]
# (1, 4)
#
#
# [[0.48764211 0.27776477]
#  [0.47213316 0.25821275]
#  [0.45571661 0.27707487]
#  [0.47136268 0.29738042]]
# [0.47171364 0.2776082 ] [0.66861719 0.28072146] [0.60071224 0.29297441]
# (1, 4)
#
#
# [[0.44071683 0.53811181]
#  [0.42790908 0.52659363]
#  [0.41832137 0.54261017]
#  [0.43081236 0.5546158 ]]
# [0.42943991 0.54048285] [0.59017289 0.51375544] [0.53464341 0.52976024]
# (1, 4)
#
#
# [[0.50979143 0.41547975]
#  [0.50027168 0.40636572]
#  [0.49159956 0.41659147]
#  [0.50089955 0.42580116]]
# [0.50064056 0.41605952] [0.62179244 0.41832173] [0.5782187  0.41331026]
# (1, 4)
#
#
# [[0.50769269 0.4344022 ]
#  [0.49348995 0.42255658]
#  [0.48209026 0.43889454]
#  [0.49628747 0.45136255]]
# [0.49489009 0.43680397] [0.64340603 0.4166683 ] [0.58623093 0.43004909]
# (1, 4)
#
#
# [[0.50423366 0.38190281]
#  [0.49524865 0.37119064]
#  [0.48648998 0.38169184]
#  [0.49536076 0.39274594]]
# [0.49533326 0.38188281] [0.60408616 0.38190407] [0.563245   0.38781935]
# (1, 4)
#
#
# [[0.55377436 0.222745  ]
#  [0.5440408  0.20895012]
#  [0.5327273  0.22084655]
#  [0.54152858 0.23505525]]
# [0.54301776 0.22189923] [0.71304947 0.25593221] [0.65486902 0.24965166]
# (1, 4)
#
#
# [[0.36960667 0.49778759]
#  [0.35623235 0.49009132]
#  [0.34822905 0.50592631]
#  [0.3613033  0.51404172]]
# [0.35884284 0.50196174] [0.50142837 0.45607549] [0.44947758 0.47261938]
# (1, 4)
#
#
# [[0.48872212 0.44146329]
#  [0.47721249 0.42933267]
#  [0.46560013 0.44079691]
#  [0.47688782 0.45308912]]
# [0.47710564 0.4411705 ] [0.62262774 0.45517051] [0.57151693 0.44831216]
# (1, 4)
#
#
# [[0.52517098 0.5097124 ]
#  [0.51254433 0.50067323]
#  [0.50410545 0.51542729]
#  [0.51653337 0.52475429]]
# [0.51458853 0.5126418 ] [0.66861862 0.47988349] [0.60918885 0.490309  ]
# (1, 4)
#
#
# [[0.46560392 0.44522834]
#  [0.45111209 0.42804289]
#  [0.43582109 0.44372749]
#  [0.45024836 0.46136165]]
# [0.45069636 0.44459009] [0.63838381 0.45523077] [0.57415795 0.45771408]
# (1, 4)
#
#
# [[0.42380598 0.42222568]
#  [0.40913236 0.40854019]
#  [0.39801708 0.42697948]
#  [0.41266638 0.44151407]]
# [0.41090545 0.42481486] [0.56433433 0.40056711] [0.50674069 0.41866407]
# (1, 4)
#
#
# [[0.43120193 0.50432366]
#  [0.41888452 0.49282488]
#  [0.4089874  0.50801063]
#  [0.42126483 0.52005738]]
# [0.42008467 0.50630414] [0.54967964 0.48993069] [0.50286239 0.50167769]
# (1, 4)
#
#
# [[0.41687784 0.38108021]
#  [0.40129399 0.37014824]
#  [0.39071539 0.38827631]
#  [0.40610337 0.39983004]]
# [0.40374765 0.3848337 ] [0.57370561 0.33776951] [0.51230061 0.36188665]
# (1, 4)
#
#
# [[0.3296189  0.42232424]
#  [0.31561416 0.40896994]
#  [0.3036671  0.42523405]
#  [0.31756973 0.43895987]]
# [0.31661747 0.42387202] [0.47263381 0.41702127] [0.41596305 0.42575237]
# (1, 4)
#
#
# [[0.63292903 0.40508461]
#  [0.60895413 0.37561125]
#  [0.58408606 0.40196219]
#  [0.60781181 0.43186647]]
# [0.60844526 0.40363113] [0.891868  0.4314625] [0.79309022 0.43247288]
# (1, 4)
#
#
# [[0.33832151 0.5295105 ]
#  [0.32338226 0.51826686]
#  [0.31279302 0.53582633]
#  [0.32750899 0.54773962]]
# [0.32550144 0.53283583] [0.4910621 0.493132 ] [0.43272698 0.51421255]
# (1, 4)
#
#
# [[0.37513307 0.45403701]
#  [0.36289489 0.4414227 ]
#  [0.35176036 0.45557213]
#  [0.3637051  0.46852267]]
# [0.36337335 0.45488863] [0.55001664 0.44604641] [0.4795506  0.44714096]
# (1, 4)
#
#
# [[0.49602917 0.44768173]
#  [0.48308626 0.42850864]
#  [0.46673802 0.44200802]
#  [0.479496   0.46171114]]
# [0.48133736 0.44497738] [0.64728808 0.49017876] [0.58781153 0.47844845]
# (1, 4)
#
#
# [[0.46044311 0.31227091]
#  [0.4473407  0.29206443]
#  [0.43074924 0.30761179]
#  [0.4441137  0.32853967]]
# [0.44566169 0.3101217 ] [0.61609316 0.33550584] [0.55443776 0.33637288]
# (1, 4)
#
#
# [[0.41704154 0.39973703]
#  [0.40345439 0.3833853 ]
#  [0.39015853 0.39981261]
#  [0.40355849 0.41697699]]
# [0.40355324 0.39997798] [0.57353318 0.39682892] [0.51277059 0.41226703]
# (1, 4)
#
#
# [[0.46407208 0.46522671]
#  [0.45319375 0.45294303]
#  [0.4432753  0.46613142]
#  [0.45392752 0.47874835]]
# [0.45361716 0.46576238] [0.5927524  0.46570933] [0.54502916 0.47352368]
# (1, 4)
#
#
# [[0.34135583 0.51525867]
#  [0.326132   0.49900818]
#  [0.31172538 0.51646656]
#  [0.326888   0.53324127]]
# [0.3265253  0.51599367] [0.52644348 0.51365697] [0.44963852 0.51413459]
# (1, 4)
#
#
# [[0.47368473 0.41144985]
#  [0.4594321  0.39479524]
#  [0.44512168 0.41125244]
#  [0.45946878 0.42833719]]
# [0.45942682 0.41145868] [0.62691045 0.41449273] [0.5653044 0.4214029]
# (1, 4)
#
#
# [[0.53410268 0.56320947]
#  [0.51983768 0.54534554]
#  [0.50468922 0.56163657]
#  [0.51913589 0.58010924]]
# [0.51944137 0.56257521] [0.6820699  0.57079393] [0.62214005 0.57515448]
# (1, 4)
#
#
# [[0.40761828 0.33154055]
#  [0.39033014 0.31823707]
#  [0.37711522 0.33714712]
#  [0.39400589 0.35082263]]
# [0.39226738 0.33443684] [0.61409277 0.31139711] [0.53835833 0.31723377]
# (1, 4)
#
#
# [[0.42547578 0.53032541]
#  [0.4097161  0.51101577]
#  [0.39322171 0.52834666]
#  [0.40875423 0.54851282]]
# [0.40929195 0.52955016] [0.60805649 0.5390873 ] [0.53346592 0.54858655]
# (1, 4)
#
#
# [[0.48156148 0.30352157]
#  [0.46444812 0.28446978]
#  [0.44670942 0.30188292]
#  [0.46375299 0.32152247]]
# [0.464118   0.30284919] [0.66490531 0.31088462] [0.5925554  0.31964791]
# (1, 4)
#
#
# [[0.51479816 0.42528856]
#  [0.50326967 0.40951568]
#  [0.49046201 0.42313796]
#  [0.50168663 0.43993619]]
# [0.50255412 0.4244696 ] [0.66005391 0.44171593] [0.60343373 0.44515544]
# (1, 4)
#
#
# [[0.24461234 0.24664247]
#  [0.22623184 0.23860492]
#  [0.21675381 0.2602835 ]
#  [0.23488471 0.26892138]]
# [0.23062067 0.25361307] [0.4127146  0.16874214] [0.35007298 0.20041688]
# (1, 4)
#
#
# [[0.54635912 0.49323261]
#  [0.53717035 0.48410964]
#  [0.52942121 0.49484313]
#  [0.53860402 0.50437558]]
# [0.53788868 0.49414024] [0.63620681 0.48223603] [0.60055083 0.49275693]
# (1, 4)
#
#
# [[0.48189721 0.33679315]
#  [0.4713546  0.32422242]
#  [0.4608297  0.33612671]
#  [0.47125739 0.34904066]]
# [0.47133473 0.33654574] [0.6007989  0.34351587] [0.55645978 0.3468371 ]
# (1, 4)
#
#
# [[0.46622741 0.39236286]
#  [0.4522371  0.37369639]
#  [0.43696734 0.39033985]
#  [0.45078367 0.40952757]]
# [0.45155388 0.39148167] [0.63431782 0.39919958] [0.56602615 0.40674952]
# (1, 4)
#
#
# [[0.34451377 0.34748617]
#  [0.33230636 0.33158675]
#  [0.31896484 0.34526718]
#  [0.33115378 0.36127293]]
# [0.33173469 0.34640326] [0.49888015 0.3661249 ] [0.44101152 0.35821325]
# (1, 4)
#
#
# [[0.52083343 0.57414079]
#  [0.51012754 0.55951643]
#  [0.49839222 0.57196641]
#  [0.50896132 0.58719492]]
# [0.50957863 0.57320464] [0.65481961 0.59206426] [0.60513061 0.59130496]
# (1, 4)
#
#
# [[0.48133647 0.50267279]
#  [0.46927676 0.4914155 ]
#  [0.45914748 0.5047279 ]
#  [0.47105336 0.51637095]]
# [0.47020352 0.50379679] [0.61598939 0.48638877] [0.56474608 0.49726313]
# (1, 4)
#
#
# [[0.51230001 0.21503922]
#  [0.50029242 0.19935584]
#  [0.48740736 0.21346332]
#  [0.49935114 0.22986427]]
# [0.49983773 0.21443066] [0.64645255 0.22585677] [0.5920645  0.23138866]
# (1, 4)
#
#
# [[0.52847934 0.50068122]
#  [0.51464123 0.48578608]
#  [0.50245059 0.50283092]
#  [0.51601821 0.51830316]]
# [0.51539734 0.50190035] [0.67076409 0.48922634] [0.60941631 0.50307328]
# (1, 4)
#
#
# [[0.39901513 0.37799335]
#  [0.38844278 0.36566931]
#  [0.37781015 0.37728038]
#  [0.38843355 0.38998026]]
# [0.3884254  0.37773082] [0.53075355 0.39742351] [0.48262817 0.3877809 ]
# (1, 4)
#
#
# [[0.50320965 0.33397877]
#  [0.49318174 0.32256401]
#  [0.48289672 0.33356318]
#  [0.4928433  0.34528613]]
# [0.49303285 0.33384802] [0.61617929 0.34199941] [0.57028598 0.34012365]
# (1, 4)
#
#
# [[0.40709513 0.51137894]
#  [0.39132711 0.49420726]
#  [0.37648392 0.51239073]
#  [0.39222547 0.53030735]]
# [0.39178291 0.51207107] [0.56987488 0.50337481] [0.49764019 0.51785296]
# (1, 4)
#
#
# [[0.4996939  0.56310487]
#  [0.48668748 0.54853076]
#  [0.47471359 0.5642153 ]
#  [0.48778409 0.57935327]]
# [0.48721977 0.56380105] [0.63788873 0.55189681] [0.58130985 0.56874883]
# (1, 4)
#
#
# [[0.16544846 0.34665918]
#  [0.15275219 0.33358884]
#  [0.14078154 0.34709561]
#  [0.15331715 0.36054611]]
# [0.15307483 0.34697244] [0.31363499 0.34663737] [0.25754142 0.35128814]
# (1, 4)
#
#
# [[0.35058892 0.21970133]
#  [0.33715063 0.19592412]
#  [0.31898925 0.21237366]
#  [0.33280361 0.23713624]]
# [0.3348831  0.21628384] [0.52344549 0.26593512] [0.45154011 0.25739467]
# (1, 4)
#
#
# [[0.5025062  0.51977932]
#  [0.49082267 0.50301033]
#  [0.4771955  0.51718974]
#  [0.48895243 0.53452003]]
# [0.4898692  0.51862486] [0.65770036 0.54395533] [0.59657443 0.53175026]
# (1, 4)
#
#
# [[0.49195758 0.43046969]
#  [0.48449159 0.42232376]
#  [0.47717601 0.43069834]
#  [0.4845303  0.43919289]]
# [0.48453887 0.43067117] [0.6011216 0.4323262] [0.55810124 0.43162185]
# (1, 4)
#
#
# [[0.44539389 0.47037408]
#  [0.43825439 0.46208984]
#  [0.43112376 0.47032794]
#  [0.43819302 0.47893044]]
# [0.43824127 0.47043058] [0.54721373 0.47162122] [0.50805002 0.4714188 ]
# (1, 4)
#
#
# [[0.54312062 0.21589729]
#  [0.53435576 0.207058  ]
#  [0.52606046 0.21578074]
#  [0.53470266 0.22512135]]
# [0.53455988 0.21596434] [0.65589672 0.22923079] [0.61152637 0.22355738]
# (1, 4)
#
#
# [[0.58607239 0.4022409 ]
#  [0.56976384 0.38013709]
#  [0.55107266 0.39766866]
#  [0.56699878 0.42003596]]
# [0.56847692 0.40002065] [0.77800894 0.42590687] [0.70586938 0.43096673]
# (1, 4)
#
#
# [[0.42030096 0.47637394]
#  [0.40806705 0.46192375]
#  [0.39599511 0.47594577]
#  [0.40806317 0.49080878]]
# [0.40810657 0.47626306] [0.55419695 0.48202932] [0.50263804 0.48575187]
# (1, 4)
#
#
# [[0.5822649  0.47653335]
#  [0.566966   0.45950693]
#  [0.55244613 0.47789168]
#  [0.5677039  0.49539363]]
# [0.56734523 0.4773314 ] [0.74551183 0.45638877] [0.68773353 0.47579455]
# (1, 4)
#
#
# [[0.35921821 0.3427541 ]
#  [0.34227926 0.32383582]
#  [0.32701898 0.34403256]
#  [0.34393752 0.36358589]]
# [0.34311349 0.34355209] [0.53121108 0.34095412] [0.46193841 0.35064697]
# (1, 4)
#
#
# [[0.51889616 0.32934609]
#  [0.50960404 0.3186273 ]
#  [0.50023329 0.32910237]
#  [0.50936693 0.34021693]]
# [0.50952511 0.32932317] [0.62584347 0.34151718] [0.58340138 0.33972904]
# (1, 4)
#
#
# [[0.52732438 0.41133386]
#  [0.51795232 0.39943916]
#  [0.508946   0.41171342]
#  [0.51828933 0.4239068 ]]
# [0.51812801 0.41159831] [0.64997995 0.40823171] [0.60922754 0.41438067]
# (1, 4)
#
#
# [[0.48401845 0.50517172]
#  [0.47306409 0.49302098]
#  [0.46269798 0.50561637]
#  [0.47358647 0.51849663]]
# [0.47334175 0.50557642] [0.60587168 0.50240421] [0.56390983 0.51182169]
# (1, 4)
#
#
# [[0.4887538  0.52324659]
#  [0.48031387 0.51339668]
#  [0.47186404 0.52335185]
#  [0.48033112 0.53352201]]
# [0.48031571 0.52337928] [0.57808989 0.52299649] [0.54333049 0.5285002 ]
# (1, 4)
#
#
# [[0.51434505 0.39012909]
#  [0.50564736 0.38118038]
#  [0.4975507  0.39052927]
#  [0.50607765 0.39951169]]
# [0.50590519 0.39033761] [0.61391956 0.38597292] [0.57632899 0.39103428]
# (1, 4)
#
#
# [[0.54582429 0.20517018]
#  [0.53511572 0.19562875]
#  [0.52576935 0.20562097]
#  [0.53629977 0.21535066]]
# [0.53575228 0.20544264] [0.67851877 0.22342139] [0.63235956 0.21422789]
# (1, 4)
#
#
# [[0.49457839 0.40772191]
#  [0.4846043  0.39585125]
#  [0.47358212 0.40566516]
#  [0.48331353 0.41774857]]
# [0.48401958 0.40674672] [0.61256999 0.42384183] [0.5651567  0.42234153]
# (1, 4)
#
#
# [[0.41081902 0.19415942]
#  [0.39553344 0.17342873]
#  [0.37726858 0.18909632]
#  [0.39241916 0.21065716]]
# [0.39401005 0.19183541] [0.58551276 0.22042394] [0.51438236 0.22361118]
# (1, 4)
#
#
# [[0.4833107  0.40518099]
#  [0.46945137 0.3900494 ]
#  [0.45595911 0.40604156]
#  [0.46994162 0.42197475]]
# [0.4696657  0.40581167] [0.62810034 0.40192351] [0.56933194 0.41329628]
# (1, 4)
#
#
# [[0.40634575 0.43091995]
#  [0.39122528 0.41639134]
#  [0.37839699 0.43454218]
#  [0.39366063 0.44955188]]
# [0.39240716 0.43285134] [0.55712396 0.41774318] [0.49843654 0.42827877]
# (1, 4)
#
#
# [[0.40369868 0.43906569]
#  [0.39324713 0.42957646]
#  [0.38514262 0.44271058]
#  [0.3956838  0.45274401]]
# [0.39444306 0.44102418] [0.50044829 0.41831714] [0.46385822 0.43258685]
# (1, 4)
#
#
# [[0.41552463 0.33730242]
#  [0.40577057 0.328253  ]
#  [0.39747283 0.33936822]
#  [0.40702802 0.34885544]]
# [0.40644901 0.33844477] [0.5402168  0.32412243] [0.49195427 0.33108455]
# (1, 4)
#
#
# [[0.49606138 0.42395926]
#  [0.48510849 0.41363087]
#  [0.47559333 0.42534918]
#  [0.48649174 0.43591434]]
# [0.48581374 0.42471341] [0.6251334 0.4214336] [0.57585841 0.42293572]
# (1, 4)
#
#
# [[0.43449068 0.38640317]
#  [0.41948375 0.37325299]
#  [0.40733722 0.39073822]
#  [0.42242825 0.40441519]]
# [0.42093498 0.38870239] [0.57582325 0.36267421] [0.5150423  0.38014549]
# (1, 4)
#
#
# [[0.45113868 0.46819544]
#  [0.4367674  0.45007414]
#  [0.42228085 0.46797299]
#  [0.43625146 0.48662561]]
# [0.4366096  0.46821705] [0.64063281 0.47042313] [0.56842226 0.47657824]
# (1, 4)
#
#
# [[0.38436842 0.31124157]
#  [0.3706513  0.29297525]
#  [0.35709178 0.31040353]
#  [0.37023902 0.32893652]]
# [0.37058763 0.31088921] [0.58051974 0.30708939] [0.49780566 0.31544545]
# (1, 4)
#
#
# [[0.44481966 0.35859507]
#  [0.43292725 0.34367144]
#  [0.42010331 0.35681692]
#  [0.43175647 0.37196928]]
# [0.43240167 0.35776318] [0.58084774 0.37158716] [0.52735907 0.36986312]
# (1, 4)
#
#
# [[0.41945288 0.21429338]
#  [0.40561402 0.19893256]
#  [0.39322981 0.21631545]
#  [0.40702844 0.23250952]]
# [0.40633129 0.21551273] [0.56294316 0.19498055] [0.50625378 0.21475279]
# (1, 4)
#
#
# [[0.51657516 0.40493855]
#  [0.5058428  0.39181122]
#  [0.49447399 0.40383205]
#  [0.50503075 0.41733778]]
# [0.50548068 0.4044799 ] [0.65312994 0.41555971] [0.59932184 0.41380799]
# (1, 4)
#
#
# [[0.39027804 0.548437  ]
#  [0.36639613 0.51811099]
#  [0.34091464 0.54676348]
#  [0.36492056 0.57841694]]
# [0.36562734 0.5479321 ] [0.64917594 0.55567896] [0.54635811 0.57226855]
# (1, 4)
#
#
# [[0.38026506 0.40197584]
#  [0.36291426 0.38589707]
#  [0.3491061  0.40568802]
#  [0.36596724 0.42242116]]
# [0.36456317 0.40399552] [0.56580746 0.38943738] [0.49097332 0.40263164]
# (1, 4)
#
#
# [[0.54108727 0.47630394]
#  [0.5261988  0.46231169]
#  [0.51347321 0.479018  ]
#  [0.52820039 0.49350357]]
# [0.52723992 0.4777843 ] [0.6901834  0.46840209] [0.62955725 0.47691062]
# (1, 4)
#
#
# [[0.48346385 0.54263186]
#  [0.47283643 0.53188562]
#  [0.4632037  0.54370904]
#  [0.47343561 0.55461389]]
# [0.4732349 0.5432101] [0.61713469 0.52811199] [0.56183875 0.53745693]
# (1, 4)
#
#
# [[0.4392302  0.46409833]
#  [0.43071774 0.45574287]
#  [0.42330629 0.46516824]
#  [0.43167377 0.4737111 ]]
# [0.431232   0.46468014] [0.54102343 0.4549022 ] [0.50071341 0.46079385]
# (1, 4)
#
#
# [[0.52578658 0.34460625]
#  [0.5166744  0.33378828]
#  [0.50761718 0.34484911]
#  [0.51667356 0.35614526]]
# [0.51668793 0.34484722] [0.65418202 0.35437459] [0.60286736 0.34712434]
# (1, 4)
#
#
# [[0.37444752 0.46739593]
#  [0.35939437 0.45686185]
#  [0.34837401 0.47435939]
#  [0.36328706 0.4853498 ]]
# [0.36137574 0.47099175] [0.52134615 0.43296233] [0.46524987 0.45065147]
# (1, 4)
#
#
# [[0.5316385  0.33927381]
#  [0.52469659 0.33019966]
#  [0.51705873 0.33786905]
#  [0.52379674 0.34702069]]
# [0.52429764 0.3385908 ] [0.63559651 0.34322581] [0.5951224  0.34169915]
# (1, 4)
#
#
# [[0.47641855 0.26815039]
#  [0.46242669 0.25279117]
#  [0.44869637 0.26786375]
#  [0.46254176 0.28367531]]
# [0.46252085 0.26812015] [0.62944567 0.2809608 ] [0.56714332 0.28052539]
# (1, 4)
#
#
# [[0.41544715 0.41328499]
#  [0.40307683 0.40034968]
#  [0.39154127 0.41408554]
#  [0.40392509 0.42726398]]
# [0.40349758 0.41374604] [0.55645168 0.41458303] [0.50491703 0.4171946 ]
# (1, 4)
#
#
# [[0.43893018 0.29794186]
#  [0.42788982 0.28440127]
#  [0.41600469 0.29592913]
#  [0.42679173 0.30998951]]
# [0.42740411 0.29706544] [0.55839074 0.31484482] [0.51111054 0.31187174]
# (1, 4)
#
#
# [[0.53258783 0.61294758]
#  [0.51315111 0.59009379]
#  [0.49498093 0.61372781]
#  [0.51526326 0.63788676]]
# [0.51399578 0.61366399] [0.73066205 0.60512906] [0.65340561 0.62261719]
# (1, 4)
#
#
# [[0.4536106  0.52554923]
#  [0.44214964 0.51359528]
#  [0.43135908 0.52606487]
#  [0.44260302 0.53854293]]
# [0.44243059 0.52593808] [0.59441257 0.52787995] [0.5421353  0.53080976]
# (1, 4)

# %% [markdown]
# # End
