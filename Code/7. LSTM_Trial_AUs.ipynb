# %% [markdown]
# # **Introduction**
# The goal of this program is to detect deception in videos using the LSTM (Long Short Term Memory) network. We use LSTM because a single image or video frame is not enough to tell whether a person is lying. LSTM is well-suited for sequential analysis. The LSTM model will take Action Units (AUs) as an input and output a probability of the person telling the truth.<br><br>
#
# Action Units (AUs) track the movements of individual or group facial muscles. We use OpenFace, a toolkit that is able to judge the existence of 18 recognizable AU subsets and score the intensity of 17 AUs. This gives us a total of 35 AUs (features). Because we were unable to run OpenFace on Google Colab, we did so on our local machines and uploaded the corresponding CSV files to Drive. <br><br>
#
#
# 1.   For each video, we used OpenFace to extract 35 AUs on each frame. The result for each video is saved as an csv file.
# 2.   We take the results of 30 consecutive video frames as 1 input (or chunk). For example, if a video has 240 frames, then it has 8 chunks. We discard the remainder frames.
# 3. We feed the chunks and the corresponding true/false value into an LSTM model

# %% [markdown]
# # **Import Relevant Python Modules**

# %%
from google.colab import drive
drive.mount('/content/drive')

import numpy as np
import glob
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F

# Check for GPU availability and set device
#device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = torch.device("cpu")
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Getting the Input X and Output Y**

# %%
# Converts a CSV file into a Numpy array
def csv_to_npy_chunk(path):
  df = pd.read_csv(path)
  # Take the last 35 columns
  df = df.iloc[:, -35:]
  data = df.to_numpy()

  chunk_size = 30
  num_chunks = data.shape[0] // chunk_size

  # Split the array into chunks
  chunks = np.array_split(data[:num_chunks * 30], num_chunks)

  # Convert list of arrays to a single numpy array
  array = np.stack(chunks)
  return array

# %%
from pathlib import Path

PROCESSED = '/content/drive/MyDrive/Deception_Detection/processed_trial'

# Separate out the Truth Videos and False Videos
# This allows us to collect the same percentage of Truth videos in our Training Set and Testing Set, reducing bias


input_list_T = []
input_list_F = []
output_list_T = []
output_list_F = []

loop = 1
for file_path in glob.glob(PROCESSED+"/*.csv", recursive = True):
  array = csv_to_npy_chunk(file_path)

  num_chunks = array.shape[0]

  output = Path(file_path).stem.split("_")[1] == "truth"
  if output == True:
    input_list_T.append(array)
    output_list_T += [output]*num_chunks
  else:
    input_list_F.append(array)
    output_list_F += [output]*num_chunks
  print(f"# of Videos Processed: {loop}")
  loop += 1

X_T = np.vstack(input_list_T)
X_F = np.vstack(input_list_F)
Y_T = np.array(output_list_T).reshape(-1,1)
Y_F = np.array(output_list_F).reshape(-1,1)



X_T = torch.from_numpy(X_T).to(device)
X_F = torch.from_numpy(X_F).to(device)
Y_T = torch.from_numpy(Y_T).to(device)
Y_F = torch.from_numpy(Y_F).to(device)

X_T = X_T.float()
X_F = X_F.float()
Y_T = Y_T.float()
Y_F = Y_F.float()

print("X_T.shape", X_T.shape)
print("X_F.shape", X_F.shape)
print("Y_T.shape", Y_T.shape)
print("Y_F.shape", Y_F.shape)
# Out:
# # of Videos Processed: 1
# # of Videos Processed: 2
# # of Videos Processed: 3
# # of Videos Processed: 4
# # of Videos Processed: 5
# # of Videos Processed: 6
# # of Videos Processed: 7
# # of Videos Processed: 8
# # of Videos Processed: 9
# # of Videos Processed: 10
# # of Videos Processed: 11
# # of Videos Processed: 12
# # of Videos Processed: 13
# %% [markdown]
# # Data Split

# %%
import torch.utils.data as data

# Split the shuffled data into 80% Training, 20% Testing
train_dataset_T, val_dataset_T = torch.utils.data.random_split(data.TensorDataset(X_T, Y_T), [0.8, 0.2])
train_dataset_F, val_dataset_F = torch.utils.data.random_split(data.TensorDataset(X_F, Y_F), [0.8, 0.2])

train_dataset = data.ConcatDataset([train_dataset_T, train_dataset_F])
val_dataset = data.ConcatDataset([val_dataset_T, val_dataset_F])

print("Training Dataset Size:", len(train_dataset))
print("Testing Dataset Size:", len(val_dataset))
print()

train_loader = data.DataLoader(train_dataset, batch_size=50, shuffle=True)

total_train_samples = len(train_dataset)
count_train_ones = sum(1 for _, label in train_dataset if label == 1)
percentage_train_ones = (count_train_ones / total_train_samples) * 100
print("Percentage of Y that are Truths in train_dataset:", percentage_train_ones)


test_loader = data.DataLoader(val_dataset, batch_size=1, shuffle=False)

total_val_samples = len(val_dataset)
count_val_ones = sum(1 for _, label in val_dataset if label == 1)
percentage_val_ones = (count_val_ones / total_val_samples) * 100
print("Percentage of Y that are Truths in val_dataset:", percentage_val_ones)


X_train_all = []
Y_train_all = []


# Iterate over the train_loader to accumulate the entire dataset
for X_train, Y_train in train_loader:
    X_train_all.append(X_train)
    Y_train_all.append(Y_train)

X_test_all = []
Y_test_all = []

for X_test, Y_test in test_loader:
    X_test_all.append(X_test)
    Y_test_all.append(Y_test)

X_test_all = torch.cat(X_test_all, dim=0).to(device)
Y_test_all = torch.cat(Y_test_all, dim=0).to(device)

X_train_all = torch.cat(X_train_all, dim=0).to(device)
Y_train_all = torch.cat(Y_train_all, dim=0).to(device)
# Out:
# Training Dataset Size: 2375
# Testing Dataset Size: 593
#
# Percentage of Y that are Truths in train_dataset: 46.31578947368421
# Percentage of Y that are Truths in val_dataset: 46.3743676222597

# %% [markdown]
# # LSTM Model

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

class LSTMModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, layer_num, output_dim):
        super().__init__()
        self.lstm = nn.LSTM(input_size=input_dim, hidden_size=hidden_dim, num_layers=layer_num, batch_first=True)
        self.dropout = nn.Dropout(0.17)
        self.linear = nn.Linear(170, 1)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        out, _ = self.lstm(x)
        out = out[:, -1, :]
        out = self.linear(self.dropout(out))
        out = self.sigmoid(out)
        return out

# %%
import torch.utils.data as data
import matplotlib.pyplot as plt

# Lists to store training and test losses for each epoch
train_losses = []
test_losses = []

# Function to calculate accuracy
def accuracy(outputs, labels):
  preds = torch.round(outputs)
  return torch.tensor(torch.sum(preds == labels).item() / len(preds))


criterion = nn.BCELoss()
model = LSTMModel(input_dim=35, hidden_dim=170, layer_num=1, output_dim=1)
model = model.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

num_epochs = 50

# Training loop
for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0.0
    epoch_acc = 0.0
    for X_batch, y_batch in train_loader:
        y_pred = model(X_batch)
        loss = criterion(y_pred, y_batch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    model.eval()
    with torch.no_grad():
        print("-------------------")
        # Calculate accuracy on training set
        y_pred = model(X_train_all)
        train_loss = criterion(y_pred, Y_train_all)
        train_acc = accuracy(y_pred, Y_train_all)

        # Calculate accuracy on test set
        y_pred = model(X_test_all)
        test_loss = criterion(y_pred, Y_test_all)
        test_acc = accuracy(y_pred, Y_test_all)

    print("Epoch %d: train loss %.4f, test loss %.4f, train accuracy %.4f, test accuracy %.4f" % (epoch, train_loss, test_loss, train_acc, test_acc))

    # Append the losses to the lists
    train_losses.append(train_loss)
    test_losses.append(test_loss)

# Smooth the losses using a moving average
window_size = 5
train_losses_smoothed = np.convolve(train_losses, np.ones(window_size) / window_size, mode='valid')
test_losses_smoothed = np.convolve(test_losses, np.ones(window_size) / window_size, mode='valid')

# Plotting epoch vs training loss and test loss
epochs = range(window_size // 2 + 1, num_epochs - window_size // 2 + 1)
plt.plot(epochs, train_losses_smoothed, label='Train Loss')
plt.plot(epochs, test_losses_smoothed, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Epoch vs Loss (Smoothed)')
plt.legend()
plt.show()
# Out:
# -------------------
# Epoch 0: train loss 0.5468, test loss 0.5367, train accuracy 0.6758, test accuracy 0.6813
# -------------------
# Epoch 1: train loss 0.5391, test loss 0.5441, train accuracy 0.6733, test accuracy 0.6695
# -------------------
# Epoch 2: train loss 0.4843, test loss 0.4968, train accuracy 0.7288, test accuracy 0.7336
# -------------------
# Epoch 3: train loss 0.4539, test loss 0.4712, train accuracy 0.7486, test accuracy 0.7470
# -------------------
# Epoch 4: train loss 0.4642, test loss 0.5025, train accuracy 0.7575, test accuracy 0.7420
# -------------------
# Epoch 5: train loss 0.4086, test loss 0.4557, train accuracy 0.7916, test accuracy 0.7555
# -------------------
# Epoch 6: train loss 0.3964, test loss 0.4644, train accuracy 0.7924, test accuracy 0.7605
# -------------------
# Epoch 7: train loss 0.3949, test loss 0.4369, train accuracy 0.7975, test accuracy 0.7723
# -------------------
# Epoch 8: train loss 0.3647, test loss 0.4378, train accuracy 0.8101, test accuracy 0.7774
# -------------------
# Epoch 9: train loss 0.3786, test loss 0.4067, train accuracy 0.8046, test accuracy 0.7909
# -------------------
# Epoch 10: train loss 0.3475, test loss 0.4031, train accuracy 0.8219, test accuracy 0.7993
# -------------------
# Epoch 11: train loss 0.3291, test loss 0.4056, train accuracy 0.8341, test accuracy 0.8044
# -------------------
# Epoch 12: train loss 0.3011, test loss 0.3953, train accuracy 0.8501, test accuracy 0.8196
# -------------------
# Epoch 13: train loss 0.2981, test loss 0.3925, train accuracy 0.8556, test accuracy 0.8196
# -------------------
# Epoch 14: train loss 0.2857, test loss 0.3753, train accuracy 0.8632, test accuracy 0.8111
# -------------------
# Epoch 15: train loss 0.2777, test loss 0.4047, train accuracy 0.8632, test accuracy 0.8331
# -------------------
# Epoch 16: train loss 0.2446, test loss 0.3775, train accuracy 0.8859, test accuracy 0.8263
# -------------------
# Epoch 17: train loss 0.2273, test loss 0.3389, train accuracy 0.8939, test accuracy 0.8583
# -------------------
# Epoch 18: train loss 0.2176, test loss 0.4017, train accuracy 0.9027, test accuracy 0.8263
# -------------------
# Epoch 19: train loss 0.2721, test loss 0.3901, train accuracy 0.8813, test accuracy 0.8179
# -------------------
# Epoch 20: train loss 0.2187, test loss 0.3617, train accuracy 0.9011, test accuracy 0.8314
# -------------------
# Epoch 21: train loss 0.1596, test loss 0.3835, train accuracy 0.9267, test accuracy 0.8516
# -------------------
# Epoch 22: train loss 0.1732, test loss 0.3422, train accuracy 0.9385, test accuracy 0.8600
# -------------------
# Epoch 23: train loss 0.1913, test loss 0.3701, train accuracy 0.9162, test accuracy 0.8482
# -------------------
# Epoch 24: train loss 0.1439, test loss 0.3908, train accuracy 0.9427, test accuracy 0.8634
# -------------------
# Epoch 25: train loss 0.1480, test loss 0.3951, train accuracy 0.9385, test accuracy 0.8482
# -------------------
# Epoch 26: train loss 0.1077, test loss 0.3850, train accuracy 0.9566, test accuracy 0.8651
# -------------------
# Epoch 27: train loss 0.1052, test loss 0.4657, train accuracy 0.9562, test accuracy 0.8499
# -------------------
# Epoch 28: train loss 0.1985, test loss 0.3892, train accuracy 0.9162, test accuracy 0.8550
# -------------------
# Epoch 29: train loss 0.1283, test loss 0.4113, train accuracy 0.9427, test accuracy 0.8432
# -------------------
# Epoch 30: train loss 0.0917, test loss 0.4093, train accuracy 0.9655, test accuracy 0.8651
# -------------------
# Epoch 31: train loss 0.1062, test loss 0.4591, train accuracy 0.9604, test accuracy 0.8600
# -------------------
# Epoch 32: train loss 0.0847, test loss 0.4187, train accuracy 0.9697, test accuracy 0.8600
# -------------------
# Epoch 33: train loss 0.0621, test loss 0.3975, train accuracy 0.9756, test accuracy 0.8820
# -------------------
# Epoch 34: train loss 0.1395, test loss 0.4924, train accuracy 0.9453, test accuracy 0.8449
# -------------------
# Epoch 35: train loss 0.0736, test loss 0.4393, train accuracy 0.9726, test accuracy 0.8550
# -------------------
# Epoch 36: train loss 0.0563, test loss 0.4952, train accuracy 0.9815, test accuracy 0.8735
# -------------------
# Epoch 37: train loss 0.0936, test loss 0.4047, train accuracy 0.9672, test accuracy 0.8533
# -------------------
# Epoch 38: train loss 0.0531, test loss 0.5522, train accuracy 0.9802, test accuracy 0.8499
# -------------------
# Epoch 39: train loss 0.0736, test loss 0.4640, train accuracy 0.9798, test accuracy 0.8482
# -------------------
# Epoch 40: train loss 0.0561, test loss 0.5016, train accuracy 0.9794, test accuracy 0.8634
# -------------------
# Epoch 41: train loss 0.0761, test loss 0.5320, train accuracy 0.9680, test accuracy 0.8583
# -------------------
# Epoch 42: train loss 0.0706, test loss 0.4222, train accuracy 0.9777, test accuracy 0.8550
# -------------------
# Epoch 43: train loss 0.0469, test loss 0.4822, train accuracy 0.9832, test accuracy 0.8718
# -------------------
# Epoch 44: train loss 0.0686, test loss 0.5569, train accuracy 0.9819, test accuracy 0.8583
# -------------------
# Epoch 45: train loss 0.0921, test loss 0.3879, train accuracy 0.9688, test accuracy 0.8499
# -------------------
# Epoch 46: train loss 0.0439, test loss 0.5282, train accuracy 0.9844, test accuracy 0.8567
# -------------------
# Epoch 47: train loss 0.0467, test loss 0.4279, train accuracy 0.9865, test accuracy 0.8651
# -------------------
# Epoch 48: train loss 0.0390, test loss 0.5091, train accuracy 0.9853, test accuracy 0.8702
# -------------------
# Epoch 49: train loss 0.0238, test loss 0.5098, train accuracy 0.9903, test accuracy 0.8718
